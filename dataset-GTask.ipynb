# %%
import pandas as pd
from textblob import TextBlob
import inflect
import nltk
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from nltk.corpus import stopwords

# Download stopwords untuk nltk
nltk.download('stopwords')

# Inisialisasi inflect engine untuk konversi angka ke kata
p = inflect.engine()

# Inisialisasi stemmer Bahasa Indonesia dari Sastrawi
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# Mengambil daftar stopwords bahasa Indonesia
stop_words = set(stopwords.words('indonesian'))

# Fungsi untuk memperbaiki typo
# def perbaiki_typo(teks):
#     blob = TextBlob(teks)
#     return str(blob.correct())

# Fungsi untuk mengganti angka dengan kata
angka_to_kata = {
    '0': 'nol', '1': 'satu', '2': 'dua', '3': 'tiga', '4': 'empat',
    '5': 'lima', '6': 'enam', '7': 'tujuh', '8': 'delapan', '9': 'sembilan'
}

# Fungsi untuk mengganti angka dengan kata
def ganti_angka_dengan_kata(teks):
    def replace(match):
        return angka_to_kata[match.group(0)]
    return re.sub(r'\d', replace, teks)

# Fungsi untuk tokenisasi
def tokenize(teks):
    return teks.split()

# Fungsi untuk transformasi kasus (menjadi huruf kecil)
def transform_case(teks):
    return teks.lower()

# Fungsi untuk menghapus stopwords
def hapus_stopwords(teks):
    tokens = teks.split()
    tokens = [word for word in tokens if word not in stop_words]
    return ' '.join(tokens)

# Fungsi untuk stemming
def stem_text(teks):
    return stemmer.stem(teks)

# Membaca file excel
df = pd.read_excel('./dataset-GTask.xlsx')

# Proses preprocessing dengan cetakan proses
for index, row in df.iterrows():
    print(f"Original: {row['content']}")

#     row['content'] = perbaiki_typo(row['content'])
#     print(f"After typo correction: {row['content']}")

    row['content'] = ganti_angka_dengan_kata(row['content'])
    print(f"After replacing numbers: {row['content']}")

    row['content'] = transform_case(row['content'])
    print(f"After case transformation: {row['content']}")

    tokens = tokenize(row['content'])
    print(f"After tokenization: {tokens}")

    row['content'] = ' '.join(tokens)
    row['content'] = hapus_stopwords(row['content'])
    print(f"After stopword removal: {row['content']}")

    row['content'] = stem_text(row['content'])
    print(f"After stemming: {row['content']}")

    # Update the dataframe with processed content
    df.at[index, 'content'] = row['content']
    print("------")

# Menyimpan kembali ke file excel atau menampilkan hasil
df.to_excel('dataset-GTask-after-preprocess.xlsx', index=False)
print(df.head())
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Original: Aplikasi ini sudah bagus, tetapi selain centang tugas, tambahkan fitur Nama, berdasarkan tanggal, dan Notifikasi. Buruan download!
# After replacing numbers: Aplikasi ini sudah bagus, tetapi selain centang tugas, tambahkan fitur Nama, berdasarkan tanggal, dan Notifikasi. Buruan download!
# After case transformation: aplikasi ini sudah bagus, tetapi selain centang tugas, tambahkan fitur nama, berdasarkan tanggal, dan notifikasi. buruan download!
# After tokenization: ['aplikasi', 'ini', 'sudah', 'bagus,', 'tetapi', 'selain', 'centang', 'tugas,', 'tambahkan', 'fitur', 'nama,', 'berdasarkan', 'tanggal,', 'dan', 'notifikasi.', 'buruan', 'download!']
# After stopword removal: aplikasi bagus, centang tugas, tambahkan fitur nama, berdasarkan tanggal, notifikasi. buruan download!
# After stemming: aplikasi bagus centang tugas tambah fitur nama dasar tanggal notifikasi buru download
# ------
# Original: bagus google
# After replacing numbers: bagus google
# After case transformation: bagus google
# After tokenization: ['bagus', 'google']
# After stopword removal: bagus google
# After stemming: bagus google
# ------
# Original: Terimakasih akun masih tersimpan dan masih bisa di gunakan
# After replacing numbers: Terimakasih akun masih tersimpan dan masih bisa di gunakan
# After case transformation: terimakasih akun masih tersimpan dan masih bisa di gunakan
# After tokenization: ['terimakasih', 'akun', 'masih', 'tersimpan', 'dan', 'masih', 'bisa', 'di', 'gunakan']
# After stopword removal: terimakasih akun tersimpan
# After stemming: terimakasih akun simpan
# ------
# Original: mencoba produktif berkarya dibantu aplikasi ini buat manajemen
# After replacing numbers: mencoba produktif berkarya dibantu aplikasi ini buat manajemen
# After case transformation: mencoba produktif berkarya dibantu aplikasi ini buat manajemen
# After tokenization: ['mencoba', 'produktif', 'berkarya', 'dibantu', 'aplikasi', 'ini', 'buat', 'manajemen']
# After stopword removal: mencoba produktif berkarya dibantu aplikasi manajemen
# After stemming: coba produktif karya bantu aplikasi manajemen
# ------
# Original: Sangat bermanfaat
# After replacing numbers: Sangat bermanfaat
# After case transformation: sangat bermanfaat
# After tokenization: ['sangat', 'bermanfaat']
# After stopword removal: bermanfaat
# After stemming: manfaat
# ------
# Original: terimakasih menyediakan layanannya, gratis
# After replacing numbers: terimakasih menyediakan layanannya, gratis
# After case transformation: terimakasih menyediakan layanannya, gratis
# After tokenization: ['terimakasih', 'menyediakan', 'layanannya,', 'gratis']
# After stopword removal: terimakasih menyediakan layanannya, gratis
# After stemming: terimakasih sedia layan gratis
# ------
# Original: sejauh ini saya suka, simple dan ringan aplikasinya..
# After replacing numbers: sejauh ini saya suka, simple dan ringan aplikasinya..
# After case transformation: sejauh ini saya suka, simple dan ringan aplikasinya..
# After tokenization: ['sejauh', 'ini', 'saya', 'suka,', 'simple', 'dan', 'ringan', 'aplikasinya..']
# After stopword removal: suka, simple ringan aplikasinya..
# After stemming: suka simple ringan aplikasi
# ------
# Original: Sangat bagus.
# After replacing numbers: Sangat bagus.
# After case transformation: sangat bagus.
# After tokenization: ['sangat', 'bagus.']
# After stopword removal: bagus.
# After stemming: bagus
# ------
# Original: Sangat berguna, semoga bisa lebih berinovasi lagi tentang fitur dan tampilan apknya ya, agar lebih fresh dan simpel
# After replacing numbers: Sangat berguna, semoga bisa lebih berinovasi lagi tentang fitur dan tampilan apknya ya, agar lebih fresh dan simpel
# After case transformation: sangat berguna, semoga bisa lebih berinovasi lagi tentang fitur dan tampilan apknya ya, agar lebih fresh dan simpel
# After tokenization: ['sangat', 'berguna,', 'semoga', 'bisa', 'lebih', 'berinovasi', 'lagi', 'tentang', 'fitur', 'dan', 'tampilan', 'apknya', 'ya,', 'agar', 'lebih', 'fresh', 'dan', 'simpel']
# After stopword removal: berguna, semoga berinovasi fitur tampilan apknya ya, fresh simpel
# After stemming: guna moga inovasi fitur tampil apknya ya fresh simpel
# ------
# Original: sangat berguna
# After replacing numbers: sangat berguna
# After case transformation: sangat berguna
# After tokenization: ['sangat', 'berguna']
# After stopword removal: berguna
# After stemming: guna
# ------
# Original: Saya baru download dan saya kasih biNtang 5
# After replacing numbers: Saya baru download dan saya kasih biNtang lima
# After case transformation: saya baru download dan saya kasih bintang lima
# After tokenization: ['saya', 'baru', 'download', 'dan', 'saya', 'kasih', 'bintang', 'lima']
# After stopword removal: download kasih bintang
# After stemming: download kasih bintang
# ------
# Original: Semua cara membuat tujuan target terdeteksi sesuai misiku
# After replacing numbers: Semua cara membuat tujuan target terdeteksi sesuai misiku
# After case transformation: semua cara membuat tujuan target terdeteksi sesuai misiku
# After tokenization: ['semua', 'cara', 'membuat', 'tujuan', 'target', 'terdeteksi', 'sesuai', 'misiku']
# After stopword removal: tujuan target terdeteksi sesuai misiku
# After stemming: tuju target deteksi sesuai misi
# ------
# Original: Membantu sekali dalam urutan pengerjakan tugas
# After replacing numbers: Membantu sekali dalam urutan pengerjakan tugas
# After case transformation: membantu sekali dalam urutan pengerjakan tugas
# After tokenization: ['membantu', 'sekali', 'dalam', 'urutan', 'pengerjakan', 'tugas']
# After stopword removal: membantu urutan pengerjakan tugas
# After stemming: bantu urut kerja tugas
# ------
# Original: Terimakasih sangat membantu untuk mengorganisir Tugas
# After replacing numbers: Terimakasih sangat membantu untuk mengorganisir Tugas
# After case transformation: terimakasih sangat membantu untuk mengorganisir tugas
# After tokenization: ['terimakasih', 'sangat', 'membantu', 'untuk', 'mengorganisir', 'tugas']
# After stopword removal: terimakasih membantu mengorganisir tugas
# After stemming: terimakasih bantu organisir tugas
# ------
# Original: Aplikasi nya udah bagus tapi tolong tambahkan fitur notifikasi untuk tugasnya agar tahu
# After replacing numbers: Aplikasi nya udah bagus tapi tolong tambahkan fitur notifikasi untuk tugasnya agar tahu
# After case transformation: aplikasi nya udah bagus tapi tolong tambahkan fitur notifikasi untuk tugasnya agar tahu
# After tokenization: ['aplikasi', 'nya', 'udah', 'bagus', 'tapi', 'tolong', 'tambahkan', 'fitur', 'notifikasi', 'untuk', 'tugasnya', 'agar', 'tahu']
# After stopword removal: aplikasi nya udah bagus tolong tambahkan fitur notifikasi tugasnya
# After stemming: aplikasi nya udah bagus tolong tambah fitur notifikasi tugas
# ------
# Original: sederhana dan membantu
# After replacing numbers: sederhana dan membantu
# After case transformation: sederhana dan membantu
# After tokenization: ['sederhana', 'dan', 'membantu']
# After stopword removal: sederhana membantu
# After stemming: sederhana bantu
# ------
# Original: Luar Biasa Aplikasi Nya Sangat Membantu
# After replacing numbers: Luar Biasa Aplikasi Nya Sangat Membantu
# After case transformation: luar biasa aplikasi nya sangat membantu
# After tokenization: ['luar', 'biasa', 'aplikasi', 'nya', 'sangat', 'membantu']
# After stopword removal: aplikasi nya membantu
# After stemming: aplikasi nya bantu
# ------
# Original: Suka sama interfacenya
# After replacing numbers: Suka sama interfacenya
# After case transformation: suka sama interfacenya
# After tokenization: ['suka', 'sama', 'interfacenya']
# After stopword removal: suka interfacenya
# After stemming: suka interfacenya
# ------
# Original: Bagus dan ada notifikasinya
# After replacing numbers: Bagus dan ada notifikasinya
# After case transformation: bagus dan ada notifikasinya
# After tokenization: ['bagus', 'dan', 'ada', 'notifikasinya']
# After stopword removal: bagus notifikasinya
# After stemming: bagus notifikasi
# ------
# Original: Bagi yang butuh, ini recommended, simple, mudah di gunakan..
# After replacing numbers: Bagi yang butuh, ini recommended, simple, mudah di gunakan..
# After case transformation: bagi yang butuh, ini recommended, simple, mudah di gunakan..
# After tokenization: ['bagi', 'yang', 'butuh,', 'ini', 'recommended,', 'simple,', 'mudah', 'di', 'gunakan..']
# After stopword removal: butuh, recommended, simple, mudah gunakan..
# After stemming: butuh recommended simple mudah guna
# ------
# Original: SANGAT bagus Google tasks, silakan dicoba ya
# After replacing numbers: SANGAT bagus Google tasks, silakan dicoba ya
# After case transformation: sangat bagus google tasks, silakan dicoba ya
# After tokenization: ['sangat', 'bagus', 'google', 'tasks,', 'silakan', 'dicoba', 'ya']
# After stopword removal: bagus google tasks, silakan dicoba ya
# After stemming: bagus google tasks sila coba ya
# ------
# Original: simple dan mudah digunakan
# After replacing numbers: simple dan mudah digunakan
# After case transformation: simple dan mudah digunakan
# After tokenization: ['simple', 'dan', 'mudah', 'digunakan']
# After stopword removal: simple mudah
# After stemming: simple mudah
# ------
# Original: Saya ingin google, kedepan semakin mudah, pengguna menggunakannya
# After replacing numbers: Saya ingin google, kedepan semakin mudah, pengguna menggunakannya
# After case transformation: saya ingin google, kedepan semakin mudah, pengguna menggunakannya
# After tokenization: ['saya', 'ingin', 'google,', 'kedepan', 'semakin', 'mudah,', 'pengguna', 'menggunakannya']
# After stopword removal: google, kedepan mudah, pengguna menggunakannya
# After stemming: google depan mudah guna guna
# ------
# Original: sementara masih bagus, tidak ada iklan
# After replacing numbers: sementara masih bagus, tidak ada iklan
# After case transformation: sementara masih bagus, tidak ada iklan
# After tokenization: ['sementara', 'masih', 'bagus,', 'tidak', 'ada', 'iklan']
# After stopword removal: bagus, iklan
# After stemming: bagus iklan
# ------
# Original: luar biasa aplikasi buat nulis todolist sangat simpel tampilan sederhana dan menariknya bisa langsung terhubung ke google calendar mantap
# After replacing numbers: luar biasa aplikasi buat nulis todolist sangat simpel tampilan sederhana dan menariknya bisa langsung terhubung ke google calendar mantap
# After case transformation: luar biasa aplikasi buat nulis todolist sangat simpel tampilan sederhana dan menariknya bisa langsung terhubung ke google calendar mantap
# After tokenization: ['luar', 'biasa', 'aplikasi', 'buat', 'nulis', 'todolist', 'sangat', 'simpel', 'tampilan', 'sederhana', 'dan', 'menariknya', 'bisa', 'langsung', 'terhubung', 'ke', 'google', 'calendar', 'mantap']
# After stopword removal: aplikasi nulis todolist simpel tampilan sederhana menariknya langsung terhubung google calendar mantap
# After stemming: aplikasi nulis todolist simpel tampil sederhana tarik langsung hubung google calendar mantap
# ------
# Original: berinovasi
# After replacing numbers: berinovasi
# After case transformation: berinovasi
# After tokenization: ['berinovasi']
# After stopword removal: berinovasi
# After stemming: inovasi
# ------
# Original: praktis simpel dan mudah digunakan
# After replacing numbers: praktis simpel dan mudah digunakan
# After case transformation: praktis simpel dan mudah digunakan
# After tokenization: ['praktis', 'simpel', 'dan', 'mudah', 'digunakan']
# After stopword removal: praktis simpel mudah
# After stemming: praktis simpel mudah
# ------
# Original: Integrasi dengan google calendar sudah. Selanjutnya, saran saya adalah adanya fitur untuk merubah warna tugas seperti Google Calendar. Dengan demikian, kita bisa melihat pemetaan dan pembagian waktu berdasarkan peran kita.
# After replacing numbers: Integrasi dengan google calendar sudah. Selanjutnya, saran saya adalah adanya fitur untuk merubah warna tugas seperti Google Calendar. Dengan demikian, kita bisa melihat pemetaan dan pembagian waktu berdasarkan peran kita.
# After case transformation: integrasi dengan google calendar sudah. selanjutnya, saran saya adalah adanya fitur untuk merubah warna tugas seperti google calendar. dengan demikian, kita bisa melihat pemetaan dan pembagian waktu berdasarkan peran kita.
# After tokenization: ['integrasi', 'dengan', 'google', 'calendar', 'sudah.', 'selanjutnya,', 'saran', 'saya', 'adalah', 'adanya', 'fitur', 'untuk', 'merubah', 'warna', 'tugas', 'seperti', 'google', 'calendar.', 'dengan', 'demikian,', 'kita', 'bisa', 'melihat', 'pemetaan', 'dan', 'pembagian', 'waktu', 'berdasarkan', 'peran', 'kita.']
# After stopword removal: integrasi google calendar sudah. selanjutnya, saran fitur merubah warna tugas google calendar. demikian, pemetaan pembagian berdasarkan peran kita.
# After stemming: integrasi google calendar sudah lanjut saran fitur rubah warna tugas google calendar demikian meta bagi dasar peran kita
# ------
# Original: membantu mengingatkan
# After replacing numbers: membantu mengingatkan
# After case transformation: membantu mengingatkan
# After tokenization: ['membantu', 'mengingatkan']
# After stopword removal: membantu
# After stemming: bantu
# ------
# Original: Tolong tambahkan fitur "All task"
# After replacing numbers: Tolong tambahkan fitur "All task"
# After case transformation: tolong tambahkan fitur "all task"
# After tokenization: ['tolong', 'tambahkan', 'fitur', '"all', 'task"']
# After stopword removal: tolong tambahkan fitur "all task"
# After stemming: tolong tambah fitur all task
# ------
# Original: bagus sekali dan sangat membantu, dan connect juga ke google kalendar. good
# After replacing numbers: bagus sekali dan sangat membantu, dan connect juga ke google kalendar. good
# After case transformation: bagus sekali dan sangat membantu, dan connect juga ke google kalendar. good
# After tokenization: ['bagus', 'sekali', 'dan', 'sangat', 'membantu,', 'dan', 'connect', 'juga', 'ke', 'google', 'kalendar.', 'good']
# After stopword removal: bagus membantu, connect google kalendar. good
# After stemming: bagus bantu connect google kalendar good
# ------
# Original: Sangat memudahkan ingatan, pekerjaan dan bersifat praktis.
# After replacing numbers: Sangat memudahkan ingatan, pekerjaan dan bersifat praktis.
# After case transformation: sangat memudahkan ingatan, pekerjaan dan bersifat praktis.
# After tokenization: ['sangat', 'memudahkan', 'ingatan,', 'pekerjaan', 'dan', 'bersifat', 'praktis.']
# After stopword removal: memudahkan ingatan, pekerjaan bersifat praktis.
# After stemming: mudah ingat kerja sifat praktis
# ------
# Original: Sangat bermanfaat untuk saya mencatat idea saya. Terimakasih google telah menciptakan aplikasi bermanfaat ini. No iklan lagi
# After replacing numbers: Sangat bermanfaat untuk saya mencatat idea saya. Terimakasih google telah menciptakan aplikasi bermanfaat ini. No iklan lagi
# After case transformation: sangat bermanfaat untuk saya mencatat idea saya. terimakasih google telah menciptakan aplikasi bermanfaat ini. no iklan lagi
# After tokenization: ['sangat', 'bermanfaat', 'untuk', 'saya', 'mencatat', 'idea', 'saya.', 'terimakasih', 'google', 'telah', 'menciptakan', 'aplikasi', 'bermanfaat', 'ini.', 'no', 'iklan', 'lagi']
# After stopword removal: bermanfaat mencatat idea saya. terimakasih google menciptakan aplikasi bermanfaat ini. no iklan
# After stemming: manfaat catat idea saya terimakasih google cipta aplikasi manfaat ini no iklan
# ------
# Original: Tampilannya sederhana dan gk ribet dan bisa buat pengingat aktivitas seperti alarm
# After replacing numbers: Tampilannya sederhana dan gk ribet dan bisa buat pengingat aktivitas seperti alarm
# After case transformation: tampilannya sederhana dan gk ribet dan bisa buat pengingat aktivitas seperti alarm
# After tokenization: ['tampilannya', 'sederhana', 'dan', 'gk', 'ribet', 'dan', 'bisa', 'buat', 'pengingat', 'aktivitas', 'seperti', 'alarm']
# After stopword removal: tampilannya sederhana gk ribet pengingat aktivitas alarm
# After stemming: tampil sederhana gk ribet ingat aktivitas alarm
# ------
# Original: Bagus Dan bermanfaat
# After replacing numbers: Bagus Dan bermanfaat
# After case transformation: bagus dan bermanfaat
# After tokenization: ['bagus', 'dan', 'bermanfaat']
# After stopword removal: bagus bermanfaat
# After stemming: bagus manfaat
# ------
# Original: Sangat membantu. Oke
# After replacing numbers: Sangat membantu. Oke
# After case transformation: sangat membantu. oke
# After tokenization: ['sangat', 'membantu.', 'oke']
# After stopword removal: membantu. oke
# After stemming: bantu oke
# ------
# Original: bagus tepat.
# After replacing numbers: bagus tepat.
# After case transformation: bagus tepat.
# After tokenization: ['bagus', 'tepat.']
# After stopword removal: bagus tepat.
# After stemming: bagus tepat
# ------
# Original: mantap banget
# After replacing numbers: mantap banget
# After case transformation: mantap banget
# After tokenization: ['mantap', 'banget']
# After stopword removal: mantap banget
# After stemming: mantap banget
# ------
# Original: Mencatat lebih baik bagi saya daripada mengingat setiap saat
# After replacing numbers: Mencatat lebih baik bagi saya daripada mengingat setiap saat
# After case transformation: mencatat lebih baik bagi saya daripada mengingat setiap saat
# After tokenization: ['mencatat', 'lebih', 'baik', 'bagi', 'saya', 'daripada', 'mengingat', 'setiap', 'saat']
# After stopword removal: mencatat
# After stemming: catat
# ------
# Original: Sangat bermanfaat bagi yang ingin tugas-tugasnya tersusun rapih
# After replacing numbers: Sangat bermanfaat bagi yang ingin tugas-tugasnya tersusun rapih
# After case transformation: sangat bermanfaat bagi yang ingin tugas-tugasnya tersusun rapih
# After tokenization: ['sangat', 'bermanfaat', 'bagi', 'yang', 'ingin', 'tugas-tugasnya', 'tersusun', 'rapih']
# After stopword removal: bermanfaat tugas-tugasnya tersusun rapih
# After stemming: manfaat tugas susun rapih
# ------
# Original: aplikasi bagus, terhubung google drive
# After replacing numbers: aplikasi bagus, terhubung google drive
# After case transformation: aplikasi bagus, terhubung google drive
# After tokenization: ['aplikasi', 'bagus,', 'terhubung', 'google', 'drive']
# After stopword removal: aplikasi bagus, terhubung google drive
# After stemming: aplikasi bagus hubung google drive
# ------
# Original: Kasih Bintang 5 lah biar semangat, Install saja lah jarang dipake ge produk Google punya
# After replacing numbers: Kasih Bintang lima lah biar semangat, Install saja lah jarang dipake ge produk Google punya
# After case transformation: kasih bintang lima lah biar semangat, install saja lah jarang dipake ge produk google punya
# After tokenization: ['kasih', 'bintang', 'lima', 'lah', 'biar', 'semangat,', 'install', 'saja', 'lah', 'jarang', 'dipake', 'ge', 'produk', 'google', 'punya']
# After stopword removal: kasih bintang biar semangat, install jarang dipake ge produk google
# After stemming: kasih bintang biar semangat install jarang dipake ge produk google
# ------
# Original: sudah baik, tapi perlu ditingkatkan
# After replacing numbers: sudah baik, tapi perlu ditingkatkan
# After case transformation: sudah baik, tapi perlu ditingkatkan
# After tokenization: ['sudah', 'baik,', 'tapi', 'perlu', 'ditingkatkan']
# After stopword removal: baik, ditingkatkan
# After stemming: baik tingkat
# ------
# Original: Sederhana, tanpa basa-basi dan power full
# After replacing numbers: Sederhana, tanpa basa-basi dan power full
# After case transformation: sederhana, tanpa basa-basi dan power full
# After tokenization: ['sederhana,', 'tanpa', 'basa-basi', 'dan', 'power', 'full']
# After stopword removal: sederhana, basa-basi power full
# After stemming: sederhana basa-basi power full
# ------
# Original: Seperti aplikasi google lainnya, simple, efektif, dan efisien.
# After replacing numbers: Seperti aplikasi google lainnya, simple, efektif, dan efisien.
# After case transformation: seperti aplikasi google lainnya, simple, efektif, dan efisien.
# After tokenization: ['seperti', 'aplikasi', 'google', 'lainnya,', 'simple,', 'efektif,', 'dan', 'efisien.']
# After stopword removal: aplikasi google lainnya, simple, efektif, efisien.
# After stemming: aplikasi google lain simple efektif efisien
# ------
# Original: Google teks sangat bagus buat pengingat acara penting didalam aktifitas kerja.
# After replacing numbers: Google teks sangat bagus buat pengingat acara penting didalam aktifitas kerja.
# After case transformation: google teks sangat bagus buat pengingat acara penting didalam aktifitas kerja.
# After tokenization: ['google', 'teks', 'sangat', 'bagus', 'buat', 'pengingat', 'acara', 'penting', 'didalam', 'aktifitas', 'kerja.']
# After stopword removal: google teks bagus pengingat acara didalam aktifitas kerja.
# After stemming: google teks bagus ingat acara dalam aktifitas kerja
# ------
# Original: Aplikasinya bagus, cukup simple jadi enggak lupa kalo mau ngerjain tugas
# After replacing numbers: Aplikasinya bagus, cukup simple jadi enggak lupa kalo mau ngerjain tugas
# After case transformation: aplikasinya bagus, cukup simple jadi enggak lupa kalo mau ngerjain tugas
# After tokenization: ['aplikasinya', 'bagus,', 'cukup', 'simple', 'jadi', 'enggak', 'lupa', 'kalo', 'mau', 'ngerjain', 'tugas']
# After stopword removal: aplikasinya bagus, simple lupa kalo ngerjain tugas
# After stemming: aplikasi bagus simple lupa kalo ngerjain tugas
# ------
# Original: Aplikasi andal dan bug dan kesalahan minimalis
# After replacing numbers: Aplikasi andal dan bug dan kesalahan minimalis
# After case transformation: aplikasi andal dan bug dan kesalahan minimalis
# After tokenization: ['aplikasi', 'andal', 'dan', 'bug', 'dan', 'kesalahan', 'minimalis']
# After stopword removal: aplikasi andal bug kesalahan minimalis
# After stemming: aplikasi andal bug salah minimal
# ------
# Original: berguna bagi yang pelupa
# After replacing numbers: berguna bagi yang pelupa
# After case transformation: berguna bagi yang pelupa
# After tokenization: ['berguna', 'bagi', 'yang', 'pelupa']
# After stopword removal: berguna pelupa
# After stemming: guna lupa
# ------
# Original: Semua lengkap dari versi Google tinggal jalankan saja
# After replacing numbers: Semua lengkap dari versi Google tinggal jalankan saja
# After case transformation: semua lengkap dari versi google tinggal jalankan saja
# After tokenization: ['semua', 'lengkap', 'dari', 'versi', 'google', 'tinggal', 'jalankan', 'saja']
# After stopword removal: lengkap versi google tinggal jalankan
# After stemming: lengkap versi google tinggal jalan
# ------
# Original:   ,kepikiran aplikasi yang bisa bantu mencatat program rutin dengan judul , Sub judul dan sub sub judul .   sama dikasih aplikasi ini muncul di layar utama Google Play .
# After replacing numbers:   ,kepikiran aplikasi yang bisa bantu mencatat program rutin dengan judul , Sub judul dan sub sub judul .   sama dikasih aplikasi ini muncul di layar utama Google Play .
# After case transformation:   ,kepikiran aplikasi yang bisa bantu mencatat program rutin dengan judul , sub judul dan sub sub judul .   sama dikasih aplikasi ini muncul di layar utama google play .
# After tokenization: [',kepikiran', 'aplikasi', 'yang', 'bisa', 'bantu', 'mencatat', 'program', 'rutin', 'dengan', 'judul', ',', 'sub', 'judul', 'dan', 'sub', 'sub', 'judul', '.', 'sama', 'dikasih', 'aplikasi', 'ini', 'muncul', 'di', 'layar', 'utama', 'google', 'play', '.']
# After stopword removal: ,kepikiran aplikasi bantu mencatat program rutin judul , sub judul sub sub judul . dikasih aplikasi muncul layar utama google play .
# After stemming: pikir aplikasi bantu catat program rutin judul sub judul sub sub judul kasih aplikasi muncul layar utama google play
# ------
# Original: apps ini sangat berguna seperti apps google lainnya (keep , calendar, drive , foto tugas2 sekolah / tugas2 rumah saya dapat terselesasikan di waktu yang tepat karena ada pengingat yang langsung tersambung dengan calendar , pokoknya good job deh buat google task , thanks google task
# After replacing numbers: apps ini sangat berguna seperti apps google lainnya (keep , calendar, drive , foto tugasdua sekolah / tugasdua rumah saya dapat terselesasikan di waktu yang tepat karena ada pengingat yang langsung tersambung dengan calendar , pokoknya good job deh buat google task , thanks google task
# After case transformation: apps ini sangat berguna seperti apps google lainnya (keep , calendar, drive , foto tugasdua sekolah / tugasdua rumah saya dapat terselesasikan di waktu yang tepat karena ada pengingat yang langsung tersambung dengan calendar , pokoknya good job deh buat google task , thanks google task
# After tokenization: ['apps', 'ini', 'sangat', 'berguna', 'seperti', 'apps', 'google', 'lainnya', '(keep', ',', 'calendar,', 'drive', ',', 'foto', 'tugasdua', 'sekolah', '/', 'tugasdua', 'rumah', 'saya', 'dapat', 'terselesasikan', 'di', 'waktu', 'yang', 'tepat', 'karena', 'ada', 'pengingat', 'yang', 'langsung', 'tersambung', 'dengan', 'calendar', ',', 'pokoknya', 'good', 'job', 'deh', 'buat', 'google', 'task', ',', 'thanks', 'google', 'task']
# After stopword removal: apps berguna apps google (keep , calendar, drive , foto tugasdua sekolah / tugasdua rumah terselesasikan pengingat langsung tersambung calendar , pokoknya good job deh google task , thanks google task
# After stemming: apps guna apps google keep calendar drive foto tugasdua sekolah tugasdua rumah terselesasikan ingat langsung sambung calendar pokok good job deh google task thanks google task
# ------
# Original: sederhana tapi tegas. penggunaan lancar tanpa masalah
# After replacing numbers: sederhana tapi tegas. penggunaan lancar tanpa masalah
# After case transformation: sederhana tapi tegas. penggunaan lancar tanpa masalah
# After tokenization: ['sederhana', 'tapi', 'tegas.', 'penggunaan', 'lancar', 'tanpa', 'masalah']
# After stopword removal: sederhana tegas. penggunaan lancar
# After stemming: sederhana tegas guna lancar
# ------
# Original: simple dan mudah pengaplikasiannya
# After replacing numbers: simple dan mudah pengaplikasiannya
# After case transformation: simple dan mudah pengaplikasiannya
# After tokenization: ['simple', 'dan', 'mudah', 'pengaplikasiannya']
# After stopword removal: simple mudah pengaplikasiannya
# After stemming: simple mudah aplikasi
# ------
# Original: dengan aplikasi ini saya dapat mengingatkan saya tentang tugas saya
# After replacing numbers: dengan aplikasi ini saya dapat mengingatkan saya tentang tugas saya
# After case transformation: dengan aplikasi ini saya dapat mengingatkan saya tentang tugas saya
# After tokenization: ['dengan', 'aplikasi', 'ini', 'saya', 'dapat', 'mengingatkan', 'saya', 'tentang', 'tugas', 'saya']
# After stopword removal: aplikasi tugas
# After stemming: aplikasi tugas
# ------
# Original: Membuat saya lebih terkesan
# After replacing numbers: Membuat saya lebih terkesan
# After case transformation: membuat saya lebih terkesan
# After tokenization: ['membuat', 'saya', 'lebih', 'terkesan']
# After stopword removal: terkesan
# After stemming: kes
# ------
# Original: Membantu mengatur tugas sehari-hari
# After replacing numbers: Membantu mengatur tugas sehari-hari
# After case transformation: membantu mengatur tugas sehari-hari
# After tokenization: ['membantu', 'mengatur', 'tugas', 'sehari-hari']
# After stopword removal: membantu mengatur tugas sehari-hari
# After stemming: bantu atur tugas hari
# ------
# Original: sederhana, interaktif, dapat digunakan, dan dipraktikkan
# After replacing numbers: sederhana, interaktif, dapat digunakan, dan dipraktikkan
# After case transformation: sederhana, interaktif, dapat digunakan, dan dipraktikkan
# After tokenization: ['sederhana,', 'interaktif,', 'dapat', 'digunakan,', 'dan', 'dipraktikkan']
# After stopword removal: sederhana, interaktif, digunakan, dipraktikkan
# After stemming: sederhana interaktif guna praktik
# ------
# Original: sebelumnya aku kasih 4, sekarang sudah 5. untuk Google LLC semoga bisa ciptakan aplikasi lainnya yang punya fitur keren seperti ini lagi
# After replacing numbers: sebelumnya aku kasih empat, sekarang sudah lima. untuk Google LLC semoga bisa ciptakan aplikasi lainnya yang punya fitur keren seperti ini lagi
# After case transformation: sebelumnya aku kasih empat, sekarang sudah lima. untuk google llc semoga bisa ciptakan aplikasi lainnya yang punya fitur keren seperti ini lagi
# After tokenization: ['sebelumnya', 'aku', 'kasih', 'empat,', 'sekarang', 'sudah', 'lima.', 'untuk', 'google', 'llc', 'semoga', 'bisa', 'ciptakan', 'aplikasi', 'lainnya', 'yang', 'punya', 'fitur', 'keren', 'seperti', 'ini', 'lagi']
# After stopword removal: kasih empat, lima. google llc semoga ciptakan aplikasi fitur keren
# After stemming: kasih empat lima google llc moga cipta aplikasi fitur keren
# ------
# Original: Bagus, ditambahkan fitur berganti warna dong untuk setiap daftar tugas
# After replacing numbers: Bagus, ditambahkan fitur berganti warna dong untuk setiap daftar tugas
# After case transformation: bagus, ditambahkan fitur berganti warna dong untuk setiap daftar tugas
# After tokenization: ['bagus,', 'ditambahkan', 'fitur', 'berganti', 'warna', 'dong', 'untuk', 'setiap', 'daftar', 'tugas']
# After stopword removal: bagus, fitur berganti warna daftar tugas
# After stemming: bagus fitur ganti warna daftar tugas
# ------
# Original: Aplikasi simple mudah digunakan, sangat bermanfaat bagi catatan saya tentang rencana apa saja yang akan dikerjaan sehingga tidak ada pekerjaan yang terlewatkan. Saran saya terus ditingkatkan tampilan antarmuka dibuat lebih atraktif dan interaktif supaya pengguna tidak bosan saat buka apps..
# After replacing numbers: Aplikasi simple mudah digunakan, sangat bermanfaat bagi catatan saya tentang rencana apa saja yang akan dikerjaan sehingga tidak ada pekerjaan yang terlewatkan. Saran saya terus ditingkatkan tampilan antarmuka dibuat lebih atraktif dan interaktif supaya pengguna tidak bosan saat buka apps..
# After case transformation: aplikasi simple mudah digunakan, sangat bermanfaat bagi catatan saya tentang rencana apa saja yang akan dikerjaan sehingga tidak ada pekerjaan yang terlewatkan. saran saya terus ditingkatkan tampilan antarmuka dibuat lebih atraktif dan interaktif supaya pengguna tidak bosan saat buka apps..
# After tokenization: ['aplikasi', 'simple', 'mudah', 'digunakan,', 'sangat', 'bermanfaat', 'bagi', 'catatan', 'saya', 'tentang', 'rencana', 'apa', 'saja', 'yang', 'akan', 'dikerjaan', 'sehingga', 'tidak', 'ada', 'pekerjaan', 'yang', 'terlewatkan.', 'saran', 'saya', 'terus', 'ditingkatkan', 'tampilan', 'antarmuka', 'dibuat', 'lebih', 'atraktif', 'dan', 'interaktif', 'supaya', 'pengguna', 'tidak', 'bosan', 'saat', 'buka', 'apps..']
# After stopword removal: aplikasi simple mudah digunakan, bermanfaat catatan rencana dikerjaan pekerjaan terlewatkan. saran ditingkatkan tampilan antarmuka atraktif interaktif pengguna bosan buka apps..
# After stemming: aplikasi simple mudah guna manfaat catat rencana kerja kerja lewat saran tingkat tampil antarmuka atraktif interaktif guna bosan buka apps
# ------
# Original: Membantu mengingat pekerjaan
# After replacing numbers: Membantu mengingat pekerjaan
# After case transformation: membantu mengingat pekerjaan
# After tokenization: ['membantu', 'mengingat', 'pekerjaan']
# After stopword removal: membantu pekerjaan
# After stemming: bantu kerja
# ------
# Original: Bagus Simple Berguna
# After replacing numbers: Bagus Simple Berguna
# After case transformation: bagus simple berguna
# After tokenization: ['bagus', 'simple', 'berguna']
# After stopword removal: bagus simple berguna
# After stemming: bagus simple guna
# ------
# Original: Sangat membantu membuat to do list sehingga membantu mengerjakan apa saja yang harus saya kerjakan setiap hari. Saran : Tambahkan fitur arsipkan tugas jadi tugas yg sudah selesai bisa diarsipkan
# After replacing numbers: Sangat membantu membuat to do list sehingga membantu mengerjakan apa saja yang harus saya kerjakan setiap hari. Saran : Tambahkan fitur arsipkan tugas jadi tugas yg sudah selesai bisa diarsipkan
# After case transformation: sangat membantu membuat to do list sehingga membantu mengerjakan apa saja yang harus saya kerjakan setiap hari. saran : tambahkan fitur arsipkan tugas jadi tugas yg sudah selesai bisa diarsipkan
# After tokenization: ['sangat', 'membantu', 'membuat', 'to', 'do', 'list', 'sehingga', 'membantu', 'mengerjakan', 'apa', 'saja', 'yang', 'harus', 'saya', 'kerjakan', 'setiap', 'hari.', 'saran', ':', 'tambahkan', 'fitur', 'arsipkan', 'tugas', 'jadi', 'tugas', 'yg', 'sudah', 'selesai', 'bisa', 'diarsipkan']
# After stopword removal: membantu to do list membantu kerjakan hari. saran : tambahkan fitur arsipkan tugas tugas yg selesai diarsipkan
# After stemming: bantu to do list bantu kerja hari saran tambah fitur arsip tugas tugas yg selesai arsip
# ------
# Original: Mudah digunakan sesuai kebutuhan
# After replacing numbers: Mudah digunakan sesuai kebutuhan
# After case transformation: mudah digunakan sesuai kebutuhan
# After tokenization: ['mudah', 'digunakan', 'sesuai', 'kebutuhan']
# After stopword removal: mudah sesuai kebutuhan
# After stemming: mudah sesuai butuh
# ------
# Original: Membantu sekali.. terimakasih
# After replacing numbers: Membantu sekali.. terimakasih
# After case transformation: membantu sekali.. terimakasih
# After tokenization: ['membantu', 'sekali..', 'terimakasih']
# After stopword removal: membantu sekali.. terimakasih
# After stemming: bantu sekali terimakasih
# ------
# Original: Mudah dan simple untuk digunakan
# After replacing numbers: Mudah dan simple untuk digunakan
# After case transformation: mudah dan simple untuk digunakan
# After tokenization: ['mudah', 'dan', 'simple', 'untuk', 'digunakan']
# After stopword removal: mudah simple
# After stemming: mudah simple
# ------
# Original: Mantap, semua dapat tercatat lengkap, asal ditepati jadwalnya.
# After replacing numbers: Mantap, semua dapat tercatat lengkap, asal ditepati jadwalnya.
# After case transformation: mantap, semua dapat tercatat lengkap, asal ditepati jadwalnya.
# After tokenization: ['mantap,', 'semua', 'dapat', 'tercatat', 'lengkap,', 'asal', 'ditepati', 'jadwalnya.']
# After stopword removal: mantap, tercatat lengkap, ditepati jadwalnya.
# After stemming: mantap catat lengkap tepat jadwal
# ------
# Original: mantap google task membantu produktifitas
# After replacing numbers: mantap google task membantu produktifitas
# After case transformation: mantap google task membantu produktifitas
# After tokenization: ['mantap', 'google', 'task', 'membantu', 'produktifitas']
# After stopword removal: mantap google task membantu produktifitas
# After stemming: mantap google task bantu produktifitas
# ------
# Original: Emang dasarnya suka produk google
# After replacing numbers: Emang dasarnya suka produk google
# After case transformation: emang dasarnya suka produk google
# After tokenization: ['emang', 'dasarnya', 'suka', 'produk', 'google']
# After stopword removal: emang dasarnya suka produk google
# After stemming: emang dasar suka produk google
# ------
# Original: Buat mengikuti program kreativitas cocok buat pertemuan berikutnya
# After replacing numbers: Buat mengikuti program kreativitas cocok buat pertemuan berikutnya
# After case transformation: buat mengikuti program kreativitas cocok buat pertemuan berikutnya
# After tokenization: ['buat', 'mengikuti', 'program', 'kreativitas', 'cocok', 'buat', 'pertemuan', 'berikutnya']
# After stopword removal: mengikuti program kreativitas cocok pertemuan
# After stemming: ikut program kreativitas cocok temu
# ------
# Original: Ini adalah aplikasi yang ringan 'simple dan bermanfaat untuk mendukung pribadi yang lebih produktif dan memanajemen waktu dengan lebih baik.
# After replacing numbers: Ini adalah aplikasi yang ringan 'simple dan bermanfaat untuk mendukung pribadi yang lebih produktif dan memanajemen waktu dengan lebih baik.
# After case transformation: ini adalah aplikasi yang ringan 'simple dan bermanfaat untuk mendukung pribadi yang lebih produktif dan memanajemen waktu dengan lebih baik.
# After tokenization: ['ini', 'adalah', 'aplikasi', 'yang', 'ringan', "'simple", 'dan', 'bermanfaat', 'untuk', 'mendukung', 'pribadi', 'yang', 'lebih', 'produktif', 'dan', 'memanajemen', 'waktu', 'dengan', 'lebih', 'baik.']
# After stopword removal: aplikasi ringan 'simple bermanfaat mendukung pribadi produktif memanajemen baik.
# After stemming: aplikasi ringan simple manfaat dukung pribadi produktif manajemen baik
# ------
# Original: Sangat membatu rutinitas saya setiap hari
# After replacing numbers: Sangat membatu rutinitas saya setiap hari
# After case transformation: sangat membatu rutinitas saya setiap hari
# After tokenization: ['sangat', 'membatu', 'rutinitas', 'saya', 'setiap', 'hari']
# After stopword removal: membatu rutinitas
# After stemming: batu rutinitas
# ------
# Original: Urutan catatan yg mudah dan cepat yg terbaca dengan sekilas pandang.
# After replacing numbers: Urutan catatan yg mudah dan cepat yg terbaca dengan sekilas pandang.
# After case transformation: urutan catatan yg mudah dan cepat yg terbaca dengan sekilas pandang.
# After tokenization: ['urutan', 'catatan', 'yg', 'mudah', 'dan', 'cepat', 'yg', 'terbaca', 'dengan', 'sekilas', 'pandang.']
# After stopword removal: urutan catatan yg mudah cepat yg terbaca sekilas pandang.
# After stemming: urut catat yg mudah cepat yg baca kilas pandang
# ------
# Original: Google Tasks membantu saya mengingat tugas-tugas yang harus saya lakukan berdasarkan batas akhir. Akan lebih bagus jika kedepannya ditambahkan fitur lockscreen dari Google yang dapat diberi fitur dari Google Tasks ini
# After replacing numbers: Google Tasks membantu saya mengingat tugas-tugas yang harus saya lakukan berdasarkan batas akhir. Akan lebih bagus jika kedepannya ditambahkan fitur lockscreen dari Google yang dapat diberi fitur dari Google Tasks ini
# After case transformation: google tasks membantu saya mengingat tugas-tugas yang harus saya lakukan berdasarkan batas akhir. akan lebih bagus jika kedepannya ditambahkan fitur lockscreen dari google yang dapat diberi fitur dari google tasks ini
# After tokenization: ['google', 'tasks', 'membantu', 'saya', 'mengingat', 'tugas-tugas', 'yang', 'harus', 'saya', 'lakukan', 'berdasarkan', 'batas', 'akhir.', 'akan', 'lebih', 'bagus', 'jika', 'kedepannya', 'ditambahkan', 'fitur', 'lockscreen', 'dari', 'google', 'yang', 'dapat', 'diberi', 'fitur', 'dari', 'google', 'tasks', 'ini']
# After stopword removal: google tasks membantu tugas-tugas lakukan berdasarkan batas akhir. bagus kedepannya fitur lockscreen google fitur google tasks
# After stemming: google tasks bantu tugas laku dasar batas akhir bagus depan fitur lockscreen google fitur google tasks
# ------
# Original: keren sekali aplikasi ini saya benar-benar sangat sukaa !!
# After replacing numbers: keren sekali aplikasi ini saya benar-benar sangat sukaa !!
# After case transformation: keren sekali aplikasi ini saya benar-benar sangat sukaa !!
# After tokenization: ['keren', 'sekali', 'aplikasi', 'ini', 'saya', 'benar-benar', 'sangat', 'sukaa', '!!']
# After stopword removal: keren aplikasi benar-benar sukaa !!
# After stemming: keren aplikasi benar sukaa
# ------
# Original: Mudah digunakan
# After replacing numbers: Mudah digunakan
# After case transformation: mudah digunakan
# After tokenization: ['mudah', 'digunakan']
# After stopword removal: mudah
# After stemming: mudah
# ------
# Original: Simple enak digunakan mantap, tambahin fitur yang lebih menarik ya
# After replacing numbers: Simple enak digunakan mantap, tambahin fitur yang lebih menarik ya
# After case transformation: simple enak digunakan mantap, tambahin fitur yang lebih menarik ya
# After tokenization: ['simple', 'enak', 'digunakan', 'mantap,', 'tambahin', 'fitur', 'yang', 'lebih', 'menarik', 'ya']
# After stopword removal: simple enak mantap, tambahin fitur menarik ya
# After stemming: simple enak mantap tambahin fitur tarik ya
# ------
# Original: Sangat membantu untuk memanajemen tugas. Biar lebih terjadwal dan meminimalisir lupa
# After replacing numbers: Sangat membantu untuk memanajemen tugas. Biar lebih terjadwal dan meminimalisir lupa
# After case transformation: sangat membantu untuk memanajemen tugas. biar lebih terjadwal dan meminimalisir lupa
# After tokenization: ['sangat', 'membantu', 'untuk', 'memanajemen', 'tugas.', 'biar', 'lebih', 'terjadwal', 'dan', 'meminimalisir', 'lupa']
# After stopword removal: membantu memanajemen tugas. biar terjadwal meminimalisir lupa
# After stemming: bantu manajemen tugas biar jadwal meminimalisir lupa
# ------
# Original: Sangat baik, sangat membantu
# After replacing numbers: Sangat baik, sangat membantu
# After case transformation: sangat baik, sangat membantu
# After tokenization: ['sangat', 'baik,', 'sangat', 'membantu']
# After stopword removal: baik, membantu
# After stemming: baik bantu
# ------
# Original: Mudah dipakai, menata semua agenda kita, saya sangat terbantu dengan aplikasi task.
# After replacing numbers: Mudah dipakai, menata semua agenda kita, saya sangat terbantu dengan aplikasi task.
# After case transformation: mudah dipakai, menata semua agenda kita, saya sangat terbantu dengan aplikasi task.
# After tokenization: ['mudah', 'dipakai,', 'menata', 'semua', 'agenda', 'kita,', 'saya', 'sangat', 'terbantu', 'dengan', 'aplikasi', 'task.']
# After stopword removal: mudah dipakai, menata agenda kita, terbantu aplikasi task.
# After stemming: mudah pakai tata agenda kita bantu aplikasi task
# ------
# Original: Sangat membantu dan praktis karena dibagi berdasarkan kategorinya
# After replacing numbers: Sangat membantu dan praktis karena dibagi berdasarkan kategorinya
# After case transformation: sangat membantu dan praktis karena dibagi berdasarkan kategorinya
# After tokenization: ['sangat', 'membantu', 'dan', 'praktis', 'karena', 'dibagi', 'berdasarkan', 'kategorinya']
# After stopword removal: membantu praktis dibagi berdasarkan kategorinya
# After stemming: bantu praktis bagi dasar kategori
# ------
# Original: Sangat membantu pekerjaan
# After replacing numbers: Sangat membantu pekerjaan
# After case transformation: sangat membantu pekerjaan
# After tokenization: ['sangat', 'membantu', 'pekerjaan']
# After stopword removal: membantu pekerjaan
# After stemming: bantu kerja
# ------
# Original: Sangat membantu untuk manajemen semua kegiatan
# After replacing numbers: Sangat membantu untuk manajemen semua kegiatan
# After case transformation: sangat membantu untuk manajemen semua kegiatan
# After tokenization: ['sangat', 'membantu', 'untuk', 'manajemen', 'semua', 'kegiatan']
# After stopword removal: membantu manajemen kegiatan
# After stemming: bantu manajemen giat
# ------
# Original: Sangat membantu dalam mengelola tugas
# After replacing numbers: Sangat membantu dalam mengelola tugas
# After case transformation: sangat membantu dalam mengelola tugas
# After tokenization: ['sangat', 'membantu', 'dalam', 'mengelola', 'tugas']
# After stopword removal: membantu mengelola tugas
# After stemming: bantu kelola tugas
# ------
# Original: Sangat memudahkan pekerjaan
# After replacing numbers: Sangat memudahkan pekerjaan
# After case transformation: sangat memudahkan pekerjaan
# After tokenization: ['sangat', 'memudahkan', 'pekerjaan']
# After stopword removal: memudahkan pekerjaan
# After stemming: mudah kerja
# ------
# Original: Sangat membantu mengingatkan tugas2 kita. Karena produksi Google maka mudah terintegrasi dengan aplikasi lain.
# After replacing numbers: Sangat membantu mengingatkan tugasdua kita. Karena produksi Google maka mudah terintegrasi dengan aplikasi lain.
# After case transformation: sangat membantu mengingatkan tugasdua kita. karena produksi google maka mudah terintegrasi dengan aplikasi lain.
# After tokenization: ['sangat', 'membantu', 'mengingatkan', 'tugasdua', 'kita.', 'karena', 'produksi', 'google', 'maka', 'mudah', 'terintegrasi', 'dengan', 'aplikasi', 'lain.']
# After stopword removal: membantu tugasdua kita. produksi google mudah terintegrasi aplikasi lain.
# After stemming: bantu tugasdua kita produksi google mudah integrasi aplikasi lain
# ------
# Original: Tidak ribet. Simpel banget tapi membantu. Kalau bisa ada tambahan gambar
# After replacing numbers: Tidak ribet. Simpel banget tapi membantu. Kalau bisa ada tambahan gambar
# After case transformation: tidak ribet. simpel banget tapi membantu. kalau bisa ada tambahan gambar
# After tokenization: ['tidak', 'ribet.', 'simpel', 'banget', 'tapi', 'membantu.', 'kalau', 'bisa', 'ada', 'tambahan', 'gambar']
# After stopword removal: ribet. simpel banget membantu. tambahan gambar
# After stemming: ribet simpel banget bantu tambah gambar
# ------
# Original: karena saya sering lupa, ini sangat membantu untuk kegiatan sekolah, saya punya saran untuk menambah waktu tugas dibuat
# After replacing numbers: karena saya sering lupa, ini sangat membantu untuk kegiatan sekolah, saya punya saran untuk menambah waktu tugas dibuat
# After case transformation: karena saya sering lupa, ini sangat membantu untuk kegiatan sekolah, saya punya saran untuk menambah waktu tugas dibuat
# After tokenization: ['karena', 'saya', 'sering', 'lupa,', 'ini', 'sangat', 'membantu', 'untuk', 'kegiatan', 'sekolah,', 'saya', 'punya', 'saran', 'untuk', 'menambah', 'waktu', 'tugas', 'dibuat']
# After stopword removal: lupa, membantu kegiatan sekolah, saran menambah tugas
# After stemming: lupa bantu giat sekolah saran tambah tugas
# ------
# Original: Oke min aplikasinya bagus, membuatku jadi lebih terarah..terimakasih
# After replacing numbers: Oke min aplikasinya bagus, membuatku jadi lebih terarah..terimakasih
# After case transformation: oke min aplikasinya bagus, membuatku jadi lebih terarah..terimakasih
# After tokenization: ['oke', 'min', 'aplikasinya', 'bagus,', 'membuatku', 'jadi', 'lebih', 'terarah..terimakasih']
# After stopword removal: oke min aplikasinya bagus, membuatku terarah..terimakasih
# After stemming: oke min aplikasi bagus buat arah terimakasih
# ------
# Original: TUGAS BANYAK JADI TERSORTIR MANTAP
# After replacing numbers: TUGAS BANYAK JADI TERSORTIR MANTAP
# After case transformation: tugas banyak jadi tersortir mantap
# After tokenization: ['tugas', 'banyak', 'jadi', 'tersortir', 'mantap']
# After stopword removal: tugas tersortir mantap
# After stemming: tugas sortir mantap
# ------
# Original: Sangat membantu, terutama untuk orang yang sering lupa mau ngapain aja.
# After replacing numbers: Sangat membantu, terutama untuk orang yang sering lupa mau ngapain aja.
# After case transformation: sangat membantu, terutama untuk orang yang sering lupa mau ngapain aja.
# After tokenization: ['sangat', 'membantu,', 'terutama', 'untuk', 'orang', 'yang', 'sering', 'lupa', 'mau', 'ngapain', 'aja.']
# After stopword removal: membantu, orang lupa ngapain aja.
# After stemming: bantu orang lupa ngapain aja
# ------
# Original: Cukup bagus, semoga nanti ada peningkatan desain transparan di tampilan widgetnya
# After replacing numbers: Cukup bagus, semoga nanti ada peningkatan desain transparan di tampilan widgetnya
# After case transformation: cukup bagus, semoga nanti ada peningkatan desain transparan di tampilan widgetnya
# After tokenization: ['cukup', 'bagus,', 'semoga', 'nanti', 'ada', 'peningkatan', 'desain', 'transparan', 'di', 'tampilan', 'widgetnya']
# After stopword removal: bagus, semoga peningkatan desain transparan tampilan widgetnya
# After stemming: bagus moga tingkat desain transparan tampil widgetnya
# ------
# Original: aplikasinya sudah bagus nanti saya kasih bintang 5, jika ada menu tampilan seperti kanban board (Todo, doing, done)
# After replacing numbers: aplikasinya sudah bagus nanti saya kasih bintang lima, jika ada menu tampilan seperti kanban board (Todo, doing, done)
# After case transformation: aplikasinya sudah bagus nanti saya kasih bintang lima, jika ada menu tampilan seperti kanban board (todo, doing, done)
# After tokenization: ['aplikasinya', 'sudah', 'bagus', 'nanti', 'saya', 'kasih', 'bintang', 'lima,', 'jika', 'ada', 'menu', 'tampilan', 'seperti', 'kanban', 'board', '(todo,', 'doing,', 'done)']
# After stopword removal: aplikasinya bagus kasih bintang lima, menu tampilan kanban board (todo, doing, done)
# After stemming: aplikasi bagus kasih bintang lima menu tampil kanban board todo doing done
# ------
# Original: Gratis dan tidak ada iklan
# After replacing numbers: Gratis dan tidak ada iklan
# After case transformation: gratis dan tidak ada iklan
# After tokenization: ['gratis', 'dan', 'tidak', 'ada', 'iklan']
# After stopword removal: gratis iklan
# After stemming: gratis iklan
# ------
# Original: Sangat membantu kebutuhan saya
# After replacing numbers: Sangat membantu kebutuhan saya
# After case transformation: sangat membantu kebutuhan saya
# After tokenization: ['sangat', 'membantu', 'kebutuhan', 'saya']
# After stopword removal: membantu kebutuhan
# ...
# After case transformation: saya mencoba semuanya tetapi tidak diberitahukan tepat waktu dan beberapa tugas bahkan terlewatkan tanpa pemberitahuan
# After tokenization: ['saya', 'mencoba', 'semuanya', 'tetapi', 'tidak', 'diberitahukan', 'tepat', 'waktu', 'dan', 'beberapa', 'tugas', 'bahkan', 'terlewatkan', 'tanpa', 'pemberitahuan']
# After stopword removal: mencoba diberitahukan tugas terlewatkan pemberitahuan
# After stemming: coba diberitahukan tugas lewat pemberitahuan
# ------
# Original: pemberitahuannya berhenti berfungsi
# After replacing numbers: pemberitahuannya berhenti berfungsi
# After case transformation: pemberitahuannya berhenti berfungsi
# After tokenization: ['pemberitahuannya', 'berhenti', 'berfungsi']
# After stopword removal: pemberitahuannya berhenti berfungsi
# After stemming: pemberitahuannya henti fungsi
# ------
# Original: Tombol pencarian seharusnya ada di Google Tasks jadi seseorang dapat mencari tugas dan item lainnya
# After replacing numbers: Tombol pencarian seharusnya ada di Google Tasks jadi seseorang dapat mencari tugas dan item lainnya
# After case transformation: tombol pencarian seharusnya ada di google tasks jadi seseorang dapat mencari tugas dan item lainnya
# After tokenization: ['tombol', 'pencarian', 'seharusnya', 'ada', 'di', 'google', 'tasks', 'jadi', 'seseorang', 'dapat', 'mencari', 'tugas', 'dan', 'item', 'lainnya']
# After stopword removal: tombol pencarian google tasks mencari tugas item
# After stemming: tombol cari google tasks cari tugas item
# ------
# Original: Kamu nggak bisa berbagi daftar tugas kecuali punya versi workspace dari aplikasi ini. Seharusnya fitur dasar seperti ini ada.
# After replacing numbers: Kamu nggak bisa berbagi daftar tugas kecuali punya versi workspace dari aplikasi ini. Seharusnya fitur dasar seperti ini ada.
# After case transformation: kamu nggak bisa berbagi daftar tugas kecuali punya versi workspace dari aplikasi ini. seharusnya fitur dasar seperti ini ada.
# After tokenization: ['kamu', 'nggak', 'bisa', 'berbagi', 'daftar', 'tugas', 'kecuali', 'punya', 'versi', 'workspace', 'dari', 'aplikasi', 'ini.', 'seharusnya', 'fitur', 'dasar', 'seperti', 'ini', 'ada.']
# After stopword removal: nggak berbagi daftar tugas kecuali versi workspace aplikasi ini. fitur dasar ada.
# After stemming: nggak bagi daftar tugas kecuali versi workspace aplikasi ini fitur dasar ada
# ------
# Original: Nggak kasih notifikasi.
# After replacing numbers: Nggak kasih notifikasi.
# After case transformation: nggak kasih notifikasi.
# After tokenization: ['nggak', 'kasih', 'notifikasi.']
# After stopword removal: nggak kasih notifikasi.
# After stemming: nggak kasih notifikasi
# ------
# Original: Sekarang aplikasi ini mengirimkan pengingat dari 2 tahun yang lalu!! Aku nggak bisa matikan pengingatnya. Aku juga nggak bisa langsung ke kalender buat hapus. Ini benar-benar mengganggu sekali!!!
# After replacing numbers: Sekarang aplikasi ini mengirimkan pengingat dari dua tahun yang lalu!! Aku nggak bisa matikan pengingatnya. Aku juga nggak bisa langsung ke kalender buat hapus. Ini benar-benar mengganggu sekali!!!
# After case transformation: sekarang aplikasi ini mengirimkan pengingat dari dua tahun yang lalu!! aku nggak bisa matikan pengingatnya. aku juga nggak bisa langsung ke kalender buat hapus. ini benar-benar mengganggu sekali!!!
# After tokenization: ['sekarang', 'aplikasi', 'ini', 'mengirimkan', 'pengingat', 'dari', 'dua', 'tahun', 'yang', 'lalu!!', 'aku', 'nggak', 'bisa', 'matikan', 'pengingatnya.', 'aku', 'juga', 'nggak', 'bisa', 'langsung', 'ke', 'kalender', 'buat', 'hapus.', 'ini', 'benar-benar', 'mengganggu', 'sekali!!!']
# After stopword removal: aplikasi mengirimkan pengingat lalu!! nggak matikan pengingatnya. nggak langsung kalender hapus. benar-benar mengganggu sekali!!!
# After stemming: aplikasi kirim ingat lalu nggak mati ingat nggak langsung kalender hapus benar ganggu sekali
# ------
# Original: cepet perbaikin
# After replacing numbers: cepet perbaikin
# After case transformation: cepet perbaikin
# After tokenization: ['cepet', 'perbaikin']
# After stopword removal: cepet perbaikin
# After stemming: cepet perbaikin
# ------
# Original: Tidak ada pencarian, tidak ada semua task dalam satu layar
# After replacing numbers: Tidak ada pencarian, tidak ada semua task dalam satu layar
# After case transformation: tidak ada pencarian, tidak ada semua task dalam satu layar
# After tokenization: ['tidak', 'ada', 'pencarian,', 'tidak', 'ada', 'semua', 'task', 'dalam', 'satu', 'layar']
# After stopword removal: pencarian, task layar
# After stemming: cari task layar
# ------
# Original: Pengingat tidak muncul sehingga terlewatkan. Aplikasi yang mengerikan.
# After replacing numbers: Pengingat tidak muncul sehingga terlewatkan. Aplikasi yang mengerikan.
# After case transformation: pengingat tidak muncul sehingga terlewatkan. aplikasi yang mengerikan.
# After tokenization: ['pengingat', 'tidak', 'muncul', 'sehingga', 'terlewatkan.', 'aplikasi', 'yang', 'mengerikan.']
# After stopword removal: pengingat muncul terlewatkan. aplikasi mengerikan.
# After stemming: ingat muncul lewat aplikasi keri
# ------
# Original: setelah diupdate jadi aplikasi terpisah, notifikasinya cuma muncul separuh waktu, dan kadang-kadang aku harus buka aplikasinya dulu baru pengingatnya keluar. Semoga segera diperbaiki. Kecewa banget.
# After replacing numbers: setelah diupdate jadi aplikasi terpisah, notifikasinya cuma muncul separuh waktu, dan kadang-kadang aku harus buka aplikasinya dulu baru pengingatnya keluar. Semoga segera diperbaiki. Kecewa banget.
# After case transformation: setelah diupdate jadi aplikasi terpisah, notifikasinya cuma muncul separuh waktu, dan kadang-kadang aku harus buka aplikasinya dulu baru pengingatnya keluar. semoga segera diperbaiki. kecewa banget.
# After tokenization: ['setelah', 'diupdate', 'jadi', 'aplikasi', 'terpisah,', 'notifikasinya', 'cuma', 'muncul', 'separuh', 'waktu,', 'dan', 'kadang-kadang', 'aku', 'harus', 'buka', 'aplikasinya', 'dulu', 'baru', 'pengingatnya', 'keluar.', 'semoga', 'segera', 'diperbaiki.', 'kecewa', 'banget.']
# After stopword removal: diupdate aplikasi terpisah, notifikasinya muncul separuh waktu, kadang-kadang buka aplikasinya pengingatnya keluar. semoga diperbaiki. kecewa banget.
# After stemming: diupdate aplikasi pisah notifikasi muncul paruh waktu kadang buka aplikasi ingat keluar moga baik kecewa banget
# ------
# Original: fitur pencarian dimana? Apa yang dilakukan google!
# After replacing numbers: fitur pencarian dimana? Apa yang dilakukan google!
# After case transformation: fitur pencarian dimana? apa yang dilakukan google!
# After tokenization: ['fitur', 'pencarian', 'dimana?', 'apa', 'yang', 'dilakukan', 'google!']
# After stopword removal: fitur pencarian dimana? google!
# After stemming: fitur cari mana google
# ------
# Original: Di mana alarm? Apa gunanya memiliki pengingat waktu jika itu bahkan tidak mengingatkan saya pada waktu yang disebuntukan?
# After replacing numbers: Di mana alarm? Apa gunanya memiliki pengingat waktu jika itu bahkan tidak mengingatkan saya pada waktu yang disebuntukan?
# After case transformation: di mana alarm? apa gunanya memiliki pengingat waktu jika itu bahkan tidak mengingatkan saya pada waktu yang disebuntukan?
# After tokenization: ['di', 'mana', 'alarm?', 'apa', 'gunanya', 'memiliki', 'pengingat', 'waktu', 'jika', 'itu', 'bahkan', 'tidak', 'mengingatkan', 'saya', 'pada', 'waktu', 'yang', 'disebuntukan?']
# After stopword removal: alarm? gunanya memiliki pengingat disebuntukan?
# After stemming: alarm guna milik ingat buntu
# ------
# Original: dirancang dengan buruk Tidak dapat menghapus tugas tidak dapat membatalkan tidak dapat melakukan apa pun yang akan membuat ini berguna
# After replacing numbers: dirancang dengan buruk Tidak dapat menghapus tugas tidak dapat membatalkan tidak dapat melakukan apa pun yang akan membuat ini berguna
# After case transformation: dirancang dengan buruk tidak dapat menghapus tugas tidak dapat membatalkan tidak dapat melakukan apa pun yang akan membuat ini berguna
# After tokenization: ['dirancang', 'dengan', 'buruk', 'tidak', 'dapat', 'menghapus', 'tugas', 'tidak', 'dapat', 'membatalkan', 'tidak', 'dapat', 'melakukan', 'apa', 'pun', 'yang', 'akan', 'membuat', 'ini', 'berguna']
# After stopword removal: dirancang buruk menghapus tugas membatalkan berguna
# After stemming: rancang buruk hapus tugas batal guna
# ------
# Original: hanya semakin buruk seiring berjalannya waktu.
# After replacing numbers: hanya semakin buruk seiring berjalannya waktu.
# After case transformation: hanya semakin buruk seiring berjalannya waktu.
# After tokenization: ['hanya', 'semakin', 'buruk', 'seiring', 'berjalannya', 'waktu.']
# After stopword removal: buruk seiring berjalannya waktu.
# After stemming: buruk iring jalan waktu
# ------
# Original: "Tugas" baru, tidak ada pemberitahuan untuk pengingat.
# After replacing numbers: "Tugas" baru, tidak ada pemberitahuan untuk pengingat.
# After case transformation: "tugas" baru, tidak ada pemberitahuan untuk pengingat.
# After tokenization: ['"tugas"', 'baru,', 'tidak', 'ada', 'pemberitahuan', 'untuk', 'pengingat.']
# After stopword removal: "tugas" baru, pemberitahuan pengingat.
# After stemming: tugas baru pemberitahuan ingat
# ------
# Original: tidak ada pengingat yang berbunyi, sudah menauntukannya ke kalender dan pengingat kalender juga tidak lagi mati. Sampah
# After replacing numbers: tidak ada pengingat yang berbunyi, sudah menauntukannya ke kalender dan pengingat kalender juga tidak lagi mati. Sampah
# After case transformation: tidak ada pengingat yang berbunyi, sudah menauntukannya ke kalender dan pengingat kalender juga tidak lagi mati. sampah
# After tokenization: ['tidak', 'ada', 'pengingat', 'yang', 'berbunyi,', 'sudah', 'menauntukannya', 'ke', 'kalender', 'dan', 'pengingat', 'kalender', 'juga', 'tidak', 'lagi', 'mati.', 'sampah']
# After stopword removal: pengingat berbunyi, menauntukannya kalender pengingat kalender mati. sampah
# After stemming: ingat bunyi menauntukannya kalender ingat kalender mati sampah
# ------
# Original: Aku nggak menerima pemberitahuan untuk tugas-tugasku. Hari ini aku buat dua tugas yang seharusnya kasih pemberitahuan ke aku (jam 8 pagi dan jam 2 siang), tapi nggak ada yang kasih tahu aku. Barusan aku coba buat pemberitahuan tes buat satu menit ke depan dan semuanya langsung muncul. Aku pake Pixel 7 Pro.
# After replacing numbers: Aku nggak menerima pemberitahuan untuk tugas-tugasku. Hari ini aku buat dua tugas yang seharusnya kasih pemberitahuan ke aku (jam delapan pagi dan jam dua siang), tapi nggak ada yang kasih tahu aku. Barusan aku coba buat pemberitahuan tes buat satu menit ke depan dan semuanya langsung muncul. Aku pake Pixel tujuh Pro.
# After case transformation: aku nggak menerima pemberitahuan untuk tugas-tugasku. hari ini aku buat dua tugas yang seharusnya kasih pemberitahuan ke aku (jam delapan pagi dan jam dua siang), tapi nggak ada yang kasih tahu aku. barusan aku coba buat pemberitahuan tes buat satu menit ke depan dan semuanya langsung muncul. aku pake pixel tujuh pro.
# After tokenization: ['aku', 'nggak', 'menerima', 'pemberitahuan', 'untuk', 'tugas-tugasku.', 'hari', 'ini', 'aku', 'buat', 'dua', 'tugas', 'yang', 'seharusnya', 'kasih', 'pemberitahuan', 'ke', 'aku', '(jam', 'delapan', 'pagi', 'dan', 'jam', 'dua', 'siang),', 'tapi', 'nggak', 'ada', 'yang', 'kasih', 'tahu', 'aku.', 'barusan', 'aku', 'coba', 'buat', 'pemberitahuan', 'tes', 'buat', 'satu', 'menit', 'ke', 'depan', 'dan', 'semuanya', 'langsung', 'muncul.', 'aku', 'pake', 'pixel', 'tujuh', 'pro.']
# After stopword removal: nggak menerima pemberitahuan tugas-tugasku. tugas kasih pemberitahuan (jam delapan pagi jam siang), nggak kasih aku. barusan coba pemberitahuan tes menit langsung muncul. pake pixel tujuh pro.
# After stemming: nggak terima pemberitahuan tugas tugas kasih pemberitahuan jam delapan pagi jam siang nggak kasih aku barusan coba pemberitahuan tes menit langsung muncul pake pixel tujuh pro
# ------
# Original: Sederhana, ya, tetapi kehilangan semua fitur sederhana
# After replacing numbers: Sederhana, ya, tetapi kehilangan semua fitur sederhana
# After case transformation: sederhana, ya, tetapi kehilangan semua fitur sederhana
# After tokenization: ['sederhana,', 'ya,', 'tetapi', 'kehilangan', 'semua', 'fitur', 'sederhana']
# After stopword removal: sederhana, ya, kehilangan fitur sederhana
# After stemming: sederhana ya hilang fitur sederhana
# ------
# Original: yang terburuk
# After replacing numbers: yang terburuk
# After case transformation: yang terburuk
# After tokenization: ['yang', 'terburuk']
# After stopword removal: terburuk
# After stemming: buruk
# ------
# Original: Lebih sedikit fitur daripada Microsoftto do yang menambahkan fitur maksimal, google perlu lebih banyak perbaikan & memperbaiki bug.
# After replacing numbers: Lebih sedikit fitur daripada Microsoftto do yang menambahkan fitur maksimal, google perlu lebih banyak perbaikan & memperbaiki bug.
# After case transformation: lebih sedikit fitur daripada microsoftto do yang menambahkan fitur maksimal, google perlu lebih banyak perbaikan & memperbaiki bug.
# After tokenization: ['lebih', 'sedikit', 'fitur', 'daripada', 'microsoftto', 'do', 'yang', 'menambahkan', 'fitur', 'maksimal,', 'google', 'perlu', 'lebih', 'banyak', 'perbaikan', '&', 'memperbaiki', 'bug.']
# After stopword removal: fitur microsoftto do fitur maksimal, google perbaikan & memperbaiki bug.
# After stemming: fitur microsoftto do fitur maksimal google baik baik bug
# ------
# Original: gak butuh
# After replacing numbers: gak butuh
# After case transformation: gak butuh
# After tokenization: ['gak', 'butuh']
# After stopword removal: gak butuh
# After stemming: gak butuh
# ------
# Original: Pengingat dalam aplikasi Google Task sangat tidak konsisten. Seringkali tidak menerima notifikasi untuk tugas-tugas penting, jadi melewatkan banyak tenggat waktu
# After replacing numbers: Pengingat dalam aplikasi Google Task sangat tidak konsisten. Seringkali tidak menerima notifikasi untuk tugas-tugas penting, jadi melewatkan banyak tenggat waktu
# After case transformation: pengingat dalam aplikasi google task sangat tidak konsisten. seringkali tidak menerima notifikasi untuk tugas-tugas penting, jadi melewatkan banyak tenggat waktu
# After tokenization: ['pengingat', 'dalam', 'aplikasi', 'google', 'task', 'sangat', 'tidak', 'konsisten.', 'seringkali', 'tidak', 'menerima', 'notifikasi', 'untuk', 'tugas-tugas', 'penting,', 'jadi', 'melewatkan', 'banyak', 'tenggat', 'waktu']
# After stopword removal: pengingat aplikasi google task konsisten. seringkali menerima notifikasi tugas-tugas penting, melewatkan tenggat
# After stemming: ingat aplikasi google task konsisten seringkali terima notifikasi tugas penting lewat tenggat
# ------
# Original: Aplikasi mengecewakan. sering tidak mendapat pemberitahuan untuk tugas yang telah diatur, membuatnya tidak berguna sebagai alat pengingat.
# After replacing numbers: Aplikasi mengecewakan. sering tidak mendapat pemberitahuan untuk tugas yang telah diatur, membuatnya tidak berguna sebagai alat pengingat.
# After case transformation: aplikasi mengecewakan. sering tidak mendapat pemberitahuan untuk tugas yang telah diatur, membuatnya tidak berguna sebagai alat pengingat.
# After tokenization: ['aplikasi', 'mengecewakan.', 'sering', 'tidak', 'mendapat', 'pemberitahuan', 'untuk', 'tugas', 'yang', 'telah', 'diatur,', 'membuatnya', 'tidak', 'berguna', 'sebagai', 'alat', 'pengingat.']
# After stopword removal: aplikasi mengecewakan. pemberitahuan tugas diatur, membuatnya berguna alat pengingat.
# After stemming: aplikasi kecewa pemberitahuan tugas atur buat guna alat ingat
# ------
#    score                                            content    label
# 0      5  aplikasi bagus centang tugas tambah fitur nama...  POSITIF
# 1      5                                       bagus google  POSITIF
# 2      5                            terimakasih akun simpan  POSITIF
# 3      5      coba produktif karya bantu aplikasi manajemen  POSITIF
# 4      5                                            manfaat  POSITIF

# %%
import pandas as pd
import re

# Membuat mapping angka ke kata dalam bahasa Indonesia
angka_to_kata = {
    '0': 'nol', '1': 'satu', '2': 'dua', '3': 'tiga', '4': 'empat',
    '5': 'lima', '6': 'enam', '7': 'tujuh', '8': 'delapan', '9': 'sembilan'
}

# Fungsi untuk mengganti angka dengan kata
def ganti_angka_dengan_kata(teks):
    def replace(match):
        return angka_to_kata[match.group(0)]
    return re.sub(r'\d', replace, teks)

# Membaca file excel
df = pd.read_excel('dataset-GTask-after-preprocess.xlsx')

# Pastikan semua nilai di kolom 'content' adalah string dan tangani nilai NaN
df['content'] = df['content'].astype(str).fillna('')

# Mengganti angka dengan kata di kolom 'content'
df['content'] = df['content'].apply(ganti_angka_dengan_kata)

# Menyimpan kembali ke file excel atau menampilkan hasil
df.to_excel('fix-dataset-GTask-after-preprocess.xlsx', index=False)
print(df.head())
# Out:
#    score                                            content    label
# 0      5  aplikasi bagus centang tugas tambah fitur nama...  POSITIF
# 1      5                                       bagus google  POSITIF
# 2      5                            terimakasih akun simpan  POSITIF
# 3      5      coba produktif karya bantu aplikasi manajemen  POSITIF
# 4      5                                            manfaat  POSITIF
