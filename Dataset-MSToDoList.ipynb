# %%
import pandas as pd
from textblob import TextBlob
import inflect
import nltk
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from nltk.corpus import stopwords
import re

# Download stopwords untuk nltk
nltk.download('stopwords')

# Inisialisasi inflect engine untuk konversi angka ke kata
p = inflect.engine()

# Inisialisasi stemmer Bahasa Indonesia dari Sastrawi
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# Mengambil daftar stopwords bahasa Indonesia
stop_words = set(stopwords.words('indonesian'))

# Fungsi untuk memperbaiki typo
# def perbaiki_typo(teks):
#     blob = TextBlob(teks)
#     return str(blob.correct())

angka_to_kata = {
    '0': 'nol', '1': 'satu', '2': 'dua', '3': 'tiga', '4': 'empat',
    '5': 'lima', '6': 'enam', '7': 'tujuh', '8': 'delapan', '9': 'sembilan'
}

# Fungsi untuk mengganti angka dengan kata
def ganti_angka_dengan_kata(teks):
    def replace(match):
        return angka_to_kata[match.group(0)]
    return re.sub(r'\d', replace, teks)

# Fungsi untuk tokenisasi
def tokenize(teks):
    return teks.split()

# Fungsi untuk transformasi kasus (menjadi huruf kecil)
def transform_case(teks):
    return teks.lower()

# Fungsi untuk menghapus stopwords
def hapus_stopwords(teks):
    tokens = teks.split()
    tokens = [word for word in tokens if word not in stop_words]
    return ' '.join(tokens)

# Fungsi untuk stemming
def stem_text(teks):
    return stemmer.stem(teks)

# Membaca file excel
df = pd.read_excel('./Dataset-MSToDoList.xlsx')

# Proses preprocessing dengan cetakan proses
for index, row in df.iterrows():
    print(f"Original: {row['content']}")

#     row['content'] = perbaiki_typo(row['content'])
#     print(f"After typo correction: {row['content']}")

    row['content'] = ganti_angka_dengan_kata(row['content'])
    print(f"After replacing numbers: {row['content']}")

    row['content'] = transform_case(row['content'])
    print(f"After case transformation: {row['content']}")

    tokens = tokenize(row['content'])
    print(f"After tokenization: {tokens}")

    row['content'] = ' '.join(tokens)
    row['content'] = hapus_stopwords(row['content'])
    print(f"After stopword removal: {row['content']}")

    row['content'] = stem_text(row['content'])
    print(f"After stemming: {row['content']}")

    # Update the dataframe with processed content
    df.at[index, 'content'] = row['content']
    print("------")

# Menyimpan kembali ke file excel atau menampilkan hasil
df.to_excel('Dataset-MSToDoList-after-preprocess.xlsx', index=False)
print(df.head())
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Original: lebih baik dari yang lain
# After replacing numbers: lebih baik dari yang lain
# After case transformation: lebih baik dari yang lain
# After tokenization: ['lebih', 'baik', 'dari', 'yang', 'lain']
# After stopword removal:
# After stemming:
# ------
# Original: Sangat membantu dalam mengingat tugas-tugas saya yang belum dikerjakan!
# After replacing numbers: Sangat membantu dalam mengingat tugas-tugas saya yang belum dikerjakan!
# After case transformation: sangat membantu dalam mengingat tugas-tugas saya yang belum dikerjakan!
# After tokenization: ['sangat', 'membantu', 'dalam', 'mengingat', 'tugas-tugas', 'saya', 'yang', 'belum', 'dikerjakan!']
# After stopword removal: membantu tugas-tugas dikerjakan!
# After stemming: bantu tugas kerja
# ------
# Original: sangat membantu pekerjaan saya.Terimakasih
# After replacing numbers: sangat membantu pekerjaan saya.Terimakasih
# After case transformation: sangat membantu pekerjaan saya.terimakasih
# After tokenization: ['sangat', 'membantu', 'pekerjaan', 'saya.terimakasih']
# After stopword removal: membantu pekerjaan saya.terimakasih
# After stemming: bantu kerja saya terimakasih
# ------
# Original: sudah 2bulanan pakai ini dan menikmatinya
# After replacing numbers: sudah duabulanan pakai ini dan menikmatinya
# After case transformation: sudah duabulanan pakai ini dan menikmatinya
# After tokenization: ['sudah', 'duabulanan', 'pakai', 'ini', 'dan', 'menikmatinya']
# After stopword removal: duabulanan pakai menikmatinya
# After stemming: duabulanan pakai nikmat
# ------
# Original: sangat bermanfaat dengan sinkromisasi di laptop
# After replacing numbers: sangat bermanfaat dengan sinkromisasi di laptop
# After case transformation: sangat bermanfaat dengan sinkromisasi di laptop
# After tokenization: ['sangat', 'bermanfaat', 'dengan', 'sinkromisasi', 'di', 'laptop']
# After stopword removal: bermanfaat sinkromisasi laptop
# After stemming: manfaat sinkromisasi laptop
# ------
# Original: simple namun sangat bermanfaat.
# After replacing numbers: simple namun sangat bermanfaat.
# After case transformation: simple namun sangat bermanfaat.
# After tokenization: ['simple', 'namun', 'sangat', 'bermanfaat.']
# After stopword removal: simple bermanfaat.
# After stemming: simple manfaat
# ------
# Original: Selalu tetap terhubung dengan jaringan grup privat saya ini dengan hasil sangat rahasia dan semakin aman terpercaya dan lebih memuaskan.
# After replacing numbers: Selalu tetap terhubung dengan jaringan grup privat saya ini dengan hasil sangat rahasia dan semakin aman terpercaya dan lebih memuaskan.
# After case transformation: selalu tetap terhubung dengan jaringan grup privat saya ini dengan hasil sangat rahasia dan semakin aman terpercaya dan lebih memuaskan.
# After tokenization: ['selalu', 'tetap', 'terhubung', 'dengan', 'jaringan', 'grup', 'privat', 'saya', 'ini', 'dengan', 'hasil', 'sangat', 'rahasia', 'dan', 'semakin', 'aman', 'terpercaya', 'dan', 'lebih', 'memuaskan.']
# After stopword removal: terhubung jaringan grup privat hasil rahasia aman terpercaya memuaskan.
# After stemming: hubung jaring grup privat hasil rahasia aman percaya muas
# ------
# Original: to do bagus banget sih buat jadwalin tugas biar gak keteteran, bagusnya lagi bisa terhubung ke laptop
# After replacing numbers: to do bagus banget sih buat jadwalin tugas biar gak keteteran, bagusnya lagi bisa terhubung ke laptop
# After case transformation: to do bagus banget sih buat jadwalin tugas biar gak keteteran, bagusnya lagi bisa terhubung ke laptop
# After tokenization: ['to', 'do', 'bagus', 'banget', 'sih', 'buat', 'jadwalin', 'tugas', 'biar', 'gak', 'keteteran,', 'bagusnya', 'lagi', 'bisa', 'terhubung', 'ke', 'laptop']
# After stopword removal: to do bagus banget sih jadwalin tugas biar gak keteteran, bagusnya terhubung laptop
# After stemming: to do bagus banget sih jadwalin tugas biar gak keteter bagus hubung laptop
# ------
# Original: aplikasi sebagus ini... baru tau
# After replacing numbers: aplikasi sebagus ini... baru tau
# After case transformation: aplikasi sebagus ini... baru tau
# After tokenization: ['aplikasi', 'sebagus', 'ini...', 'baru', 'tau']
# After stopword removal: aplikasi sebagus ini... tau
# After stemming: aplikasi bagus ini tau
# ------
# Original: Sangat membantu agar bisa lebih produktif setiap hari. Semoga bisa terus berbenah jadi lebih baik lagi
# After replacing numbers: Sangat membantu agar bisa lebih produktif setiap hari. Semoga bisa terus berbenah jadi lebih baik lagi
# After case transformation: sangat membantu agar bisa lebih produktif setiap hari. semoga bisa terus berbenah jadi lebih baik lagi
# After tokenization: ['sangat', 'membantu', 'agar', 'bisa', 'lebih', 'produktif', 'setiap', 'hari.', 'semoga', 'bisa', 'terus', 'berbenah', 'jadi', 'lebih', 'baik', 'lagi']
# After stopword removal: membantu produktif hari. semoga berbenah
# After stemming: bantu produktif hari moga benah
# ------
# Original: Setelah mencoba dari sekian banyak aplikasi To Do List, ini sih yang paling pas.
# After replacing numbers: Setelah mencoba dari sekian banyak aplikasi To Do List, ini sih yang paling pas.
# After case transformation: setelah mencoba dari sekian banyak aplikasi to do list, ini sih yang paling pas.
# After tokenization: ['setelah', 'mencoba', 'dari', 'sekian', 'banyak', 'aplikasi', 'to', 'do', 'list,', 'ini', 'sih', 'yang', 'paling', 'pas.']
# After stopword removal: mencoba sekian aplikasi to do list, sih pas.
# After stemming: coba sekian aplikasi to do list sih pas
# ------
# Original: sangat membantu, saran saya tambahkan checklist di dalam checklist :'D
# After replacing numbers: sangat membantu, saran saya tambahkan checklist di dalam checklist :'D
# After case transformation: sangat membantu, saran saya tambahkan checklist di dalam checklist :'d
# After tokenization: ['sangat', 'membantu,', 'saran', 'saya', 'tambahkan', 'checklist', 'di', 'dalam', 'checklist', ":'d"]
# After stopword removal: membantu, saran tambahkan checklist checklist :'d
# After stemming: bantu saran tambah checklist checklist d
# ------
# Original: Sangat membantu dalam menetapkan skala prioritas pekerjaan dan mengingatkan to do list yang akan dikerjakan.
# After replacing numbers: Sangat membantu dalam menetapkan skala prioritas pekerjaan dan mengingatkan to do list yang akan dikerjakan.
# After case transformation: sangat membantu dalam menetapkan skala prioritas pekerjaan dan mengingatkan to do list yang akan dikerjakan.
# After tokenization: ['sangat', 'membantu', 'dalam', 'menetapkan', 'skala', 'prioritas', 'pekerjaan', 'dan', 'mengingatkan', 'to', 'do', 'list', 'yang', 'akan', 'dikerjakan.']
# After stopword removal: membantu menetapkan skala prioritas pekerjaan to do list dikerjakan.
# After stemming: bantu tetap skala prioritas kerja to do list kerja
# ------
# Original: sangat membantu, sesuai dengan yang saya butuhkan
# After replacing numbers: sangat membantu, sesuai dengan yang saya butuhkan
# After case transformation: sangat membantu, sesuai dengan yang saya butuhkan
# After tokenization: ['sangat', 'membantu,', 'sesuai', 'dengan', 'yang', 'saya', 'butuhkan']
# After stopword removal: membantu, sesuai butuhkan
# After stemming: bantu sesuai butuh
# ------
# Original: Aplikasi ini sangat membantu dalam action plan pekerja
# After replacing numbers: Aplikasi ini sangat membantu dalam action plan pekerja
# After case transformation: aplikasi ini sangat membantu dalam action plan pekerja
# After tokenization: ['aplikasi', 'ini', 'sangat', 'membantu', 'dalam', 'action', 'plan', 'pekerja']
# After stopword removal: aplikasi membantu action plan pekerja
# After stemming: aplikasi bantu action plan kerja
# ------
# Original: harus login dulu untuk menggunakan apk, tidak bagus untuk yang tidak ada internet
# After replacing numbers: harus login dulu untuk menggunakan apk, tidak bagus untuk yang tidak ada internet
# After case transformation: harus login dulu untuk menggunakan apk, tidak bagus untuk yang tidak ada internet
# After tokenization: ['harus', 'login', 'dulu', 'untuk', 'menggunakan', 'apk,', 'tidak', 'bagus', 'untuk', 'yang', 'tidak', 'ada', 'internet']
# After stopword removal: login apk, bagus internet
# After stemming: login apk bagus internet
# ------
# Original: aplikasinya sudah sangat bagus, mungkin haruskah menambahkan fitur yang lebih bermanfaat, dan menambahkan lebih banyak animasi untuk memberikan vibes yang bagus?
# After replacing numbers: aplikasinya sudah sangat bagus, mungkin haruskah menambahkan fitur yang lebih bermanfaat, dan menambahkan lebih banyak animasi untuk memberikan vibes yang bagus?
# After case transformation: aplikasinya sudah sangat bagus, mungkin haruskah menambahkan fitur yang lebih bermanfaat, dan menambahkan lebih banyak animasi untuk memberikan vibes yang bagus?
# After tokenization: ['aplikasinya', 'sudah', 'sangat', 'bagus,', 'mungkin', 'haruskah', 'menambahkan', 'fitur', 'yang', 'lebih', 'bermanfaat,', 'dan', 'menambahkan', 'lebih', 'banyak', 'animasi', 'untuk', 'memberikan', 'vibes', 'yang', 'bagus?']
# After stopword removal: aplikasinya bagus, haruskah fitur bermanfaat, animasi vibes bagus?
# After stemming: aplikasi bagus harus fitur manfaat animasi vibes bagus
# ------
# Original: Secara dasarnya, aplikasi ini sangat cocok bagi saya, mulai dari antarmuka, efektivitas, dan desain sederhananya yang membuat saya senang secara keseluruhan.
# After replacing numbers: Secara dasarnya, aplikasi ini sangat cocok bagi saya, mulai dari antarmuka, efektivitas, dan desain sederhananya yang membuat saya senang secara keseluruhan.
# After case transformation: secara dasarnya, aplikasi ini sangat cocok bagi saya, mulai dari antarmuka, efektivitas, dan desain sederhananya yang membuat saya senang secara keseluruhan.
# After tokenization: ['secara', 'dasarnya,', 'aplikasi', 'ini', 'sangat', 'cocok', 'bagi', 'saya,', 'mulai', 'dari', 'antarmuka,', 'efektivitas,', 'dan', 'desain', 'sederhananya', 'yang', 'membuat', 'saya', 'senang', 'secara', 'keseluruhan.']
# After stopword removal: dasarnya, aplikasi cocok saya, antarmuka, efektivitas, desain sederhananya senang keseluruhan.
# After stemming: dasar aplikasi cocok saya antarmuka efektivitas desain sederhana senang seluruh
# ------
# Original: sangat membantu untuk mengorganisir pekerjaan, TOP
# After replacing numbers: sangat membantu untuk mengorganisir pekerjaan, TOP
# After case transformation: sangat membantu untuk mengorganisir pekerjaan, top
# After tokenization: ['sangat', 'membantu', 'untuk', 'mengorganisir', 'pekerjaan,', 'top']
# After stopword removal: membantu mengorganisir pekerjaan, top
# After stemming: bantu organisir kerja top
# ------
# Original: Bermanfaat bagi saya yang sering lalai
# After replacing numbers: Bermanfaat bagi saya yang sering lalai
# After case transformation: bermanfaat bagi saya yang sering lalai
# After tokenization: ['bermanfaat', 'bagi', 'saya', 'yang', 'sering', 'lalai']
# After stopword removal: bermanfaat lalai
# After stemming: manfaat lalai
# ------
# Original: sangat membantu saya dalam merencanakan sesuatu. biasanya saya menggunakan kertas, namun kertas sendiri akan menjadi sampah jika sudah terlewat dan tangan cenderung lebih pegal bila harus menulis manual apalagi jika plan yang dimiliki banyak. saran saya jika perlu fitur pengingat dibuat seperti alarm. karena sering sekali hanya ada di bar notif tanpa saya ketahui suaranya disaat suasana ramai
# After replacing numbers: sangat membantu saya dalam merencanakan sesuatu. biasanya saya menggunakan kertas, namun kertas sendiri akan menjadi sampah jika sudah terlewat dan tangan cenderung lebih pegal bila harus menulis manual apalagi jika plan yang dimiliki banyak. saran saya jika perlu fitur pengingat dibuat seperti alarm. karena sering sekali hanya ada di bar notif tanpa saya ketahui suaranya disaat suasana ramai
# After case transformation: sangat membantu saya dalam merencanakan sesuatu. biasanya saya menggunakan kertas, namun kertas sendiri akan menjadi sampah jika sudah terlewat dan tangan cenderung lebih pegal bila harus menulis manual apalagi jika plan yang dimiliki banyak. saran saya jika perlu fitur pengingat dibuat seperti alarm. karena sering sekali hanya ada di bar notif tanpa saya ketahui suaranya disaat suasana ramai
# After tokenization: ['sangat', 'membantu', 'saya', 'dalam', 'merencanakan', 'sesuatu.', 'biasanya', 'saya', 'menggunakan', 'kertas,', 'namun', 'kertas', 'sendiri', 'akan', 'menjadi', 'sampah', 'jika', 'sudah', 'terlewat', 'dan', 'tangan', 'cenderung', 'lebih', 'pegal', 'bila', 'harus', 'menulis', 'manual', 'apalagi', 'jika', 'plan', 'yang', 'dimiliki', 'banyak.', 'saran', 'saya', 'jika', 'perlu', 'fitur', 'pengingat', 'dibuat', 'seperti', 'alarm.', 'karena', 'sering', 'sekali', 'hanya', 'ada', 'di', 'bar', 'notif', 'tanpa', 'saya', 'ketahui', 'suaranya', 'disaat', 'suasana', 'ramai']
# After stopword removal: membantu merencanakan sesuatu. kertas, kertas sampah terlewat tangan cenderung pegal menulis manual plan dimiliki banyak. saran fitur pengingat alarm. bar notif ketahui suaranya disaat suasana ramai
# After stemming: bantu rencana sesuatu kertas kertas sampah lewat tangan cenderung pegal tulis manual plan milik banyak saran fitur ingat alarm bar notif tahu suara saat suasana ramai
# ------
# Original: Bagus dan bermanfaat
# After replacing numbers: Bagus dan bermanfaat
# After case transformation: bagus dan bermanfaat
# After tokenization: ['bagus', 'dan', 'bermanfaat']
# After stopword removal: bagus bermanfaat
# After stemming: bagus manfaat
# ------
# Original: membantu banget untuk pemula yang ingin terjun di dunia setelah SMA
# After replacing numbers: membantu banget untuk pemula yang ingin terjun di dunia setelah SMA
# After case transformation: membantu banget untuk pemula yang ingin terjun di dunia setelah sma
# After tokenization: ['membantu', 'banget', 'untuk', 'pemula', 'yang', 'ingin', 'terjun', 'di', 'dunia', 'setelah', 'sma']
# After stopword removal: membantu banget pemula terjun dunia sma
# After stemming: bantu banget mula terjun dunia sma
# ------
# Original: sangat membantu dan mudah di gunakan
# After replacing numbers: sangat membantu dan mudah di gunakan
# After case transformation: sangat membantu dan mudah di gunakan
# After tokenization: ['sangat', 'membantu', 'dan', 'mudah', 'di', 'gunakan']
# After stopword removal: membantu mudah
# After stemming: bantu mudah
# ------
# Original: sangat praktis dan efisien
# After replacing numbers: sangat praktis dan efisien
# After case transformation: sangat praktis dan efisien
# After tokenization: ['sangat', 'praktis', 'dan', 'efisien']
# After stopword removal: praktis efisien
# After stemming: praktis efisien
# ------
# Original: Bagus dan mudah
# After replacing numbers: Bagus dan mudah
# After case transformation: bagus dan mudah
# After tokenization: ['bagus', 'dan', 'mudah']
# After stopword removal: bagus mudah
# After stemming: bagus mudah
# ------
# Original: aplikasi ini sangat membantu untuk meningkatkan utilitas diri dan semoga semakin lebih baik lagi kedepannya. thanks Microsoft Teams !! :)
# After replacing numbers: aplikasi ini sangat membantu untuk meningkatkan utilitas diri dan semoga semakin lebih baik lagi kedepannya. thanks Microsoft Teams !! :)
# After case transformation: aplikasi ini sangat membantu untuk meningkatkan utilitas diri dan semoga semakin lebih baik lagi kedepannya. thanks microsoft teams !! :)
# After tokenization: ['aplikasi', 'ini', 'sangat', 'membantu', 'untuk', 'meningkatkan', 'utilitas', 'diri', 'dan', 'semoga', 'semakin', 'lebih', 'baik', 'lagi', 'kedepannya.', 'thanks', 'microsoft', 'teams', '!!', ':)']
# After stopword removal: aplikasi membantu meningkatkan utilitas semoga kedepannya. thanks microsoft teams !! :)
# After stemming: aplikasi bantu tingkat utilitas moga depan thanks microsoft teams
# ------
# Original: Sangat berguna, bagi nusa dan bangsa
# After replacing numbers: Sangat berguna, bagi nusa dan bangsa
# After case transformation: sangat berguna, bagi nusa dan bangsa
# After tokenization: ['sangat', 'berguna,', 'bagi', 'nusa', 'dan', 'bangsa']
# After stopword removal: berguna, nusa bangsa
# After stemming: guna nusa bangsa
# ------
# Original: Aplikasi ini ringan, kuat, dan saya harap ini menjadi peningkat produktivitas saya.
# After replacing numbers: Aplikasi ini ringan, kuat, dan saya harap ini menjadi peningkat produktivitas saya.
# After case transformation: aplikasi ini ringan, kuat, dan saya harap ini menjadi peningkat produktivitas saya.
# After tokenization: ['aplikasi', 'ini', 'ringan,', 'kuat,', 'dan', 'saya', 'harap', 'ini', 'menjadi', 'peningkat', 'produktivitas', 'saya.']
# After stopword removal: aplikasi ringan, kuat, harap peningkat produktivitas saya.
# After stemming: aplikasi ringan kuat harap tingkat produktivitas saya
# ------
# Original: Aku suka, semoga semakin kekinian dan minimalis tampilannya.
# After replacing numbers: Aku suka, semoga semakin kekinian dan minimalis tampilannya.
# After case transformation: aku suka, semoga semakin kekinian dan minimalis tampilannya.
# After tokenization: ['aku', 'suka,', 'semoga', 'semakin', 'kekinian', 'dan', 'minimalis', 'tampilannya.']
# After stopword removal: suka, semoga kekinian minimalis tampilannya.
# After stemming: suka moga kini minimal tampil
# ------
# Original: Sangat membantu mengingat
# After replacing numbers: Sangat membantu mengingat
# After case transformation: sangat membantu mengingat
# After tokenization: ['sangat', 'membantu', 'mengingat']
# After stopword removal: membantu
# After stemming: bantu
# ------
# Original: Secara keseluruhan, aplikasi ini sangat bagus dan membantu saya untuk meningkatkan produktivitas. Terimakasih :)
# After replacing numbers: Secara keseluruhan, aplikasi ini sangat bagus dan membantu saya untuk meningkatkan produktivitas. Terimakasih :)
# After case transformation: secara keseluruhan, aplikasi ini sangat bagus dan membantu saya untuk meningkatkan produktivitas. terimakasih :)
# After tokenization: ['secara', 'keseluruhan,', 'aplikasi', 'ini', 'sangat', 'bagus', 'dan', 'membantu', 'saya', 'untuk', 'meningkatkan', 'produktivitas.', 'terimakasih', ':)']
# After stopword removal: keseluruhan, aplikasi bagus membantu meningkatkan produktivitas. terimakasih :)
# After stemming: seluruh aplikasi bagus bantu tingkat produktivitas terimakasih
# ------
# Original: Saya sangat tertarik menggunakan aplikasi ini. Semoga membantu saya dalam melakukan banyak hal.
# After replacing numbers: Saya sangat tertarik menggunakan aplikasi ini. Semoga membantu saya dalam melakukan banyak hal.
# After case transformation: saya sangat tertarik menggunakan aplikasi ini. semoga membantu saya dalam melakukan banyak hal.
# After tokenization: ['saya', 'sangat', 'tertarik', 'menggunakan', 'aplikasi', 'ini.', 'semoga', 'membantu', 'saya', 'dalam', 'melakukan', 'banyak', 'hal.']
# After stopword removal: tertarik aplikasi ini. semoga membantu hal.
# After stemming: tarik aplikasi ini moga bantu hal
# ------
# Original: Membantu membuat list kerjaan
# After replacing numbers: Membantu membuat list kerjaan
# After case transformation: membantu membuat list kerjaan
# After tokenization: ['membantu', 'membuat', 'list', 'kerjaan']
# After stopword removal: membantu list kerjaan
# After stemming: bantu list kerja
# ------
# Original: membantu pol, saran untuk task yang bertumpuk kalau mini task sudah dicentang harusnya task sudah clear
# After replacing numbers: membantu pol, saran untuk task yang bertumpuk kalau mini task sudah dicentang harusnya task sudah clear
# After case transformation: membantu pol, saran untuk task yang bertumpuk kalau mini task sudah dicentang harusnya task sudah clear
# After tokenization: ['membantu', 'pol,', 'saran', 'untuk', 'task', 'yang', 'bertumpuk', 'kalau', 'mini', 'task', 'sudah', 'dicentang', 'harusnya', 'task', 'sudah', 'clear']
# After stopword removal: membantu pol, saran task bertumpuk mini task dicentang task clear
# After stemming: bantu pol saran task tumpuk mini task centang task clear
# ------
# Original: aplikasi yang sangat bagus...mendukung pekerjaan.
# After replacing numbers: aplikasi yang sangat bagus...mendukung pekerjaan.
# After case transformation: aplikasi yang sangat bagus...mendukung pekerjaan.
# After tokenization: ['aplikasi', 'yang', 'sangat', 'bagus...mendukung', 'pekerjaan.']
# After stopword removal: aplikasi bagus...mendukung pekerjaan.
# After stemming: aplikasi bagus dukung kerja
# ------
# Original: baik, mudah penggunaannya
# After replacing numbers: baik, mudah penggunaannya
# After case transformation: baik, mudah penggunaannya
# After tokenization: ['baik,', 'mudah', 'penggunaannya']
# After stopword removal: baik, mudah penggunaannya
# After stemming: baik mudah guna
# ------
# Original: Aplikasinya keren, sangat membantu sekali dalam mengelola tugas
# After replacing numbers: Aplikasinya keren, sangat membantu sekali dalam mengelola tugas
# After case transformation: aplikasinya keren, sangat membantu sekali dalam mengelola tugas
# After tokenization: ['aplikasinya', 'keren,', 'sangat', 'membantu', 'sekali', 'dalam', 'mengelola', 'tugas']
# After stopword removal: aplikasinya keren, membantu mengelola tugas
# After stemming: aplikasi keren bantu kelola tugas
# ------
# Original: simple dan bagus
# After replacing numbers: simple dan bagus
# After case transformation: simple dan bagus
# After tokenization: ['simple', 'dan', 'bagus']
# After stopword removal: simple bagus
# After stemming: simple bagus
# ------
# Original: simple tapi sangat efisien dan berguna
# After replacing numbers: simple tapi sangat efisien dan berguna
# After case transformation: simple tapi sangat efisien dan berguna
# After tokenization: ['simple', 'tapi', 'sangat', 'efisien', 'dan', 'berguna']
# After stopword removal: simple efisien berguna
# After stemming: simple efisien guna
# ------
# Original: Bagus untuk catat Kegiatan
# After replacing numbers: Bagus untuk catat Kegiatan
# After case transformation: bagus untuk catat kegiatan
# After tokenization: ['bagus', 'untuk', 'catat', 'kegiatan']
# After stopword removal: bagus catat kegiatan
# After stemming: bagus catat giat
# ------
# Original: Aplikasi ringkas dan simpel untuk atur rencana dan tugas dan opsi yang mudah untuk pilihan tugas prioritas dan tugas yang sudah selesai
# After replacing numbers: Aplikasi ringkas dan simpel untuk atur rencana dan tugas dan opsi yang mudah untuk pilihan tugas prioritas dan tugas yang sudah selesai
# After case transformation: aplikasi ringkas dan simpel untuk atur rencana dan tugas dan opsi yang mudah untuk pilihan tugas prioritas dan tugas yang sudah selesai
# After tokenization: ['aplikasi', 'ringkas', 'dan', 'simpel', 'untuk', 'atur', 'rencana', 'dan', 'tugas', 'dan', 'opsi', 'yang', 'mudah', 'untuk', 'pilihan', 'tugas', 'prioritas', 'dan', 'tugas', 'yang', 'sudah', 'selesai']
# After stopword removal: aplikasi ringkas simpel atur rencana tugas opsi mudah pilihan tugas prioritas tugas selesai
# After stemming: aplikasi ringkas simpel atur rencana tugas opsi mudah pilih tugas prioritas tugas selesai
# ------
# Original: Aplikasi yang sangat berguna buat pribadi yang ingin menjaga fokus dlm pencapaian...
# After replacing numbers: Aplikasi yang sangat berguna buat pribadi yang ingin menjaga fokus dlm pencapaian...
# After case transformation: aplikasi yang sangat berguna buat pribadi yang ingin menjaga fokus dlm pencapaian...
# After tokenization: ['aplikasi', 'yang', 'sangat', 'berguna', 'buat', 'pribadi', 'yang', 'ingin', 'menjaga', 'fokus', 'dlm', 'pencapaian...']
# After stopword removal: aplikasi berguna pribadi menjaga fokus dlm pencapaian...
# After stemming: aplikasi guna pribadi jaga fokus dlm capai
# ------
# Original: Sangat membantu kerja saya, tingkat kan terus, terimakasih
# After replacing numbers: Sangat membantu kerja saya, tingkat kan terus, terimakasih
# After case transformation: sangat membantu kerja saya, tingkat kan terus, terimakasih
# After tokenization: ['sangat', 'membantu', 'kerja', 'saya,', 'tingkat', 'kan', 'terus,', 'terimakasih']
# After stopword removal: membantu kerja saya, tingkat terus, terimakasih
# After stemming: bantu kerja saya tingkat terus terimakasih
# ------
# Original: Praktis dan simpel
# After replacing numbers: Praktis dan simpel
# After case transformation: praktis dan simpel
# After tokenization: ['praktis', 'dan', 'simpel']
# After stopword removal: praktis simpel
# After stemming: praktis simpel
# ------
# Original: nyaman banget buat bikin list to do ataupun mengisi tanggal acara, lebih baik dari google calender sih
# After replacing numbers: nyaman banget buat bikin list to do ataupun mengisi tanggal acara, lebih baik dari google calender sih
# After case transformation: nyaman banget buat bikin list to do ataupun mengisi tanggal acara, lebih baik dari google calender sih
# After tokenization: ['nyaman', 'banget', 'buat', 'bikin', 'list', 'to', 'do', 'ataupun', 'mengisi', 'tanggal', 'acara,', 'lebih', 'baik', 'dari', 'google', 'calender', 'sih']
# After stopword removal: nyaman banget bikin list to do mengisi tanggal acara, google calender sih
# After stemming: nyaman banget bikin list to do isi tanggal acara google calender sih
# ------
# Original: Berguna untuk membantu inventarisasi tugas sehari hari.
# After replacing numbers: Berguna untuk membantu inventarisasi tugas sehari hari.
# After case transformation: berguna untuk membantu inventarisasi tugas sehari hari.
# After tokenization: ['berguna', 'untuk', 'membantu', 'inventarisasi', 'tugas', 'sehari', 'hari.']
# After stopword removal: berguna membantu inventarisasi tugas sehari hari.
# After stemming: guna bantu inventarisasi tugas hari hari
# ------
# Original: Saya sangat menikmati to do list ini
# After replacing numbers: Saya sangat menikmati to do list ini
# After case transformation: saya sangat menikmati to do list ini
# After tokenization: ['saya', 'sangat', 'menikmati', 'to', 'do', 'list', 'ini']
# After stopword removal: menikmati to do list
# After stemming: nikmat to do list
# ------
# Original: Membantu mengingatkan dalam segala aktifitas
# After replacing numbers: Membantu mengingatkan dalam segala aktifitas
# After case transformation: membantu mengingatkan dalam segala aktifitas
# After tokenization: ['membantu', 'mengingatkan', 'dalam', 'segala', 'aktifitas']
# After stopword removal: membantu aktifitas
# After stemming: bantu aktifitas
# ------
# Original: sangat membantu meringankan tugas otak untuk mengingat apa seharusnya dikerjakan, apa yang seharusnya diprioritaskan. sip. terimakasih. dan yang paling penting dari semua itu, aplikasi ini gratis. tanpa iklan. saya bosan iklan.
# After replacing numbers: sangat membantu meringankan tugas otak untuk mengingat apa seharusnya dikerjakan, apa yang seharusnya diprioritaskan. sip. terimakasih. dan yang paling penting dari semua itu, aplikasi ini gratis. tanpa iklan. saya bosan iklan.
# After case transformation: sangat membantu meringankan tugas otak untuk mengingat apa seharusnya dikerjakan, apa yang seharusnya diprioritaskan. sip. terimakasih. dan yang paling penting dari semua itu, aplikasi ini gratis. tanpa iklan. saya bosan iklan.
# After tokenization: ['sangat', 'membantu', 'meringankan', 'tugas', 'otak', 'untuk', 'mengingat', 'apa', 'seharusnya', 'dikerjakan,', 'apa', 'yang', 'seharusnya', 'diprioritaskan.', 'sip.', 'terimakasih.', 'dan', 'yang', 'paling', 'penting', 'dari', 'semua', 'itu,', 'aplikasi', 'ini', 'gratis.', 'tanpa', 'iklan.', 'saya', 'bosan', 'iklan.']
# After stopword removal: membantu meringankan tugas otak dikerjakan, diprioritaskan. sip. terimakasih. itu, aplikasi gratis. iklan. bosan iklan.
# After stemming: bantu ringan tugas otak kerja prioritas sip terimakasih itu aplikasi gratis iklan bosan iklan
# ------
# Original: Tampilan bagus, dan bisa terhubung dengan tim
# After replacing numbers: Tampilan bagus, dan bisa terhubung dengan tim
# After case transformation: tampilan bagus, dan bisa terhubung dengan tim
# After tokenization: ['tampilan', 'bagus,', 'dan', 'bisa', 'terhubung', 'dengan', 'tim']
# After stopword removal: tampilan bagus, terhubung tim
# After stemming: tampil bagus hubung tim
# ------
# Original: Saya menggunakan aplikasi ini di laptop dan lancar.
# After replacing numbers: Saya menggunakan aplikasi ini di laptop dan lancar.
# After case transformation: saya menggunakan aplikasi ini di laptop dan lancar.
# After tokenization: ['saya', 'menggunakan', 'aplikasi', 'ini', 'di', 'laptop', 'dan', 'lancar.']
# After stopword removal: aplikasi laptop lancar.
# After stemming: aplikasi laptop lancar
# ------
# Original: Aplikasi yang sangat membantu sekali bila kita mempunyai tugas yang direncanakan.
# After replacing numbers: Aplikasi yang sangat membantu sekali bila kita mempunyai tugas yang direncanakan.
# After case transformation: aplikasi yang sangat membantu sekali bila kita mempunyai tugas yang direncanakan.
# After tokenization: ['aplikasi', 'yang', 'sangat', 'membantu', 'sekali', 'bila', 'kita', 'mempunyai', 'tugas', 'yang', 'direncanakan.']
# After stopword removal: aplikasi membantu tugas direncanakan.
# After stemming: aplikasi bantu tugas rencana
# ------
# Original: Memudahkan kontrol untuk kerja tim
# After replacing numbers: Memudahkan kontrol untuk kerja tim
# After case transformation: memudahkan kontrol untuk kerja tim
# After tokenization: ['memudahkan', 'kontrol', 'untuk', 'kerja', 'tim']
# After stopword removal: memudahkan kontrol kerja tim
# After stemming: mudah kontrol kerja tim
# ------
# Original: Sangat membantu dengan adanya versi desktop dan mobile
# After replacing numbers: Sangat membantu dengan adanya versi desktop dan mobile
# After case transformation: sangat membantu dengan adanya versi desktop dan mobile
# After tokenization: ['sangat', 'membantu', 'dengan', 'adanya', 'versi', 'desktop', 'dan', 'mobile']
# After stopword removal: membantu versi desktop mobile
# After stemming: bantu versi desktop mobile
# ------
# Original: Sangat baik dan selalu updated terlindungi telusuran private server saya ini
# After replacing numbers: Sangat baik dan selalu updated terlindungi telusuran private server saya ini
# After case transformation: sangat baik dan selalu updated terlindungi telusuran private server saya ini
# After tokenization: ['sangat', 'baik', 'dan', 'selalu', 'updated', 'terlindungi', 'telusuran', 'private', 'server', 'saya', 'ini']
# After stopword removal: updated terlindungi telusuran private server
# After stemming: updated lindung telusur private server
# ------
# Original: suka banget, sangat rekomendasi
# After replacing numbers: suka banget, sangat rekomendasi
# After case transformation: suka banget, sangat rekomendasi
# After tokenization: ['suka', 'banget,', 'sangat', 'rekomendasi']
# After stopword removal: suka banget, rekomendasi
# After stemming: suka banget rekomendasi
# ------
# Original: aplikasi ini lebih efektif dan efisien
# After replacing numbers: aplikasi ini lebih efektif dan efisien
# After case transformation: aplikasi ini lebih efektif dan efisien
# After tokenization: ['aplikasi', 'ini', 'lebih', 'efektif', 'dan', 'efisien']
# After stopword removal: aplikasi efektif efisien
# After stemming: aplikasi efektif efisien
# ------
# Original: Bagus banget app nya buat yang tugasnya banyak seperti saya jadi tidak mudah lupa dan semangat buat ngerjain tugas biar bisa di ceklis list tugas yang sudah selesai.
# After replacing numbers: Bagus banget app nya buat yang tugasnya banyak seperti saya jadi tidak mudah lupa dan semangat buat ngerjain tugas biar bisa di ceklis list tugas yang sudah selesai.
# After case transformation: bagus banget app nya buat yang tugasnya banyak seperti saya jadi tidak mudah lupa dan semangat buat ngerjain tugas biar bisa di ceklis list tugas yang sudah selesai.
# After tokenization: ['bagus', 'banget', 'app', 'nya', 'buat', 'yang', 'tugasnya', 'banyak', 'seperti', 'saya', 'jadi', 'tidak', 'mudah', 'lupa', 'dan', 'semangat', 'buat', 'ngerjain', 'tugas', 'biar', 'bisa', 'di', 'ceklis', 'list', 'tugas', 'yang', 'sudah', 'selesai.']
# After stopword removal: bagus banget app nya tugasnya mudah lupa semangat ngerjain tugas biar ceklis list tugas selesai.
# After stemming: bagus banget app nya tugas mudah lupa semangat ngerjain tugas biar ceklis list tugas selesai
# ------
# Original: aplikasi bagus, sangat membantu buat yang pelupa seperti saya\
# After replacing numbers: aplikasi bagus, sangat membantu buat yang pelupa seperti saya\
# After case transformation: aplikasi bagus, sangat membantu buat yang pelupa seperti saya\
# After tokenization: ['aplikasi', 'bagus,', 'sangat', 'membantu', 'buat', 'yang', 'pelupa', 'seperti', 'saya\\']
# After stopword removal: aplikasi bagus, membantu pelupa saya\
# After stemming: aplikasi bagus bantu lupa saya
# ------
# Original: Hebat, sangat berguna dan mudah digunakan untuk merencanakan dan mengontrol kegiatan tim.
# After replacing numbers: Hebat, sangat berguna dan mudah digunakan untuk merencanakan dan mengontrol kegiatan tim.
# After case transformation: hebat, sangat berguna dan mudah digunakan untuk merencanakan dan mengontrol kegiatan tim.
# After tokenization: ['hebat,', 'sangat', 'berguna', 'dan', 'mudah', 'digunakan', 'untuk', 'merencanakan', 'dan', 'mengontrol', 'kegiatan', 'tim.']
# After stopword removal: hebat, berguna mudah merencanakan mengontrol kegiatan tim.
# After stemming: hebat guna mudah rencana kontrol giat tim
# ------
# Original: Saya sangat suka dengan aplikasi ini, sangat sederhana. Saya harap Anda bisa menambahkan fitur untuk melihat tugas dalam tampilan bulanan atau tampilan mingguan. Juga, tolong tambahkan kalender.
# After replacing numbers: Saya sangat suka dengan aplikasi ini, sangat sederhana. Saya harap Anda bisa menambahkan fitur untuk melihat tugas dalam tampilan bulanan atau tampilan mingguan. Juga, tolong tambahkan kalender.
# After case transformation: saya sangat suka dengan aplikasi ini, sangat sederhana. saya harap anda bisa menambahkan fitur untuk melihat tugas dalam tampilan bulanan atau tampilan mingguan. juga, tolong tambahkan kalender.
# After tokenization: ['saya', 'sangat', 'suka', 'dengan', 'aplikasi', 'ini,', 'sangat', 'sederhana.', 'saya', 'harap', 'anda', 'bisa', 'menambahkan', 'fitur', 'untuk', 'melihat', 'tugas', 'dalam', 'tampilan', 'bulanan', 'atau', 'tampilan', 'mingguan.', 'juga,', 'tolong', 'tambahkan', 'kalender.']
# After stopword removal: suka aplikasi ini, sederhana. harap fitur tugas tampilan bulanan tampilan mingguan. juga, tolong tambahkan kalender.
# After stemming: suka aplikasi ini sederhana harap fitur tugas tampil bulan tampil minggu juga tolong tambah kalender
# ------
# Original: Luar biasa sangat membantu
# After replacing numbers: Luar biasa sangat membantu
# After case transformation: luar biasa sangat membantu
# After tokenization: ['luar', 'biasa', 'sangat', 'membantu']
# After stopword removal: membantu
# After stemming: bantu
# ------
# Original: Aplikasi tugas yang bisa share dengan akun lain, cocok untuk kerja team dan 1 lagi gratis tanpa iklan…
# After replacing numbers: Aplikasi tugas yang bisa share dengan akun lain, cocok untuk kerja team dan satu lagi gratis tanpa iklan…
# After case transformation: aplikasi tugas yang bisa share dengan akun lain, cocok untuk kerja team dan satu lagi gratis tanpa iklan…
# After tokenization: ['aplikasi', 'tugas', 'yang', 'bisa', 'share', 'dengan', 'akun', 'lain,', 'cocok', 'untuk', 'kerja', 'team', 'dan', 'satu', 'lagi', 'gratis', 'tanpa', 'iklan…']
# After stopword removal: aplikasi tugas share akun lain, cocok kerja team gratis iklan…
# After stemming: aplikasi tugas share akun lain cocok kerja team gratis iklan
# ------
# Original: Tampilan yang bagus dan tidak ribet, sangat membantu ... daftar tugas bisa sinkron app serupa di laptop ( Windows 10 ) ... sinkron pula dengan reminds samsung . Tugas ke myday juga gampang. Mungkin bisa di urutan lini masa sesuai waktu. Thanks
# After replacing numbers: Tampilan yang bagus dan tidak ribet, sangat membantu ... daftar tugas bisa sinkron app serupa di laptop ( Windows satunol ) ... sinkron pula dengan reminds samsung . Tugas ke myday juga gampang. Mungkin bisa di urutan lini masa sesuai waktu. Thanks
# After case transformation: tampilan yang bagus dan tidak ribet, sangat membantu ... daftar tugas bisa sinkron app serupa di laptop ( windows satunol ) ... sinkron pula dengan reminds samsung . tugas ke myday juga gampang. mungkin bisa di urutan lini masa sesuai waktu. thanks
# After tokenization: ['tampilan', 'yang', 'bagus', 'dan', 'tidak', 'ribet,', 'sangat', 'membantu', '...', 'daftar', 'tugas', 'bisa', 'sinkron', 'app', 'serupa', 'di', 'laptop', '(', 'windows', 'satunol', ')', '...', 'sinkron', 'pula', 'dengan', 'reminds', 'samsung', '.', 'tugas', 'ke', 'myday', 'juga', 'gampang.', 'mungkin', 'bisa', 'di', 'urutan', 'lini', 'masa', 'sesuai', 'waktu.', 'thanks']
# After stopword removal: tampilan bagus ribet, membantu ... daftar tugas sinkron app laptop ( windows satunol ) ... sinkron reminds samsung . tugas myday gampang. urutan lini sesuai waktu. thanks
# After stemming: tampil bagus ribet bantu daftar tugas sinkron app laptop windows satunol sinkron reminds samsung tugas myday gampang urut lini sesuai waktu thanks
# ------
# Original: Sangat recommended untuk task organisator
# After replacing numbers: Sangat recommended untuk task organisator
# After case transformation: sangat recommended untuk task organisator
# After tokenization: ['sangat', 'recommended', 'untuk', 'task', 'organisator']
# After stopword removal: recommended task organisator
# After stemming: recommended task organisator
# ------
# Original: Jadi lebih mudah untuk mengejar capaian
# After replacing numbers: Jadi lebih mudah untuk mengejar capaian
# After case transformation: jadi lebih mudah untuk mengejar capaian
# After tokenization: ['jadi', 'lebih', 'mudah', 'untuk', 'mengejar', 'capaian']
# After stopword removal: mudah mengejar capaian
# After stemming: mudah kejar capai
# ------
# Original: Sangat membantu saya untuk mengingat kemudian merangkai kegiatan yang bisa saya lakukan esok hari
# After replacing numbers: Sangat membantu saya untuk mengingat kemudian merangkai kegiatan yang bisa saya lakukan esok hari
# After case transformation: sangat membantu saya untuk mengingat kemudian merangkai kegiatan yang bisa saya lakukan esok hari
# After tokenization: ['sangat', 'membantu', 'saya', 'untuk', 'mengingat', 'kemudian', 'merangkai', 'kegiatan', 'yang', 'bisa', 'saya', 'lakukan', 'esok', 'hari']
# After stopword removal: membantu merangkai kegiatan lakukan esok
# After stemming: bantu rangkai giat laku esok
# ------
# Original: sangat membantu untuk bisnis
# After replacing numbers: sangat membantu untuk bisnis
# After case transformation: sangat membantu untuk bisnis
# After tokenization: ['sangat', 'membantu', 'untuk', 'bisnis']
# After stopword removal: membantu bisnis
# After stemming: bantu bisnis
# ------
# Original: Membantu sekali dalam mengatur kegiatan harian saya
# After replacing numbers: Membantu sekali dalam mengatur kegiatan harian saya
# After case transformation: membantu sekali dalam mengatur kegiatan harian saya
# After tokenization: ['membantu', 'sekali', 'dalam', 'mengatur', 'kegiatan', 'harian', 'saya']
# After stopword removal: membantu mengatur kegiatan harian
# After stemming: bantu atur giat hari
# ------
# Original: terimakasih microsoft! Aplikasinya sangat berguna, mudah digunakan dan minimalis. Sejauh ini tidak ada bug atau hal semacamnya. Aplikasi berjalan dengan lancar tanpa hambatan.
# After replacing numbers: terimakasih microsoft! Aplikasinya sangat berguna, mudah digunakan dan minimalis. Sejauh ini tidak ada bug atau hal semacamnya. Aplikasi berjalan dengan lancar tanpa hambatan.
# After case transformation: terimakasih microsoft! aplikasinya sangat berguna, mudah digunakan dan minimalis. sejauh ini tidak ada bug atau hal semacamnya. aplikasi berjalan dengan lancar tanpa hambatan.
# After tokenization: ['terimakasih', 'microsoft!', 'aplikasinya', 'sangat', 'berguna,', 'mudah', 'digunakan', 'dan', 'minimalis.', 'sejauh', 'ini', 'tidak', 'ada', 'bug', 'atau', 'hal', 'semacamnya.', 'aplikasi', 'berjalan', 'dengan', 'lancar', 'tanpa', 'hambatan.']
# After stopword removal: terimakasih microsoft! aplikasinya berguna, mudah minimalis. bug semacamnya. aplikasi berjalan lancar hambatan.
# After stemming: terimakasih microsoft aplikasi guna mudah minimal bug macam aplikasi jalan lancar hambat
# ------
# Original: Cinta banget sama aplikasi ini, jadi pendukung produktif
# After replacing numbers: Cinta banget sama aplikasi ini, jadi pendukung produktif
# After case transformation: cinta banget sama aplikasi ini, jadi pendukung produktif
# After tokenization: ['cinta', 'banget', 'sama', 'aplikasi', 'ini,', 'jadi', 'pendukung', 'produktif']
# After stopword removal: cinta banget aplikasi ini, pendukung produktif
# After stemming: cinta banget aplikasi ini dukung produktif
# ------
# Original: Aplikasi yang bermanfaat meskipun sederhana
# After replacing numbers: Aplikasi yang bermanfaat meskipun sederhana
# After case transformation: aplikasi yang bermanfaat meskipun sederhana
# After tokenization: ['aplikasi', 'yang', 'bermanfaat', 'meskipun', 'sederhana']
# After stopword removal: aplikasi bermanfaat sederhana
# After stemming: aplikasi manfaat sederhana
# ------
# Original: Membantu banget buat nge list kebutuhan saya
# After replacing numbers: Membantu banget buat nge list kebutuhan saya
# After case transformation: membantu banget buat nge list kebutuhan saya
# After tokenization: ['membantu', 'banget', 'buat', 'nge', 'list', 'kebutuhan', 'saya']
# After stopword removal: membantu banget nge list kebutuhan
# After stemming: bantu banget nge list butuh
# ------
# Original: Sangat bagus untuk mengatur tugas sehari-hari.
# After replacing numbers: Sangat bagus untuk mengatur tugas sehari-hari.
# After case transformation: sangat bagus untuk mengatur tugas sehari-hari.
# After tokenization: ['sangat', 'bagus', 'untuk', 'mengatur', 'tugas', 'sehari-hari.']
# After stopword removal: bagus mengatur tugas sehari-hari.
# After stemming: bagus atur tugas hari
# ------
# Original: Sangat membantu mengatur jadwal
# After replacing numbers: Sangat membantu mengatur jadwal
# After case transformation: sangat membantu mengatur jadwal
# After tokenization: ['sangat', 'membantu', 'mengatur', 'jadwal']
# After stopword removal: membantu mengatur jadwal
# After stemming: bantu atur jadwal
# ------
# Original: Sangat bagus, saya jadi produktif
# After replacing numbers: Sangat bagus, saya jadi produktif
# After case transformation: sangat bagus, saya jadi produktif
# After tokenization: ['sangat', 'bagus,', 'saya', 'jadi', 'produktif']
# After stopword removal: bagus, produktif
# After stemming: bagus produktif
# ------
# Original: Sangat membantu monitoring Proyek
# After replacing numbers: Sangat membantu monitoring Proyek
# After case transformation: sangat membantu monitoring proyek
# After tokenization: ['sangat', 'membantu', 'monitoring', 'proyek']
# After stopword removal: membantu monitoring proyek
# After stemming: bantu monitoring proyek
# ------
# Original: ini aplikasi terbagus yang pernah saya gunakan
# After replacing numbers: ini aplikasi terbagus yang pernah saya gunakan
# After case transformation: ini aplikasi terbagus yang pernah saya gunakan
# After tokenization: ['ini', 'aplikasi', 'terbagus', 'yang', 'pernah', 'saya', 'gunakan']
# After stopword removal: aplikasi terbagus
# After stemming: aplikasi bagus
# ------
# Original: Praktis, user friendly, komprehensif
# After replacing numbers: Praktis, user friendly, komprehensif
# After case transformation: praktis, user friendly, komprehensif
# After tokenization: ['praktis,', 'user', 'friendly,', 'komprehensif']
# After stopword removal: praktis, user friendly, komprehensif
# After stemming: praktis user friendly komprehensif
# ------
# Original: Keren banget, sangat memudahkan mengingat tugas
# After replacing numbers: Keren banget, sangat memudahkan mengingat tugas
# After case transformation: keren banget, sangat memudahkan mengingat tugas
# After tokenization: ['keren', 'banget,', 'sangat', 'memudahkan', 'mengingat', 'tugas']
# After stopword removal: keren banget, memudahkan tugas
# After stemming: keren banget mudah tugas
# ------
# Original: Terimakasih membantu pekerjaan
# After replacing numbers: Terimakasih membantu pekerjaan
# After case transformation: terimakasih membantu pekerjaan
# After tokenization: ['terimakasih', 'membantu', 'pekerjaan']
# After stopword removal: terimakasih membantu pekerjaan
# After stemming: terimakasih bantu kerja
# ------
# Original: Sangat bermanfaat terimakasih
# After replacing numbers: Sangat bermanfaat terimakasih
# After case transformation: sangat bermanfaat terimakasih
# After tokenization: ['sangat', 'bermanfaat', 'terimakasih']
# After stopword removal: bermanfaat terimakasih
# After stemming: manfaat terimakasih
# ------
# Original: Bagus tapi sayangnya nggak ada fitur diskripsi langkah biar nggak usah bikin title yang panjang
# After replacing numbers: Bagus tapi sayangnya nggak ada fitur diskripsi langkah biar nggak usah bikin title yang panjang
# After case transformation: bagus tapi sayangnya nggak ada fitur diskripsi langkah biar nggak usah bikin title yang panjang
# After tokenization: ['bagus', 'tapi', 'sayangnya', 'nggak', 'ada', 'fitur', 'diskripsi', 'langkah', 'biar', 'nggak', 'usah', 'bikin', 'title', 'yang', 'panjang']
# After stopword removal: bagus sayangnya nggak fitur diskripsi langkah biar nggak bikin title
# After stemming: bagus sayang nggak fitur skripsi langkah biar nggak bikin title
# ------
# Original: Aplikasi To do List terbaik mudah di gunakan banyak fiturnya dan bisa tampil di deskop widget
# After replacing numbers: Aplikasi To do List terbaik mudah di gunakan banyak fiturnya dan bisa tampil di deskop widget
# After case transformation: aplikasi to do list terbaik mudah di gunakan banyak fiturnya dan bisa tampil di deskop widget
# After tokenization: ['aplikasi', 'to', 'do', 'list', 'terbaik', 'mudah', 'di', 'gunakan', 'banyak', 'fiturnya', 'dan', 'bisa', 'tampil', 'di', 'deskop', 'widget']
# After stopword removal: aplikasi to do list terbaik mudah fiturnya tampil deskop widget
# After stemming: aplikasi to do list baik mudah fiturnya tampil deskop widget
# ------
# Original: Sangat membantu pekerjaan saya
# After replacing numbers: Sangat membantu pekerjaan saya
# After case transformation: sangat membantu pekerjaan saya
# After tokenization: ['sangat', 'membantu', 'pekerjaan', 'saya']
# After stopword removal: membantu pekerjaan
# After stemming: bantu kerja
# ------
# Original: Pertama pakai langsung terasa sangat membantu
# After replacing numbers: Pertama pakai langsung terasa sangat membantu
# After case transformation: pertama pakai langsung terasa sangat membantu
# After tokenization: ['pertama', 'pakai', 'langsung', 'terasa', 'sangat', 'membantu']
# After stopword removal: pakai langsung membantu
# After stemming: pakai langsung bantu
# ------
# Original: apl paling simpel, tampilan nya juga bagus, tidak ada iklan. good job
# After replacing numbers: apl paling simpel, tampilan nya juga bagus, tidak ada iklan. good job
# After case transformation: apl paling simpel, tampilan nya juga bagus, tidak ada iklan. good job
# After tokenization: ['apl', 'paling', 'simpel,', 'tampilan', 'nya', 'juga', 'bagus,', 'tidak', 'ada', 'iklan.', 'good', 'job']
# After stopword removal: apl simpel, tampilan nya bagus, iklan. good job
# After stemming: apl simpel tampil nya bagus iklan good job
# ------
# Original: Wajib punya bagi pekerja sibuk antara kantor & tugas dinas, Mempermudah list pekerjaan harian
# After replacing numbers: Wajib punya bagi pekerja sibuk antara kantor & tugas dinas, Mempermudah list pekerjaan harian
# After case transformation: wajib punya bagi pekerja sibuk antara kantor & tugas dinas, mempermudah list pekerjaan harian
# After tokenization: ['wajib', 'punya', 'bagi', 'pekerja', 'sibuk', 'antara', 'kantor', '&', 'tugas', 'dinas,', 'mempermudah', 'list', 'pekerjaan', 'harian']
# After stopword removal: wajib pekerja sibuk kantor & tugas dinas, mempermudah list pekerjaan harian
# After stemming: wajib kerja sibuk kantor tugas dinas mudah list kerja hari
# ------
# Original: Cukup bagus untuk pengaturan kinerja saya
# After replacing numbers: Cukup bagus untuk pengaturan kinerja saya
# After case transformation: cukup bagus untuk pengaturan kinerja saya
# After tokenization: ['cukup', 'bagus', 'untuk', 'pengaturan', 'kinerja', 'saya']
# After stopword removal: bagus pengaturan kinerja
# After stemming: bagus atur kerja
# ------
# Original: Mantap, disarankan agar temanya di perbanyak lagi
# After replacing numbers: Mantap, disarankan agar temanya di perbanyak lagi
# After case transformation: mantap, disarankan agar temanya di perbanyak lagi
# ...
# ------
# Original: gak ada ngasih tau notifikasi ke hp
# After replacing numbers: gak ada ngasih tau notifikasi ke hp
# After case transformation: gak ada ngasih tau notifikasi ke hp
# After tokenization: ['gak', 'ada', 'ngasih', 'tau', 'notifikasi', 'ke', 'hp']
# After stopword removal: gak ngasih tau notifikasi hp
# After stemming: gak ngasih tau notifikasi hp
# ------
# Original: Tidak mengingatkan sekali pun
# After replacing numbers: Tidak mengingatkan sekali pun
# After case transformation: tidak mengingatkan sekali pun
# After tokenization: ['tidak', 'mengingatkan', 'sekali', 'pun']
# After stopword removal:
# After stemming:
# ------
# Original: padahal bagus sekarang jadi aplikasi rusak
# After replacing numbers: padahal bagus sekarang jadi aplikasi rusak
# After case transformation: padahal bagus sekarang jadi aplikasi rusak
# After tokenization: ['padahal', 'bagus', 'sekarang', 'jadi', 'aplikasi', 'rusak']
# After stopword removal: bagus aplikasi rusak
# After stemming: bagus aplikasi rusak
# ------
# Original: masih tidak pernah bisa menyinkronkan di ponsel saya. Versi PC bagus
# After replacing numbers: masih tidak pernah bisa menyinkronkan di ponsel saya. Versi PC bagus
# After case transformation: masih tidak pernah bisa menyinkronkan di ponsel saya. versi pc bagus
# After tokenization: ['masih', 'tidak', 'pernah', 'bisa', 'menyinkronkan', 'di', 'ponsel', 'saya.', 'versi', 'pc', 'bagus']
# After stopword removal: menyinkronkan ponsel saya. versi pc bagus
# After stemming: sinkron ponsel saya versi pc bagus
# ------
# Original: Berhenti mengganggu saya untuk ngasih feedback. Kami membayar untuk layanan ini
# After replacing numbers: Berhenti mengganggu saya untuk ngasih feedback. Kami membayar untuk layanan ini
# After case transformation: berhenti mengganggu saya untuk ngasih feedback. kami membayar untuk layanan ini
# After tokenization: ['berhenti', 'mengganggu', 'saya', 'untuk', 'ngasih', 'feedback.', 'kami', 'membayar', 'untuk', 'layanan', 'ini']
# After stopword removal: berhenti mengganggu ngasih feedback. membayar layanan
# After stemming: henti ganggu ngasih feedback bayar layan
# ------
# Original: Aplikasi ini menunjukkan pengingat di akhir pekan ketika saya telah memilih "ulangi hari kerja"
# After replacing numbers: Aplikasi ini menunjukkan pengingat di akhir pekan ketika saya telah memilih "ulangi hari kerja"
# After case transformation: aplikasi ini menunjukkan pengingat di akhir pekan ketika saya telah memilih "ulangi hari kerja"
# After tokenization: ['aplikasi', 'ini', 'menunjukkan', 'pengingat', 'di', 'akhir', 'pekan', 'ketika', 'saya', 'telah', 'memilih', '"ulangi', 'hari', 'kerja"']
# After stopword removal: aplikasi pengingat pekan memilih "ulangi kerja"
# After stemming: aplikasi ingat pekan pilih ulang kerja
# ------
# Original: Aplikasi terburuk macet saat  setiap kali memuat
# After replacing numbers: Aplikasi terburuk macet saat  setiap kali memuat
# After case transformation: aplikasi terburuk macet saat  setiap kali memuat
# After tokenization: ['aplikasi', 'terburuk', 'macet', 'saat', 'setiap', 'kali', 'memuat']
# After stopword removal: aplikasi terburuk macet kali memuat
# After stemming: aplikasi buruk macet kali muat
# ------
# Original: aplikasi scam woy
# After replacing numbers: aplikasi scam woy
# After case transformation: aplikasi scam woy
# After tokenization: ['aplikasi', 'scam', 'woy']
# After stopword removal: aplikasi scam woy
# After stemming: aplikasi scam woy
# ------
# Original: Tugas berulang tidak berfungsi lagi! Saat kita klik selesai di daftar 'Hari Saya', tugasnya muncul kembali di 'Hari Saya'.
# After replacing numbers: Tugas berulang tidak berfungsi lagi! Saat kita klik selesai di daftar 'Hari Saya', tugasnya muncul kembali di 'Hari Saya'.
# After case transformation: tugas berulang tidak berfungsi lagi! saat kita klik selesai di daftar 'hari saya', tugasnya muncul kembali di 'hari saya'.
# After tokenization: ['tugas', 'berulang', 'tidak', 'berfungsi', 'lagi!', 'saat', 'kita', 'klik', 'selesai', 'di', 'daftar', "'hari", "saya',", 'tugasnya', 'muncul', 'kembali', 'di', "'hari", "saya'."]
# After stopword removal: tugas berulang berfungsi lagi! klik selesai daftar 'hari saya', tugasnya muncul 'hari saya'.
# After stemming: tugas ulang fungsi lagi klik selesai daftar hari saya tugas muncul hari saya
# ------
# Original: update terbarunya punya banyak bug
# After replacing numbers: update terbarunya punya banyak bug
# After case transformation: update terbarunya punya banyak bug
# After tokenization: ['update', 'terbarunya', 'punya', 'banyak', 'bug']
# After stopword removal: update terbarunya bug
# After stemming: update baru bug
# ------
# Original: Aplikasi ini bekerja dengan baik pada awalnya tetapi sekarang sangat lambat. Saya berpikir untuk menghapus aplikasi tetapi saya memiliki begitu banyak yang tersimpan di dalamnya sehingga ini akan sangat menyakitkan.
# After replacing numbers: Aplikasi ini bekerja dengan baik pada awalnya tetapi sekarang sangat lambat. Saya berpikir untuk menghapus aplikasi tetapi saya memiliki begitu banyak yang tersimpan di dalamnya sehingga ini akan sangat menyakitkan.
# After case transformation: aplikasi ini bekerja dengan baik pada awalnya tetapi sekarang sangat lambat. saya berpikir untuk menghapus aplikasi tetapi saya memiliki begitu banyak yang tersimpan di dalamnya sehingga ini akan sangat menyakitkan.
# After tokenization: ['aplikasi', 'ini', 'bekerja', 'dengan', 'baik', 'pada', 'awalnya', 'tetapi', 'sekarang', 'sangat', 'lambat.', 'saya', 'berpikir', 'untuk', 'menghapus', 'aplikasi', 'tetapi', 'saya', 'memiliki', 'begitu', 'banyak', 'yang', 'tersimpan', 'di', 'dalamnya', 'sehingga', 'ini', 'akan', 'sangat', 'menyakitkan.']
# After stopword removal: aplikasi lambat. berpikir menghapus aplikasi memiliki tersimpan dalamnya menyakitkan.
# After stemming: aplikasi lambat pikir hapus aplikasi milik simpan dalam sakit
# ------
# Original: Ini adalah aplikasi hebat sampai sinkronisasi berhenti berfungsi dengan baik, padahal ini alasan utama ku makai aplikasi ini
# After replacing numbers: Ini adalah aplikasi hebat sampai sinkronisasi berhenti berfungsi dengan baik, padahal ini alasan utama ku makai aplikasi ini
# After case transformation: ini adalah aplikasi hebat sampai sinkronisasi berhenti berfungsi dengan baik, padahal ini alasan utama ku makai aplikasi ini
# After tokenization: ['ini', 'adalah', 'aplikasi', 'hebat', 'sampai', 'sinkronisasi', 'berhenti', 'berfungsi', 'dengan', 'baik,', 'padahal', 'ini', 'alasan', 'utama', 'ku', 'makai', 'aplikasi', 'ini']
# After stopword removal: aplikasi hebat sinkronisasi berhenti berfungsi baik, alasan utama ku makai aplikasi
# After stemming: aplikasi hebat sinkronisasi henti fungsi baik alas utama ku maka aplikasi
# ------
# Original: Tugas berulang tidak berfungsi lagi! Saat kita klik selesai di daftar 'Hari Saya', tugasnya muncul kembali di 'Hari Saya'.
# After replacing numbers: Tugas berulang tidak berfungsi lagi! Saat kita klik selesai di daftar 'Hari Saya', tugasnya muncul kembali di 'Hari Saya'.
# After case transformation: tugas berulang tidak berfungsi lagi! saat kita klik selesai di daftar 'hari saya', tugasnya muncul kembali di 'hari saya'.
# After tokenization: ['tugas', 'berulang', 'tidak', 'berfungsi', 'lagi!', 'saat', 'kita', 'klik', 'selesai', 'di', 'daftar', "'hari", "saya',", 'tugasnya', 'muncul', 'kembali', 'di', "'hari", "saya'."]
# After stopword removal: tugas berulang berfungsi lagi! klik selesai daftar 'hari saya', tugasnya muncul 'hari saya'.
# After stemming: tugas ulang fungsi lagi klik selesai daftar hari saya tugas muncul hari saya
# ------
# Original: Aplikasi ini berhenti memberikan pemberitahuan setelah melewatkan beberapa tugas, itulah mengapa ini tidak berguna
# After replacing numbers: Aplikasi ini berhenti memberikan pemberitahuan setelah melewatkan beberapa tugas, itulah mengapa ini tidak berguna
# After case transformation: aplikasi ini berhenti memberikan pemberitahuan setelah melewatkan beberapa tugas, itulah mengapa ini tidak berguna
# After tokenization: ['aplikasi', 'ini', 'berhenti', 'memberikan', 'pemberitahuan', 'setelah', 'melewatkan', 'beberapa', 'tugas,', 'itulah', 'mengapa', 'ini', 'tidak', 'berguna']
# After stopword removal: aplikasi berhenti pemberitahuan melewatkan tugas, berguna
# After stemming: aplikasi henti pemberitahuan lewat tugas guna
# ------
# Original: udah di setel pengingat, malah gak mengingatkan
# After replacing numbers: udah di setel pengingat, malah gak mengingatkan
# After case transformation: udah di setel pengingat, malah gak mengingatkan
# After tokenization: ['udah', 'di', 'setel', 'pengingat,', 'malah', 'gak', 'mengingatkan']
# After stopword removal: udah setel pengingat, gak
# After stemming: udah setel ingat gak
# ------
# Original: Anda harus masuk untuk menggunakan daftar tugas! Segera hapus instalan!
# After replacing numbers: Anda harus masuk untuk menggunakan daftar tugas! Segera hapus instalan!
# After case transformation: anda harus masuk untuk menggunakan daftar tugas! segera hapus instalan!
# After tokenization: ['anda', 'harus', 'masuk', 'untuk', 'menggunakan', 'daftar', 'tugas!', 'segera', 'hapus', 'instalan!']
# After stopword removal: masuk daftar tugas! hapus instalan!
# After stemming: masuk daftar tugas hapus instalan
# ------
# Original: Aplikasi seperti ini seharusnya dapat digunakan tanpa akun Microsoft.
# After replacing numbers: Aplikasi seperti ini seharusnya dapat digunakan tanpa akun Microsoft.
# After case transformation: aplikasi seperti ini seharusnya dapat digunakan tanpa akun microsoft.
# After tokenization: ['aplikasi', 'seperti', 'ini', 'seharusnya', 'dapat', 'digunakan', 'tanpa', 'akun', 'microsoft.']
# After stopword removal: aplikasi akun microsoft.
# After stemming: aplikasi akun microsoft
# ------
# Original: Tidak berfungsi seperti yang diharapkan. Bahkan setelah menambahkan tugas, itu tidak muncul di layar.
# After replacing numbers: Tidak berfungsi seperti yang diharapkan. Bahkan setelah menambahkan tugas, itu tidak muncul di layar.
# After case transformation: tidak berfungsi seperti yang diharapkan. bahkan setelah menambahkan tugas, itu tidak muncul di layar.
# After tokenization: ['tidak', 'berfungsi', 'seperti', 'yang', 'diharapkan.', 'bahkan', 'setelah', 'menambahkan', 'tugas,', 'itu', 'tidak', 'muncul', 'di', 'layar.']
# After stopword removal: berfungsi diharapkan. tugas, muncul layar.
# After stemming: fungsi harap tugas muncul layar
# ------
# Original: tidak berfungsi sama sekali. Tidak ada tugas saya yang muncul di Microsoft ToDo.
# After replacing numbers: tidak berfungsi sama sekali. Tidak ada tugas saya yang muncul di Microsoft ToDo.
# After case transformation: tidak berfungsi sama sekali. tidak ada tugas saya yang muncul di microsoft todo.
# After tokenization: ['tidak', 'berfungsi', 'sama', 'sekali.', 'tidak', 'ada', 'tugas', 'saya', 'yang', 'muncul', 'di', 'microsoft', 'todo.']
# After stopword removal: berfungsi sekali. tugas muncul microsoft todo.
# After stemming: fungsi sekali tugas muncul microsoft todo
# ------
# Original: Fungsi dasar tidak tersedia. Daftar juga menghilang tanpa alasan dan gak bisa dibalikin
# After replacing numbers: Fungsi dasar tidak tersedia. Daftar juga menghilang tanpa alasan dan gak bisa dibalikin
# After case transformation: fungsi dasar tidak tersedia. daftar juga menghilang tanpa alasan dan gak bisa dibalikin
# After tokenization: ['fungsi', 'dasar', 'tidak', 'tersedia.', 'daftar', 'juga', 'menghilang', 'tanpa', 'alasan', 'dan', 'gak', 'bisa', 'dibalikin']
# After stopword removal: fungsi dasar tersedia. daftar menghilang alasan gak dibalikin
# After stemming: fungsi dasar sedia daftar hilang alas gak dibalikin
# ------
# Original: Sangat mengecewakan karena berbagai alasan.
# After replacing numbers: Sangat mengecewakan karena berbagai alasan.
# After case transformation: sangat mengecewakan karena berbagai alasan.
# After tokenization: ['sangat', 'mengecewakan', 'karena', 'berbagai', 'alasan.']
# After stopword removal: mengecewakan alasan.
# After stemming: kecewa alas
# ------
# Original: Rumit dibandingkan dengan aplikasi to-do lainnya. Plus tidak berfungsi beberapa kali
# After replacing numbers: Rumit dibandingkan dengan aplikasi to-do lainnya. Plus tidak berfungsi beberapa kali
# After case transformation: rumit dibandingkan dengan aplikasi to-do lainnya. plus tidak berfungsi beberapa kali
# After tokenization: ['rumit', 'dibandingkan', 'dengan', 'aplikasi', 'to-do', 'lainnya.', 'plus', 'tidak', 'berfungsi', 'beberapa', 'kali']
# After stopword removal: rumit dibandingkan aplikasi to-do lainnya. plus berfungsi kali
# After stemming: rumit banding aplikasi to-do lain plus fungsi kali
# ------
# Original: Saya suka aplikasi ini dan menggunakannya setiap hari. Namun saya memberikannya 1 bintang karena mereka tidak memperbaiki bug bahkan setelah beberapa keluhan. Setiap kali saya mengeluh mereka mengatakan itu masalah dengan perangkat saya. Sangat keras kepala.
# After replacing numbers: Saya suka aplikasi ini dan menggunakannya setiap hari. Namun saya memberikannya satu bintang karena mereka tidak memperbaiki bug bahkan setelah beberapa keluhan. Setiap kali saya mengeluh mereka mengatakan itu masalah dengan perangkat saya. Sangat keras kepala.
# After case transformation: saya suka aplikasi ini dan menggunakannya setiap hari. namun saya memberikannya satu bintang karena mereka tidak memperbaiki bug bahkan setelah beberapa keluhan. setiap kali saya mengeluh mereka mengatakan itu masalah dengan perangkat saya. sangat keras kepala.
# After tokenization: ['saya', 'suka', 'aplikasi', 'ini', 'dan', 'menggunakannya', 'setiap', 'hari.', 'namun', 'saya', 'memberikannya', 'satu', 'bintang', 'karena', 'mereka', 'tidak', 'memperbaiki', 'bug', 'bahkan', 'setelah', 'beberapa', 'keluhan.', 'setiap', 'kali', 'saya', 'mengeluh', 'mereka', 'mengatakan', 'itu', 'masalah', 'dengan', 'perangkat', 'saya.', 'sangat', 'keras', 'kepala.']
# After stopword removal: suka aplikasi menggunakannya hari. memberikannya bintang memperbaiki bug keluhan. kali mengeluh perangkat saya. keras kepala.
# After stemming: suka aplikasi guna hari beri bintang baik bug keluh kali keluh perangkat saya keras kepala
# ------
# Original: entri spam, kenapa pihak ketiga punya akses ke daftar pribadi ku?
# After replacing numbers: entri spam, kenapa pihak ketiga punya akses ke daftar pribadi ku?
# After case transformation: entri spam, kenapa pihak ketiga punya akses ke daftar pribadi ku?
# After tokenization: ['entri', 'spam,', 'kenapa', 'pihak', 'ketiga', 'punya', 'akses', 'ke', 'daftar', 'pribadi', 'ku?']
# After stopword removal: entri spam, ketiga akses daftar pribadi ku?
# After stemming: entri spam tiga akses daftar pribadi ku
# ------
# Original: Aplikasi bagus tapi bugnya terlalu banyak. Membeku ang berkedip-kedip sepanjang waktu di Galaxy s22 saya.
# After replacing numbers: Aplikasi bagus tapi bugnya terlalu banyak. Membeku ang berkedip-kedip sepanjang waktu di Galaxy sduadua saya.
# After case transformation: aplikasi bagus tapi bugnya terlalu banyak. membeku ang berkedip-kedip sepanjang waktu di galaxy sduadua saya.
# After tokenization: ['aplikasi', 'bagus', 'tapi', 'bugnya', 'terlalu', 'banyak.', 'membeku', 'ang', 'berkedip-kedip', 'sepanjang', 'waktu', 'di', 'galaxy', 'sduadua', 'saya.']
# After stopword removal: aplikasi bagus bugnya banyak. membeku ang berkedip-kedip galaxy sduadua saya.
# After stemming: aplikasi bagus bugnya banyak beku ang kedip galaxy sduadua saya
# ------
# Original: Bahkan tidak bisa menghapus anggota dan bekerja sangat lambat
# After replacing numbers: Bahkan tidak bisa menghapus anggota dan bekerja sangat lambat
# After case transformation: bahkan tidak bisa menghapus anggota dan bekerja sangat lambat
# After tokenization: ['bahkan', 'tidak', 'bisa', 'menghapus', 'anggota', 'dan', 'bekerja', 'sangat', 'lambat']
# After stopword removal: menghapus anggota lambat
# After stemming: hapus anggota lambat
# ------
#    score                       content    label
# 0      5                                POSITIF
# 1      5             bantu tugas kerja  POSITIF
# 2      5  bantu kerja saya terimakasih  POSITIF
# 3      5       duabulanan pakai nikmat  POSITIF
# 4      5   manfaat sinkromisasi laptop  POSITIF
