# %%
import pandas as pd
from textblob import TextBlob
import inflect
import nltk
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from nltk.corpus import stopwords
import re

# Download stopwords untuk nltk
nltk.download('stopwords')

# Inisialisasi inflect engine untuk konversi angka ke kata
p = inflect.engine()

# Inisialisasi stemmer Bahasa Indonesia dari Sastrawi
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# Mengambil daftar stopwords bahasa Indonesia
stop_words = set(stopwords.words('indonesian'))

# Fungsi untuk memperbaiki typo
# def perbaiki_typo(teks):
#     blob = TextBlob(teks)
#     return str(blob.correct())

angka_to_kata = {
    '0': 'nol', '1': 'satu', '2': 'dua', '3': 'tiga', '4': 'empat',
    '5': 'lima', '6': 'enam', '7': 'tujuh', '8': 'delapan', '9': 'sembilan'
}

# Fungsi untuk mengganti angka dengan kata
def ganti_angka_dengan_kata(teks):
    def replace(match):
        return angka_to_kata[match.group(0)]
    return re.sub(r'\d', replace, teks)

# Fungsi untuk tokenisasi
def tokenize(teks):
    return teks.split()

# Fungsi untuk transformasi kasus (menjadi huruf kecil)
def transform_case(teks):
    return teks.lower()

# Fungsi untuk menghapus stopwords
def hapus_stopwords(teks):
    tokens = teks.split()
    tokens = [word for word in tokens if word not in stop_words]
    return ' '.join(tokens)

# Fungsi untuk stemming
def stem_text(teks):
    return stemmer.stem(teks)

# Membaca file excel
df = pd.read_excel('./dataset-MSTeam.xlsx')

# Proses preprocessing dengan cetakan proses
for index, row in df.iterrows():
    print(f"Original: {row['content']}")

#     row['content'] = perbaiki_typo(row['content'])
#     print(f"After typo correction: {row['content']}")

    row['content'] = ganti_angka_dengan_kata(row['content'])
    print(f"After replacing numbers: {row['content']}")

    row['content'] = transform_case(row['content'])
    print(f"After case transformation: {row['content']}")

    tokens = tokenize(row['content'])
    print(f"After tokenization: {tokens}")

    row['content'] = ' '.join(tokens)
    row['content'] = hapus_stopwords(row['content'])
    print(f"After stopword removal: {row['content']}")

    row['content'] = stem_text(row['content'])
    print(f"After stemming: {row['content']}")

    # Update the dataframe with processed content
    df.at[index, 'content'] = row['content']
    print("------")

# Menyimpan kembali ke file excel atau menampilkan hasil
df.to_excel('dataset-MSTeam-after-preprocess.xlsx', index=False)
print(df.head())
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Original: pintar aplikasinya
# After replacing numbers: pintar aplikasinya
# After case transformation: pintar aplikasinya
# After tokenization: ['pintar', 'aplikasinya']
# After stopword removal: pintar aplikasinya
# After stemming: pintar aplikasi
# ------
# Original: good
# After replacing numbers: good
# After case transformation: good
# After tokenization: ['good']
# After stopword removal: good
# After stemming: good
# ------
# Original: sangat memudahkan saya dalam mengerjakan tugas,
# After replacing numbers: sangat memudahkan saya dalam mengerjakan tugas,
# After case transformation: sangat memudahkan saya dalam mengerjakan tugas,
# After tokenization: ['sangat', 'memudahkan', 'saya', 'dalam', 'mengerjakan', 'tugas,']
# After stopword removal: memudahkan tugas,
# After stemming: mudah tugas
# ------
# Original: Oke
# After replacing numbers: Oke
# After case transformation: oke
# After tokenization: ['oke']
# After stopword removal: oke
# After stemming: oke
# ------
# Original:  membantu banget 1 aplikasi banyak manfaat
# After replacing numbers:  membantu banget satu aplikasi banyak manfaat
# After case transformation:  membantu banget satu aplikasi banyak manfaat
# After tokenization: ['membantu', 'banget', 'satu', 'aplikasi', 'banyak', 'manfaat']
# After stopword removal: membantu banget aplikasi manfaat
# After stemming: bantu banget aplikasi manfaat
# ------
# Original: Membantu adm perkuliahan
# After replacing numbers: Membantu adm perkuliahan
# After case transformation: membantu adm perkuliahan
# After tokenization: ['membantu', 'adm', 'perkuliahan']
# After stopword removal: membantu adm perkuliahan
# After stemming: bantu adm kuliah
# ------
# Original: Aplikasi yang sangat bagus. Meskipun tidak seringan zoom, namun memiliki fitur yang lengkap untuk mendukung karya kita. Terima kasih
# After replacing numbers: Aplikasi yang sangat bagus. Meskipun tidak seringan zoom, namun memiliki fitur yang lengkap untuk mendukung karya kita. Terima kasih
# After case transformation: aplikasi yang sangat bagus. meskipun tidak seringan zoom, namun memiliki fitur yang lengkap untuk mendukung karya kita. terima kasih
# After tokenization: ['aplikasi', 'yang', 'sangat', 'bagus.', 'meskipun', 'tidak', 'seringan', 'zoom,', 'namun', 'memiliki', 'fitur', 'yang', 'lengkap', 'untuk', 'mendukung', 'karya', 'kita.', 'terima', 'kasih']
# After stopword removal: aplikasi bagus. seringan zoom, memiliki fitur lengkap mendukung karya kita. terima kasih
# After stemming: aplikasi bagus sering zoom milik fitur lengkap dukung karya kita terima kasih
# ------
# Original: belajar pemula menyenangkan
# After replacing numbers: belajar pemula menyenangkan
# After case transformation: belajar pemula menyenangkan
# After tokenization: ['belajar', 'pemula', 'menyenangkan']
# After stopword removal: belajar pemula menyenangkan
# After stemming: ajar mula senang
# ------
# Original: Bagus kalau bisa jangan ada iklan nya
# After replacing numbers: Bagus kalau bisa jangan ada iklan nya
# After case transformation: bagus kalau bisa jangan ada iklan nya
# After tokenization: ['bagus', 'kalau', 'bisa', 'jangan', 'ada', 'iklan', 'nya']
# After stopword removal: bagus iklan nya
# After stemming: bagus iklan nya
# ------
# Original: paling keSel pas login bisa sampe 1 jam tapi bagus sih cuman ya kezel di login aj
# After replacing numbers: paling keSel pas login bisa sampe satu jam tapi bagus sih cuman ya kezel di login aj
# After case transformation: paling kesel pas login bisa sampe satu jam tapi bagus sih cuman ya kezel di login aj
# After tokenization: ['paling', 'kesel', 'pas', 'login', 'bisa', 'sampe', 'satu', 'jam', 'tapi', 'bagus', 'sih', 'cuman', 'ya', 'kezel', 'di', 'login', 'aj']
# After stopword removal: kesel pas login sampe jam bagus sih cuman ya kezel login aj
# After stemming: kesel pas login sampe jam bagus sih cuman ya kezel login aj
# ------
# Original: Sesuai kebutuhan
# After replacing numbers: Sesuai kebutuhan
# After case transformation: sesuai kebutuhan
# After tokenization: ['sesuai', 'kebutuhan']
# After stopword removal: sesuai kebutuhan
# After stemming: sesuai butuh
# ------
# Original: Sangat membantu dalam berdialog atau diskusi team yang berjauhan.
# After replacing numbers: Sangat membantu dalam berdialog atau diskusi team yang berjauhan.
# After case transformation: sangat membantu dalam berdialog atau diskusi team yang berjauhan.
# After tokenization: ['sangat', 'membantu', 'dalam', 'berdialog', 'atau', 'diskusi', 'team', 'yang', 'berjauhan.']
# After stopword removal: membantu berdialog diskusi team berjauhan.
# After stemming: bantu dialog diskusi team jauh
# ------
# Original: Saya baik untuk digunakan untuk team
# After replacing numbers: Saya baik untuk digunakan untuk team
# After case transformation: saya baik untuk digunakan untuk team
# After tokenization: ['saya', 'baik', 'untuk', 'digunakan', 'untuk', 'team']
# After stopword removal: team
# After stemming: team
# ------
# Original: memudahkan komunikasi antar team
# After replacing numbers: memudahkan komunikasi antar team
# After case transformation: memudahkan komunikasi antar team
# After tokenization: ['memudahkan', 'komunikasi', 'antar', 'team']
# After stopword removal: memudahkan komunikasi team
# After stemming: mudah komunikasi team
# ------
# Original: sangat cocok di pakai meeting
# After replacing numbers: sangat cocok di pakai meeting
# After case transformation: sangat cocok di pakai meeting
# After tokenization: ['sangat', 'cocok', 'di', 'pakai', 'meeting']
# After stopword removal: cocok pakai meeting
# After stemming: cocok pakai meeting
# ------
# Original: Membantu dalam menyampaikan info dengan cepat
# After replacing numbers: Membantu dalam menyampaikan info dengan cepat
# After case transformation: membantu dalam menyampaikan info dengan cepat
# After tokenization: ['membantu', 'dalam', 'menyampaikan', 'info', 'dengan', 'cepat']
# After stopword removal: membantu info cepat
# After stemming: bantu info cepat
# ------
# Original: Aplikasi yang ku pakai saat lagi zaman covid 19 Terimakasih Microsoft Teams
# After replacing numbers: Aplikasi yang ku pakai saat lagi zaman covid satusembilan Terimakasih Microsoft Teams
# After case transformation: aplikasi yang ku pakai saat lagi zaman covid satusembilan terimakasih microsoft teams
# After tokenization: ['aplikasi', 'yang', 'ku', 'pakai', 'saat', 'lagi', 'zaman', 'covid', 'satusembilan', 'terimakasih', 'microsoft', 'teams']
# After stopword removal: aplikasi ku pakai zaman covid satusembilan terimakasih microsoft teams
# After stemming: aplikasi ku pakai zaman covid satusembilan terimakasih microsoft teams
# ------
# Original: bisa banget untuk belajar
# After replacing numbers: bisa banget untuk belajar
# After case transformation: bisa banget untuk belajar
# After tokenization: ['bisa', 'banget', 'untuk', 'belajar']
# After stopword removal: banget belajar
# After stemming: banget ajar
# ------
# Original: sejauh ini aplikasi yang stabil di jaringan low, mudah untuk mengakses, dan banyak fiturnya. tempat saya bekerja secara resmi menggunakan aplikasi ini
# After replacing numbers: sejauh ini aplikasi yang stabil di jaringan low, mudah untuk mengakses, dan banyak fiturnya. tempat saya bekerja secara resmi menggunakan aplikasi ini
# After case transformation: sejauh ini aplikasi yang stabil di jaringan low, mudah untuk mengakses, dan banyak fiturnya. tempat saya bekerja secara resmi menggunakan aplikasi ini
# After tokenization: ['sejauh', 'ini', 'aplikasi', 'yang', 'stabil', 'di', 'jaringan', 'low,', 'mudah', 'untuk', 'mengakses,', 'dan', 'banyak', 'fiturnya.', 'tempat', 'saya', 'bekerja', 'secara', 'resmi', 'menggunakan', 'aplikasi', 'ini']
# After stopword removal: aplikasi stabil jaringan low, mudah mengakses, fiturnya. resmi aplikasi
# After stemming: aplikasi stabil jaring low mudah akses fiturnya resmi aplikasi
# ------
# Original: Sangat baik. Sangat membantu dalam bekerja karena bisa membuka file-file yang di kirim dari kantor.
# After replacing numbers: Sangat baik. Sangat membantu dalam bekerja karena bisa membuka file-file yang di kirim dari kantor.
# After case transformation: sangat baik. sangat membantu dalam bekerja karena bisa membuka file-file yang di kirim dari kantor.
# After tokenization: ['sangat', 'baik.', 'sangat', 'membantu', 'dalam', 'bekerja', 'karena', 'bisa', 'membuka', 'file-file', 'yang', 'di', 'kirim', 'dari', 'kantor.']
# After stopword removal: baik. membantu membuka file-file kirim kantor.
# After stemming: baik bantu buka file-file kirim kantor
# ------
# Original: sudah bagus..
# After replacing numbers: sudah bagus..
# After case transformation: sudah bagus..
# After tokenization: ['sudah', 'bagus..']
# After stopword removal: bagus..
# After stemming: bagus
# ------
# Original: Bagus memberi penjelasan, dan senang membantu bila ada pertanyaan dan juga kesulitan
# After replacing numbers: Bagus memberi penjelasan, dan senang membantu bila ada pertanyaan dan juga kesulitan
# After case transformation: bagus memberi penjelasan, dan senang membantu bila ada pertanyaan dan juga kesulitan
# After tokenization: ['bagus', 'memberi', 'penjelasan,', 'dan', 'senang', 'membantu', 'bila', 'ada', 'pertanyaan', 'dan', 'juga', 'kesulitan']
# After stopword removal: bagus penjelasan, senang membantu kesulitan
# After stemming: bagus jelas senang bantu sulit
# ------
# Original: Sungguh menyenangkan
# After replacing numbers: Sungguh menyenangkan
# After case transformation: sungguh menyenangkan
# After tokenization: ['sungguh', 'menyenangkan']
# After stopword removal: sungguh menyenangkan
# After stemming: sungguh senang
# ------
# Original: sangat membantu pekerjaan
# After replacing numbers: sangat membantu pekerjaan
# After case transformation: sangat membantu pekerjaan
# After tokenization: ['sangat', 'membantu', 'pekerjaan']
# After stopword removal: membantu pekerjaan
# After stemming: bantu kerja
# ------
# Original: sangat membantu dan untuk saya luar biasa dibandingkan dengan lainya.
# After replacing numbers: sangat membantu dan untuk saya luar biasa dibandingkan dengan lainya.
# After case transformation: sangat membantu dan untuk saya luar biasa dibandingkan dengan lainya.
# After tokenization: ['sangat', 'membantu', 'dan', 'untuk', 'saya', 'luar', 'biasa', 'dibandingkan', 'dengan', 'lainya.']
# After stopword removal: membantu dibandingkan lainya.
# After stemming: bantu banding lai
# ------
# Original: Bagus, hanya saja jaringan
# After replacing numbers: Bagus, hanya saja jaringan
# After case transformation: bagus, hanya saja jaringan
# After tokenization: ['bagus,', 'hanya', 'saja', 'jaringan']
# After stopword removal: bagus, jaringan
# After stemming: bagus jaring
# ------
# Original: Bisa di bergunakan dengan baik
# After replacing numbers: Bisa di bergunakan dengan baik
# After case transformation: bisa di bergunakan dengan baik
# After tokenization: ['bisa', 'di', 'bergunakan', 'dengan', 'baik']
# After stopword removal: bergunakan
# After stemming: guna
# ------
# Original: Karena saya bisa mengetahui tugas atau ulangan saya, dan saya bisa bermain dengan teman saya dengan cara diteams teleponan dan main bersama lain waktu....
# After replacing numbers: Karena saya bisa mengetahui tugas atau ulangan saya, dan saya bisa bermain dengan teman saya dengan cara diteams teleponan dan main bersama lain waktu....
# After case transformation: karena saya bisa mengetahui tugas atau ulangan saya, dan saya bisa bermain dengan teman saya dengan cara diteams teleponan dan main bersama lain waktu....
# After tokenization: ['karena', 'saya', 'bisa', 'mengetahui', 'tugas', 'atau', 'ulangan', 'saya,', 'dan', 'saya', 'bisa', 'bermain', 'dengan', 'teman', 'saya', 'dengan', 'cara', 'diteams', 'teleponan', 'dan', 'main', 'bersama', 'lain', 'waktu....']
# After stopword removal: tugas ulangan saya, bermain teman diteams teleponan main waktu....
# After stemming: tugas ulang saya main teman diteams telepon main waktu
# ------
# Original: Aplikasi yang sangat membantu untuk meet dengan siapapun tanpa hambatan
# After replacing numbers: Aplikasi yang sangat membantu untuk meet dengan siapapun tanpa hambatan
# After case transformation: aplikasi yang sangat membantu untuk meet dengan siapapun tanpa hambatan
# After tokenization: ['aplikasi', 'yang', 'sangat', 'membantu', 'untuk', 'meet', 'dengan', 'siapapun', 'tanpa', 'hambatan']
# After stopword removal: aplikasi membantu meet hambatan
# After stemming: aplikasi bantu meet hambat
# ------
# Original: Teams bagus
# After replacing numbers: Teams bagus
# After case transformation: teams bagus
# After tokenization: ['teams', 'bagus']
# After stopword removal: teams bagus
# After stemming: teams bagus
# ------
# Original: Aplikasi yang sangat bagus dan sangat berguna, terimakasih team
# After replacing numbers: Aplikasi yang sangat bagus dan sangat berguna, terimakasih team
# After case transformation: aplikasi yang sangat bagus dan sangat berguna, terimakasih team
# After tokenization: ['aplikasi', 'yang', 'sangat', 'bagus', 'dan', 'sangat', 'berguna,', 'terimakasih', 'team']
# After stopword removal: aplikasi bagus berguna, terimakasih team
# After stemming: aplikasi bagus guna terimakasih team
# ------
# Original: Bagus kalau sinyalnya kuat kadang" suka tidak jelas suaranya kalau sinyalnya tiba-tiba hilang
# After replacing numbers: Bagus kalau sinyalnya kuat kadang" suka tidak jelas suaranya kalau sinyalnya tiba-tiba hilang
# After case transformation: bagus kalau sinyalnya kuat kadang" suka tidak jelas suaranya kalau sinyalnya tiba-tiba hilang
# After tokenization: ['bagus', 'kalau', 'sinyalnya', 'kuat', 'kadang"', 'suka', 'tidak', 'jelas', 'suaranya', 'kalau', 'sinyalnya', 'tiba-tiba', 'hilang']
# After stopword removal: bagus sinyalnya kuat kadang" suka suaranya sinyalnya hilang
# After stemming: bagus sinyal kuat kadang suka suara sinyal hilang
# ------
# Original: Aplikasi sangat membantu untuk kita yang bekerja dengan team tapi jarak yang berbeda
# After replacing numbers: Aplikasi sangat membantu untuk kita yang bekerja dengan team tapi jarak yang berbeda
# After case transformation: aplikasi sangat membantu untuk kita yang bekerja dengan team tapi jarak yang berbeda
# After tokenization: ['aplikasi', 'sangat', 'membantu', 'untuk', 'kita', 'yang', 'bekerja', 'dengan', 'team', 'tapi', 'jarak', 'yang', 'berbeda']
# After stopword removal: aplikasi membantu team jarak berbeda
# After stemming: aplikasi bantu team jarak beda
# ------
# Original: memudahkan koordinasi dalam suatu instansi
# After replacing numbers: memudahkan koordinasi dalam suatu instansi
# After case transformation: memudahkan koordinasi dalam suatu instansi
# After tokenization: ['memudahkan', 'koordinasi', 'dalam', 'suatu', 'instansi']
# After stopword removal: memudahkan koordinasi instansi
# After stemming: mudah koordinasi instansi
# ------
# Original: Mantap, aplikasi yang sangat membantu
# After replacing numbers: Mantap, aplikasi yang sangat membantu
# After case transformation: mantap, aplikasi yang sangat membantu
# After tokenization: ['mantap,', 'aplikasi', 'yang', 'sangat', 'membantu']
# After stopword removal: mantap, aplikasi membantu
# After stemming: mantap aplikasi bantu
# ------
# Original: bagus untuk meeting
# After replacing numbers: bagus untuk meeting
# After case transformation: bagus untuk meeting
# After tokenization: ['bagus', 'untuk', 'meeting']
# After stopword removal: bagus meeting
# After stemming: bagus meeting
# ------
# Original: Bagus. Membantu sekali kuliah jarak jauh
# After replacing numbers: Bagus. Membantu sekali kuliah jarak jauh
# After case transformation: bagus. membantu sekali kuliah jarak jauh
# After tokenization: ['bagus.', 'membantu', 'sekali', 'kuliah', 'jarak', 'jauh']
# After stopword removal: bagus. membantu kuliah jarak
# After stemming: bagus bantu kuliah jarak
# ------
# Original: ini bagus sekali Microsoft teams ini unduh lah ayo
# After replacing numbers: ini bagus sekali Microsoft teams ini unduh lah ayo
# After case transformation: ini bagus sekali microsoft teams ini unduh lah ayo
# After tokenization: ['ini', 'bagus', 'sekali', 'microsoft', 'teams', 'ini', 'unduh', 'lah', 'ayo']
# After stopword removal: bagus microsoft teams unduh ayo
# After stemming: bagus microsoft teams unduh ayo
# ------
# Original: meeting di mana saja bisa dan efective
# After replacing numbers: meeting di mana saja bisa dan efective
# After case transformation: meeting di mana saja bisa dan efective
# After tokenization: ['meeting', 'di', 'mana', 'saja', 'bisa', 'dan', 'efective']
# After stopword removal: meeting efective
# After stemming: meeting efective
# ------
# Original: sangat mempermudah untuk membuat soal
# After replacing numbers: sangat mempermudah untuk membuat soal
# After case transformation: sangat mempermudah untuk membuat soal
# After tokenization: ['sangat', 'mempermudah', 'untuk', 'membuat', 'soal']
# After stopword removal: mempermudah
# After stemming: mudah
# ------
# Original: Fitur lengkap dan mudah, keren
# After replacing numbers: Fitur lengkap dan mudah, keren
# After case transformation: fitur lengkap dan mudah, keren
# After tokenization: ['fitur', 'lengkap', 'dan', 'mudah,', 'keren']
# After stopword removal: fitur lengkap mudah, keren
# After stemming: fitur lengkap mudah keren
# ------
# Original: Meeting online se indonesia sangat mudah hemat waktu,
# After replacing numbers: Meeting online se indonesia sangat mudah hemat waktu,
# After case transformation: meeting online se indonesia sangat mudah hemat waktu,
# After tokenization: ['meeting', 'online', 'se', 'indonesia', 'sangat', 'mudah', 'hemat', 'waktu,']
# After stopword removal: meeting online indonesia mudah hemat waktu,
# After stemming: meeting online indonesia mudah hemat waktu
# ------
# Original: Sangat membatu pekerjaan dan meminimalisir kebocoran data
# After replacing numbers: Sangat membatu pekerjaan dan meminimalisir kebocoran data
# After case transformation: sangat membatu pekerjaan dan meminimalisir kebocoran data
# After tokenization: ['sangat', 'membatu', 'pekerjaan', 'dan', 'meminimalisir', 'kebocoran', 'data']
# After stopword removal: membatu pekerjaan meminimalisir kebocoran data
# After stemming: batu kerja meminimalisir bocor data
# ------
# Original: Saya senang mengunakan Microsoft bisa bertemu langsung dengan teman dalam jarak jauh.
# After replacing numbers: Saya senang mengunakan Microsoft bisa bertemu langsung dengan teman dalam jarak jauh.
# After case transformation: saya senang mengunakan microsoft bisa bertemu langsung dengan teman dalam jarak jauh.
# After tokenization: ['saya', 'senang', 'mengunakan', 'microsoft', 'bisa', 'bertemu', 'langsung', 'dengan', 'teman', 'dalam', 'jarak', 'jauh.']
# After stopword removal: senang mengunakan microsoft bertemu langsung teman jarak jauh.
# After stemming: senang mengunakan microsoft temu langsung teman jarak jauh
# ------
# Original: mempermudah saat mobile karena bisa login bersamaan dengan di dekstop.
# After replacing numbers: mempermudah saat mobile karena bisa login bersamaan dengan di dekstop.
# After case transformation: mempermudah saat mobile karena bisa login bersamaan dengan di dekstop.
# After tokenization: ['mempermudah', 'saat', 'mobile', 'karena', 'bisa', 'login', 'bersamaan', 'dengan', 'di', 'dekstop.']
# After stopword removal: mempermudah mobile login bersamaan dekstop.
# After stemming: mudah mobile login sama dekstop
# ------
# Original: keren, membantu dalam belajar dan bekerja
# After replacing numbers: keren, membantu dalam belajar dan bekerja
# After case transformation: keren, membantu dalam belajar dan bekerja
# After tokenization: ['keren,', 'membantu', 'dalam', 'belajar', 'dan', 'bekerja']
# After stopword removal: keren, membantu belajar
# After stemming: keren bantu ajar
# ------
# Original: Aplikasi ini sangat membantu dalam rapat online dan sejenisnya
# After replacing numbers: Aplikasi ini sangat membantu dalam rapat online dan sejenisnya
# After case transformation: aplikasi ini sangat membantu dalam rapat online dan sejenisnya
# After tokenization: ['aplikasi', 'ini', 'sangat', 'membantu', 'dalam', 'rapat', 'online', 'dan', 'sejenisnya']
# After stopword removal: aplikasi membantu rapat online sejenisnya
# After stemming: aplikasi bantu rapat online jenis
# ------
# Original: Baik sekali untuk Meeting.
# After replacing numbers: Baik sekali untuk Meeting.
# After case transformation: baik sekali untuk meeting.
# After tokenization: ['baik', 'sekali', 'untuk', 'meeting.']
# After stopword removal: meeting.
# After stemming: meeting
# ------
# Original: Bagus sangat membantu dalam aktivitas
# After replacing numbers: Bagus sangat membantu dalam aktivitas
# After case transformation: bagus sangat membantu dalam aktivitas
# After tokenization: ['bagus', 'sangat', 'membantu', 'dalam', 'aktivitas']
# After stopword removal: bagus membantu aktivitas
# After stemming: bagus bantu aktivitas
# ------
# Original: mempermudah komunikasi team
# After replacing numbers: mempermudah komunikasi team
# After case transformation: mempermudah komunikasi team
# After tokenization: ['mempermudah', 'komunikasi', 'team']
# After stopword removal: mempermudah komunikasi team
# After stemming: mudah komunikasi team
# ------
# Original: Semua ada dalam satu aplikasi, bagus!
# After replacing numbers: Semua ada dalam satu aplikasi, bagus!
# After case transformation: semua ada dalam satu aplikasi, bagus!
# After tokenization: ['semua', 'ada', 'dalam', 'satu', 'aplikasi,', 'bagus!']
# After stopword removal: aplikasi, bagus!
# After stemming: aplikasi bagus
# ------
# Original: aplikasi ini sangat membantu saat bekerja
# After replacing numbers: aplikasi ini sangat membantu saat bekerja
# After case transformation: aplikasi ini sangat membantu saat bekerja
# After tokenization: ['aplikasi', 'ini', 'sangat', 'membantu', 'saat', 'bekerja']
# After stopword removal: aplikasi membantu
# After stemming: aplikasi bantu
# ------
# Original: bagus untuk kerja teams
# After replacing numbers: bagus untuk kerja teams
# After case transformation: bagus untuk kerja teams
# After tokenization: ['bagus', 'untuk', 'kerja', 'teams']
# After stopword removal: bagus kerja teams
# After stemming: bagus kerja teams
# ------
# Original: Terbaik karena tidak semua orang lain bisa masuk tanpa persetujuan dari peserta yang ada didalam meeting
# After replacing numbers: Terbaik karena tidak semua orang lain bisa masuk tanpa persetujuan dari peserta yang ada didalam meeting
# After case transformation: terbaik karena tidak semua orang lain bisa masuk tanpa persetujuan dari peserta yang ada didalam meeting
# After tokenization: ['terbaik', 'karena', 'tidak', 'semua', 'orang', 'lain', 'bisa', 'masuk', 'tanpa', 'persetujuan', 'dari', 'peserta', 'yang', 'ada', 'didalam', 'meeting']
# After stopword removal: terbaik orang masuk persetujuan peserta didalam meeting
# After stemming: baik orang masuk tuju serta dalam meeting
# ------
# Original: Sekarang ngelagnya sudah tidak separah dulu, lebih baiklah sekarang dan juga lebih banyak juga fiturnya
# After replacing numbers: Sekarang ngelagnya sudah tidak separah dulu, lebih baiklah sekarang dan juga lebih banyak juga fiturnya
# After case transformation: sekarang ngelagnya sudah tidak separah dulu, lebih baiklah sekarang dan juga lebih banyak juga fiturnya
# After tokenization: ['sekarang', 'ngelagnya', 'sudah', 'tidak', 'separah', 'dulu,', 'lebih', 'baiklah', 'sekarang', 'dan', 'juga', 'lebih', 'banyak', 'juga', 'fiturnya']
# After stopword removal: ngelagnya separah dulu, baiklah fiturnya
# After stemming: ngelagnya parah dulu baik fiturnya
# ------
# Original: sangat membantu pekerjaan.
# After replacing numbers: sangat membantu pekerjaan.
# After case transformation: sangat membantu pekerjaan.
# After tokenization: ['sangat', 'membantu', 'pekerjaan.']
# After stopword removal: membantu pekerjaan.
# After stemming: bantu kerja
# ------
# Original: platform kolaborasi yang sangat bagus
# After replacing numbers: platform kolaborasi yang sangat bagus
# After case transformation: platform kolaborasi yang sangat bagus
# After tokenization: ['platform', 'kolaborasi', 'yang', 'sangat', 'bagus']
# After stopword removal: platform kolaborasi bagus
# After stemming: platform kolaborasi bagus
# ------
# Original: Ms teams sangat praktis untuk kepentingan masayarakat di jaman sekarang.untuk pekerjaan ataupun pendidikan
# After replacing numbers: Ms teams sangat praktis untuk kepentingan masayarakat di jaman sekarang.untuk pekerjaan ataupun pendidikan
# After case transformation: ms teams sangat praktis untuk kepentingan masayarakat di jaman sekarang.untuk pekerjaan ataupun pendidikan
# After tokenization: ['ms', 'teams', 'sangat', 'praktis', 'untuk', 'kepentingan', 'masayarakat', 'di', 'jaman', 'sekarang.untuk', 'pekerjaan', 'ataupun', 'pendidikan']
# After stopword removal: ms teams praktis kepentingan masayarakat jaman sekarang.untuk pekerjaan pendidikan
# After stemming: ms teams praktis penting masayarakat jaman sekarang untuk kerja didik
# ------
# Original: mudah diimplementasikan dan cepat pengirimannya
# After replacing numbers: mudah diimplementasikan dan cepat pengirimannya
# After case transformation: mudah diimplementasikan dan cepat pengirimannya
# After tokenization: ['mudah', 'diimplementasikan', 'dan', 'cepat', 'pengirimannya']
# After stopword removal: mudah diimplementasikan cepat pengirimannya
# After stemming: mudah implementasi cepat kirim
# ------
# Original: panduan terbaik
# After replacing numbers: panduan terbaik
# After case transformation: panduan terbaik
# After tokenization: ['panduan', 'terbaik']
# After stopword removal: panduan terbaik
# After stemming: pandu baik
# ------
# Original: sangat mendukung dalam bekerja
# After replacing numbers: sangat mendukung dalam bekerja
# After case transformation: sangat mendukung dalam bekerja
# After tokenization: ['sangat', 'mendukung', 'dalam', 'bekerja']
# After stopword removal: mendukung
# After stemming: dukung
# ------
# Original: Aplikasi ini bagus banget untuk meeting di grup kerja dan menjaga privasi
# After replacing numbers: Aplikasi ini bagus banget untuk meeting di grup kerja dan menjaga privasi
# After case transformation: aplikasi ini bagus banget untuk meeting di grup kerja dan menjaga privasi
# After tokenization: ['aplikasi', 'ini', 'bagus', 'banget', 'untuk', 'meeting', 'di', 'grup', 'kerja', 'dan', 'menjaga', 'privasi']
# After stopword removal: aplikasi bagus banget meeting grup kerja menjaga privasi
# After stemming: aplikasi bagus banget meeting grup kerja jaga privasi
# ------
# Original: Aplikasi rekomendasi sangat mudah untuk digunakan
# After replacing numbers: Aplikasi rekomendasi sangat mudah untuk digunakan
# After case transformation: aplikasi rekomendasi sangat mudah untuk digunakan
# After tokenization: ['aplikasi', 'rekomendasi', 'sangat', 'mudah', 'untuk', 'digunakan']
# After stopword removal: aplikasi rekomendasi mudah
# After stemming: aplikasi rekomendasi mudah
# ------
# Original: Akses yang mudah diperlukan dan fitur-fiturnya perlu ditingkatkan lebih lanjut.
# After replacing numbers: Akses yang mudah diperlukan dan fitur-fiturnya perlu ditingkatkan lebih lanjut.
# After case transformation: akses yang mudah diperlukan dan fitur-fiturnya perlu ditingkatkan lebih lanjut.
# After tokenization: ['akses', 'yang', 'mudah', 'diperlukan', 'dan', 'fitur-fiturnya', 'perlu', 'ditingkatkan', 'lebih', 'lanjut.']
# After stopword removal: akses mudah fitur-fiturnya ditingkatkan lanjut.
# After stemming: akses mudah fitur-fiturnya tingkat lanjut
# ------
# Original: sudah baik dan tetap dipertahankan
# After replacing numbers: sudah baik dan tetap dipertahankan
# After case transformation: sudah baik dan tetap dipertahankan
# After tokenization: ['sudah', 'baik', 'dan', 'tetap', 'dipertahankan']
# After stopword removal: dipertahankan
# After stemming: tahan
# ------
# Original: Sangat cocok untuk semua meeting
# After replacing numbers: Sangat cocok untuk semua meeting
# After case transformation: sangat cocok untuk semua meeting
# After tokenization: ['sangat', 'cocok', 'untuk', 'semua', 'meeting']
# After stopword removal: cocok meeting
# After stemming: cocok meeting
# ------
# Original: Aplikasinya bagus bisa untuk sekolah offline maupun online
# After replacing numbers: Aplikasinya bagus bisa untuk sekolah offline maupun online
# After case transformation: aplikasinya bagus bisa untuk sekolah offline maupun online
# After tokenization: ['aplikasinya', 'bagus', 'bisa', 'untuk', 'sekolah', 'offline', 'maupun', 'online']
# After stopword removal: aplikasinya bagus sekolah offline online
# After stemming: aplikasi bagus sekolah offline online
# ------
# Original: Lumayan baik untuk meeting.
# After replacing numbers: Lumayan baik untuk meeting.
# After case transformation: lumayan baik untuk meeting.
# After tokenization: ['lumayan', 'baik', 'untuk', 'meeting.']
# After stopword removal: lumayan meeting.
# After stemming: lumayan meeting
# ------
# Original: Bagus sekali saya menggunakannya untuk sekolah dan selalu menjadi lebih baik.
# After replacing numbers: Bagus sekali saya menggunakannya untuk sekolah dan selalu menjadi lebih baik.
# After case transformation: bagus sekali saya menggunakannya untuk sekolah dan selalu menjadi lebih baik.
# After tokenization: ['bagus', 'sekali', 'saya', 'menggunakannya', 'untuk', 'sekolah', 'dan', 'selalu', 'menjadi', 'lebih', 'baik.']
# After stopword removal: bagus menggunakannya sekolah baik.
# After stemming: bagus guna sekolah baik
# ------
# Original: Sejak pandemi sering training menggunakan aplikasi ini dan sangat membantu sekali tentunya. Lebih efisien dan praktis. tidakood
# After replacing numbers: Sejak pandemi sering training menggunakan aplikasi ini dan sangat membantu sekali tentunya. Lebih efisien dan praktis. tidakood
# After case transformation: sejak pandemi sering training menggunakan aplikasi ini dan sangat membantu sekali tentunya. lebih efisien dan praktis. tidakood
# After tokenization: ['sejak', 'pandemi', 'sering', 'training', 'menggunakan', 'aplikasi', 'ini', 'dan', 'sangat', 'membantu', 'sekali', 'tentunya.', 'lebih', 'efisien', 'dan', 'praktis.', 'tidakood']
# After stopword removal: pandemi training aplikasi membantu tentunya. efisien praktis. tidakood
# After stemming: pandemi training aplikasi bantu tentu efisien praktis tidakood
# ------
# Original: emoji nya LUCU BANGET
# After replacing numbers: emoji nya LUCU BANGET
# After case transformation: emoji nya lucu banget
# After tokenization: ['emoji', 'nya', 'lucu', 'banget']
# After stopword removal: emoji nya lucu banget
# After stemming: emoji nya lucu banget
# ------
# Original: aplikasi yang sangat bantu di diunia pekerjaan
# After replacing numbers: aplikasi yang sangat bantu di diunia pekerjaan
# After case transformation: aplikasi yang sangat bantu di diunia pekerjaan
# After tokenization: ['aplikasi', 'yang', 'sangat', 'bantu', 'di', 'diunia', 'pekerjaan']
# After stopword removal: aplikasi bantu diunia pekerjaan
# After stemming: aplikasi bantu diunia kerja
# ------
# Original: Sangat membantu untuk terhubung dengan relasi kerja apalagi untuk meeting
# After replacing numbers: Sangat membantu untuk terhubung dengan relasi kerja apalagi untuk meeting
# After case transformation: sangat membantu untuk terhubung dengan relasi kerja apalagi untuk meeting
# After tokenization: ['sangat', 'membantu', 'untuk', 'terhubung', 'dengan', 'relasi', 'kerja', 'apalagi', 'untuk', 'meeting']
# After stopword removal: membantu terhubung relasi kerja meeting
# After stemming: bantu hubung relasi kerja meeting
# ------
# Original: ok.. aman untuk jaringan kantor
# After replacing numbers: ok.. aman untuk jaringan kantor
# After case transformation: ok.. aman untuk jaringan kantor
# After tokenization: ['ok..', 'aman', 'untuk', 'jaringan', 'kantor']
# After stopword removal: ok.. aman jaringan kantor
# After stemming: ok aman jaring kantor
# ------
# Original: memudahkan komunikasi
# After replacing numbers: memudahkan komunikasi
# After case transformation: memudahkan komunikasi
# After tokenization: ['memudahkan', 'komunikasi']
# After stopword removal: memudahkan komunikasi
# After stemming: mudah komunikasi
# ------
# Original: mudah digunakan dan bisa merespon customer dengan cepat
# After replacing numbers: mudah digunakan dan bisa merespon customer dengan cepat
# After case transformation: mudah digunakan dan bisa merespon customer dengan cepat
# After tokenization: ['mudah', 'digunakan', 'dan', 'bisa', 'merespon', 'customer', 'dengan', 'cepat']
# After stopword removal: mudah merespon customer cepat
# After stemming: mudah merespon customer cepat
# ------
# Original: Ok sangat baik dalam aplikasi ini untuk menunjang pekerjaan kami
# After replacing numbers: Ok sangat baik dalam aplikasi ini untuk menunjang pekerjaan kami
# After case transformation: ok sangat baik dalam aplikasi ini untuk menunjang pekerjaan kami
# After tokenization: ['ok', 'sangat', 'baik', 'dalam', 'aplikasi', 'ini', 'untuk', 'menunjang', 'pekerjaan', 'kami']
# After stopword removal: ok aplikasi menunjang pekerjaan
# After stemming: ok aplikasi tunjang kerja
# ------
# Original: mempermudah untuk meeting melibatkan banyak peserta
# After replacing numbers: mempermudah untuk meeting melibatkan banyak peserta
# After case transformation: mempermudah untuk meeting melibatkan banyak peserta
# After tokenization: ['mempermudah', 'untuk', 'meeting', 'melibatkan', 'banyak', 'peserta']
# After stopword removal: mempermudah meeting melibatkan peserta
# After stemming: mudah meeting libat serta
# ------
# Original: Aplikasi ini cukup membantu untuk meeting online.
# After replacing numbers: Aplikasi ini cukup membantu untuk meeting online.
# After case transformation: aplikasi ini cukup membantu untuk meeting online.
# After tokenization: ['aplikasi', 'ini', 'cukup', 'membantu', 'untuk', 'meeting', 'online.']
# After stopword removal: aplikasi membantu meeting online.
# After stemming: aplikasi bantu meeting online
# ------
# Original: Aplikasi mempermudah pekerjaan
# After replacing numbers: Aplikasi mempermudah pekerjaan
# After case transformation: aplikasi mempermudah pekerjaan
# After tokenization: ['aplikasi', 'mempermudah', 'pekerjaan']
# After stopword removal: aplikasi mempermudah pekerjaan
# After stemming: aplikasi mudah kerja
# ------
# Original: Saya baru membuka Microsoft Teams ini ternyata bagus dan saya tertarik setelah dipelajari dan disimak maksud dan tujuannya untuk pengguna.
# After replacing numbers: Saya baru membuka Microsoft Teams ini ternyata bagus dan saya tertarik setelah dipelajari dan disimak maksud dan tujuannya untuk pengguna.
# After case transformation: saya baru membuka microsoft teams ini ternyata bagus dan saya tertarik setelah dipelajari dan disimak maksud dan tujuannya untuk pengguna.
# After tokenization: ['saya', 'baru', 'membuka', 'microsoft', 'teams', 'ini', 'ternyata', 'bagus', 'dan', 'saya', 'tertarik', 'setelah', 'dipelajari', 'dan', 'disimak', 'maksud', 'dan', 'tujuannya', 'untuk', 'pengguna.']
# After stopword removal: membuka microsoft teams bagus tertarik dipelajari disimak maksud tujuannya pengguna.
# After stemming: buka microsoft teams bagus tarik ajar simak maksud tuju guna
# ------
# Original: Memberi kemudahan dalam mengelola team, apalagi sekarang WFH, Jadi Lebih efisien.
# After replacing numbers: Memberi kemudahan dalam mengelola team, apalagi sekarang WFH, Jadi Lebih efisien.
# After case transformation: memberi kemudahan dalam mengelola team, apalagi sekarang wfh, jadi lebih efisien.
# After tokenization: ['memberi', 'kemudahan', 'dalam', 'mengelola', 'team,', 'apalagi', 'sekarang', 'wfh,', 'jadi', 'lebih', 'efisien.']
# After stopword removal: kemudahan mengelola team, wfh, efisien.
# After stemming: mudah kelola team wfh efisien
# ------
# Original: memperlancar pekerjaan
# After replacing numbers: memperlancar pekerjaan
# After case transformation: memperlancar pekerjaan
# After tokenization: ['memperlancar', 'pekerjaan']
# After stopword removal: memperlancar pekerjaan
# After stemming: lancar kerja
# ------
# Original: membantu pekerjaan
# After replacing numbers: membantu pekerjaan
# After case transformation: membantu pekerjaan
# After tokenization: ['membantu', 'pekerjaan']
# After stopword removal: membantu pekerjaan
# After stemming: bantu kerja
# ------
# Original: Keren.. gampang melakukan meeting dengan aplikasi ini
# After replacing numbers: Keren.. gampang melakukan meeting dengan aplikasi ini
# After case transformation: keren.. gampang melakukan meeting dengan aplikasi ini
# After tokenization: ['keren..', 'gampang', 'melakukan', 'meeting', 'dengan', 'aplikasi', 'ini']
# After stopword removal: keren.. gampang meeting aplikasi
# After stemming: keren gampang meeting aplikasi
# ------
# Original: sangat membantu untuk kerja
# After replacing numbers: sangat membantu untuk kerja
# After case transformation: sangat membantu untuk kerja
# After tokenization: ['sangat', 'membantu', 'untuk', 'kerja']
# After stopword removal: membantu kerja
# After stemming: bantu kerja
# ------
# Original: Keren lebih bagus dari zoom. Bisa meeting lama Berjam jam tanpa tanda mati tiba2
# After replacing numbers: Keren lebih bagus dari zoom. Bisa meeting lama Berjam jam tanpa tanda mati tibadua
# After case transformation: keren lebih bagus dari zoom. bisa meeting lama berjam jam tanpa tanda mati tibadua
# After tokenization: ['keren', 'lebih', 'bagus', 'dari', 'zoom.', 'bisa', 'meeting', 'lama', 'berjam', 'jam', 'tanpa', 'tanda', 'mati', 'tibadua']
# After stopword removal: keren bagus zoom. meeting berjam jam tanda mati tibadua
# After stemming: keren bagus zoom meeting jam jam tanda mati tibadua
# ------
# Original: sangat berguna untuk meeting
# After replacing numbers: sangat berguna untuk meeting
# After case transformation: sangat berguna untuk meeting
# After tokenization: ['sangat', 'berguna', 'untuk', 'meeting']
# After stopword removal: berguna meeting
# After stemming: guna meeting
# ------
# Original: terimakasih microsoft Teams.. sangat membantu saya dalam pertemuan2 bersama grup atau keluarga dalam tatap muka jarak jauh (online).
# After replacing numbers: terimakasih microsoft Teams.. sangat membantu saya dalam pertemuandua bersama grup atau keluarga dalam tatap muka jarak jauh (online).
# After case transformation: terimakasih microsoft teams.. sangat membantu saya dalam pertemuandua bersama grup atau keluarga dalam tatap muka jarak jauh (online).
# After tokenization: ['terimakasih', 'microsoft', 'teams..', 'sangat', 'membantu', 'saya', 'dalam', 'pertemuandua', 'bersama', 'grup', 'atau', 'keluarga', 'dalam', 'tatap', 'muka', 'jarak', 'jauh', '(online).']
# After stopword removal: terimakasih microsoft teams.. membantu pertemuandua grup keluarga tatap muka jarak (online).
# After stemming: terimakasih microsoft teams bantu pertemuandua grup keluarga tatap muka jarak online
# ------
# Original: Cocok untuk professional
# After replacing numbers: Cocok untuk professional
# After case transformation: cocok untuk professional
# After tokenization: ['cocok', 'untuk', 'professional']
# After stopword removal: cocok professional
# After stemming: cocok professional
# ------
# Original: mendukung meeting jarak jauh
# After replacing numbers: mendukung meeting jarak jauh
# After case transformation: mendukung meeting jarak jauh
# After tokenization: ['mendukung', 'meeting', 'jarak', 'jauh']
# After stopword removal: mendukung meeting jarak
# After stemming: dukung meeting jarak
# ------
# Original: penggunaan sejauh ini tidak ada kendala dan masalah. dan tidak ada yang namanya ngefreeze,teams juga terconnect dengan office 365 yang mempermudah dalam mendownload dan menyimpan file.
# After replacing numbers: penggunaan sejauh ini tidak ada kendala dan masalah. dan tidak ada yang namanya ngefreeze,teams juga terconnect dengan office tigaenamlima yang mempermudah dalam mendownload dan menyimpan file.
# After case transformation: penggunaan sejauh ini tidak ada kendala dan masalah. dan tidak ada yang namanya ngefreeze,teams juga terconnect dengan office tigaenamlima yang mempermudah dalam mendownload dan menyimpan file.
# After tokenization: ['penggunaan', 'sejauh', 'ini', 'tidak', 'ada', 'kendala', 'dan', 'masalah.', 'dan', 'tidak', 'ada', 'yang', 'namanya', 'ngefreeze,teams', 'juga', 'terconnect', 'dengan', 'office', 'tigaenamlima', 'yang', 'mempermudah', 'dalam', 'mendownload', 'dan', 'menyimpan', 'file.']
# After stopword removal: penggunaan kendala masalah. namanya ngefreeze,teams terconnect office tigaenamlima mempermudah mendownload menyimpan file.
# After stemming: guna kendala masalah nama ngefreeze teams terconnect office tigaenamlima mudah mendownload simpan file
# ------
# Original: Sip, sangat membatu saat meeting dari jarak yang berjauhan
# After replacing numbers: Sip, sangat membatu saat meeting dari jarak yang berjauhan
# After case transformation: sip, sangat membatu saat meeting dari jarak yang berjauhan
# After tokenization: ['sip,', 'sangat', 'membatu', 'saat', 'meeting', 'dari', 'jarak', 'yang', 'berjauhan']
# After stopword removal: sip, membatu meeting jarak berjauhan
# After stemming: sip batu meeting jarak jauh
# ------
# Original: sangat membantu dalam kegiatan rapat baik banyak orang ataupun hanya berdua
# After replacing numbers: sangat membantu dalam kegiatan rapat baik banyak orang ataupun hanya berdua
# After case transformation: sangat membantu dalam kegiatan rapat baik banyak orang ataupun hanya berdua
# After tokenization: ['sangat', 'membantu', 'dalam', 'kegiatan', 'rapat', 'baik', 'banyak', 'orang', 'ataupun', 'hanya', 'berdua']
# After stopword removal: membantu kegiatan rapat orang berdua
# After stemming: bantu giat rapat orang dua
# ------
# Original: Sangat bagus dalam mengelola dokumen
# After replacing numbers: Sangat bagus dalam mengelola dokumen
# After case transformation: sangat bagus dalam mengelola dokumen
# After tokenization: ['sangat', 'bagus', 'dalam', 'mengelola', 'dokumen']
# After stopword removal: bagus mengelola dokumen
# After stemming: bagus kelola dokumen
# ------
# Original: Bekerja dengan sesuatu yang barusan mendapatkan pengalaman yang bagus, Microsoft Teams memang keren, sangat membantu pekerjaan
# After replacing numbers: Bekerja dengan sesuatu yang barusan mendapatkan pengalaman yang bagus, Microsoft Teams memang keren, sangat membantu pekerjaan
# After case transformation: bekerja dengan sesuatu yang barusan mendapatkan pengalaman yang bagus, microsoft teams memang keren, sangat membantu pekerjaan
# After tokenization: ['bekerja', 'dengan', 'sesuatu', 'yang', 'barusan', 'mendapatkan', 'pengalaman', 'yang', 'bagus,', 'microsoft', 'teams', 'memang', 'keren,', 'sangat', 'membantu', 'pekerjaan']
# After stopword removal: barusan pengalaman bagus, microsoft teams keren, membantu pekerjaan
# After stemming: barusan alam bagus microsoft teams keren bantu kerja
# ------
# Original: Sangat memudahkan kerja
# After replacing numbers: Sangat memudahkan kerja
# After case transformation: sangat memudahkan kerja
# After tokenization: ['sangat', 'memudahkan', 'kerja']
# After stopword removal: memudahkan kerja
# After stemming: mudah kerja
# ------
# Original: Nice. memudahkan pekerjaan saya
# After replacing numbers: Nice. memudahkan pekerjaan saya
# After case transformation: nice. memudahkan pekerjaan saya
# After tokenization: ['nice.', 'memudahkan', 'pekerjaan', 'saya']
# After stopword removal: nice. memudahkan pekerjaan
# After stemming: nice mudah kerja
# ------
# Original: Bisa membantu pekerjaan melalui HP
# After replacing numbers: Bisa membantu pekerjaan melalui HP
# After case transformation: bisa membantu pekerjaan melalui hp
# After tokenization: ['bisa', 'membantu', 'pekerjaan', 'melalui', 'hp']
# After stopword removal: membantu pekerjaan hp
# After stemming: bantu kerja hp
# ------
# Original: Aplikasi yang bagus untuk grup kelas. Bisa untuk belajar bersama
# After replacing numbers: Aplikasi yang bagus untuk grup kelas. Bisa untuk belajar bersama
# After case transformation: aplikasi yang bagus untuk grup kelas. bisa untuk belajar bersama
# After tokenization: ['aplikasi', 'yang', 'bagus', 'untuk', 'grup', 'kelas.', 'bisa', 'untuk', 'belajar', 'bersama']
# After stopword removal: aplikasi bagus grup kelas. belajar
# After stemming: aplikasi bagus grup kelas ajar
# ------
# Original: Bagus banget aplikasi ini, mudah tidak ribet dipakai nya. Recomend banget pokoknya 
# After replacing numbers: Bagus banget aplikasi ini, mudah tidak ribet dipakai nya. Recomend banget pokoknya 
# After case transformation: bagus banget aplikasi ini, mudah tidak ribet dipakai nya. recomend banget pokoknya 
# After tokenization: ['bagus', 'banget', 'aplikasi', 'ini,', 'mudah', 'tidak', 'ribet', 'dipakai', 'nya.', 'recomend', 'banget', 'pokoknya', '\x8d']
# After stopword removal: bagus banget aplikasi ini, mudah ribet dipakai nya. recomend banget pokoknya 
# After stemming: bagus banget aplikasi ini mudah ribet pakai nya recomend banget pokok
# ------
# Original: Bertemu menjadi mudah , meeting pun menjadi lancar
# After replacing numbers: Bertemu menjadi mudah , meeting pun menjadi lancar
# After case transformation: bertemu menjadi mudah , meeting pun menjadi lancar
# After tokenization: ['bertemu', 'menjadi', 'mudah', ',', 'meeting', 'pun', 'menjadi', 'lancar']
# After stopword removal: bertemu mudah , meeting lancar
# After stemming: temu mudah meeting lancar
# ------
# Original: Dengan microsoft teams, sangat membantu pekerjaan saya untuk terus berkomunikasi dengan parter partner kerja seperti permata motor kadipaten, dan yang lainnya, memudahkan saya untuk terus terhubung satu sama lain, hanya dengan satu aplikasi, yaitu microsoft teams, terus di tingkatkan lagi, dan semoga lebih baik lagi.
# After replacing numbers: Dengan microsoft teams, sangat membantu pekerjaan saya untuk terus berkomunikasi dengan parter partner kerja seperti permata motor kadipaten, dan yang lainnya, memudahkan saya untuk terus terhubung satu sama lain, hanya dengan satu aplikasi, yaitu microsoft teams, terus di tingkatkan lagi, dan semoga lebih baik lagi.
# After case transformation: dengan microsoft teams, sangat membantu pekerjaan saya untuk terus berkomunikasi dengan parter partner kerja seperti permata motor kadipaten, dan yang lainnya, memudahkan saya untuk terus terhubung satu sama lain, hanya dengan satu aplikasi, yaitu microsoft teams, terus di tingkatkan lagi, dan semoga lebih baik lagi.
# After tokenization: ['dengan', 'microsoft', 'teams,', 'sangat', 'membantu', 'pekerjaan', 'saya', 'untuk', 'terus', 'berkomunikasi', 'dengan', 'parter', 'partner', 'kerja', 'seperti', 'permata', 'motor', 'kadipaten,', 'dan', 'yang', 'lainnya,', 'memudahkan', 'saya', 'untuk', 'terus', 'terhubung', 'satu', 'sama', 'lain,', 'hanya', 'dengan', 'satu', 'aplikasi,', 'yaitu', 'microsoft', 'teams,', 'terus', 'di', 'tingkatkan', 'lagi,', 'dan', 'semoga', 'lebih', 'baik', 'lagi.']
# After stopword removal: microsoft teams, membantu pekerjaan berkomunikasi parter partner kerja permata motor kadipaten, lainnya, memudahkan terhubung lain, aplikasi, microsoft teams, tingkatkan lagi, semoga lagi.
# After stemming: microsoft teams bantu kerja komunikasi parter partner kerja permata motor kadipaten lain mudah hubung lain aplikasi microsoft teams tingkat lagi moga lagi
# ------
# Original: Mantap untuk meeting kerja dan saat interview kerja
# After replacing numbers: Mantap untuk meeting kerja dan saat interview kerja
# After case transformation: mantap untuk meeting kerja dan saat interview kerja
# After tokenization: ['mantap', 'untuk', 'meeting', 'kerja', 'dan', 'saat', 'interview', 'kerja']
# After stopword removal: mantap meeting kerja interview kerja
# After stemming: mantap meeting kerja interview kerja
# ------
# Original: Bagus, applikasi terbaik untuk telekonferens
# After replacing numbers: Bagus, applikasi terbaik untuk telekonferens
# After case transformation: bagus, applikasi terbaik untuk telekonferens
# After tokenization: ['bagus,', 'applikasi', 'terbaik', 'untuk', 'telekonferens']
# After stopword removal: bagus, applikasi terbaik telekonferens
# After stemming: bagus applikasi baik telekonferens
# ------
# Original: User friendly
# After replacing numbers: User friendly
# After case transformation: user friendly
# After tokenization: ['user', 'friendly']
# After stopword removal: user friendly
# After stemming: user friendly
# ------
# Original: sangat bagus tidak ada kekurangan bagi saya
# After replacing numbers: sangat bagus tidak ada kekurangan bagi saya
# After case transformation: sangat bagus tidak ada kekurangan bagi saya
# After tokenization: ['sangat', 'bagus', 'tidak', 'ada', 'kekurangan', 'bagi', 'saya']
# After stopword removal: bagus kekurangan
# After stemming: bagus kurang
# ------
# Original: Kegiatan lancar
# After replacing numbers: Kegiatan lancar
# After case transformation: kegiatan lancar
# After tokenization: ['kegiatan', 'lancar']
# After stopword removal: kegiatan lancar
# After stemming: giat lancar
# ------
# Original: Sangat bermanfaat untuk rapat official
# ...
# After stopword removal: suka heran gambar layarnya kecil. dosen gw share kontent, gambar hp gw banget terlerak pojok biasanya( uluran satu/delapan ukuran seharusnya) gambar stack. tombol join meeting buka dosen. jadul banget aplikasi lu, seberat game. game bug langsung fix. aplikasi lu bug emosi karuan lamanya. beres beresnya. lu tau bawahan lu ? arahan
# After stemming: suka heran gambar layar kecil dosen gw share kontent gambar hp gw banget lerak pojok biasa ulur satu delapan ukur harus gambar stack tombol join meeting buka dosen jadul banget aplikasi lu berat game game bug langsung fix aplikasi lu bug emosi karuan lama beres beres lu tau bawah lu arah
# ------
# Original: Loading tugasnya lama padahal sinyal bagus
# After replacing numbers: Loading tugasnya lama padahal sinyal bagus
# After case transformation: loading tugasnya lama padahal sinyal bagus
# After tokenization: ['loading', 'tugasnya', 'lama', 'padahal', 'sinyal', 'bagus']
# After stopword removal: loading tugasnya sinyal bagus
# After stemming: loading tugas sinyal bagus
# ------
# Original: Susah joinnya... Aplikasinya Payah...
# After replacing numbers: Susah joinnya... Aplikasinya Payah...
# After case transformation: susah joinnya... aplikasinya payah...
# After tokenization: ['susah', 'joinnya...', 'aplikasinya', 'payah...']
# After stopword removal: susah joinnya... aplikasinya payah...
# After stemming: susah joinnya aplikasi payah
# ------
# Original: Erornya masayallah, keluar sendiri terus.
# After replacing numbers: Erornya masayallah, keluar sendiri terus.
# After case transformation: erornya masayallah, keluar sendiri terus.
# After tokenization: ['erornya', 'masayallah,', 'keluar', 'sendiri', 'terus.']
# After stopword removal: erornya masayallah, terus.
# After stemming: eror masayallah terus
# ------
# Original: Kenapa sih tearms ini selalu minta password setiap dibuka
# After replacing numbers: Kenapa sih tearms ini selalu minta password setiap dibuka
# After case transformation: kenapa sih tearms ini selalu minta password setiap dibuka
# After tokenization: ['kenapa', 'sih', 'tearms', 'ini', 'selalu', 'minta', 'password', 'setiap', 'dibuka']
# After stopword removal: sih tearms password dibuka
# After stemming: sih tearms password buka
# ------
# Original: Suka keluar masuk padahal jaringan bagus
# After replacing numbers: Suka keluar masuk padahal jaringan bagus
# After case transformation: suka keluar masuk padahal jaringan bagus
# After tokenization: ['suka', 'keluar', 'masuk', 'padahal', 'jaringan', 'bagus']
# After stopword removal: suka masuk jaringan bagus
# After stemming: suka masuk jaring bagus
# ------
# Original: Ngecewain banget setiap zoom tidak bisa langsung masuk
# After replacing numbers: Ngecewain banget setiap zoom tidak bisa langsung masuk
# After case transformation: ngecewain banget setiap zoom tidak bisa langsung masuk
# After tokenization: ['ngecewain', 'banget', 'setiap', 'zoom', 'tidak', 'bisa', 'langsung', 'masuk']
# After stopword removal: ngecewain banget zoom langsung masuk
# After stemming: ngecewain banget zoom langsung masuk
# ------
# Original: Apk rusak jelek banget baru didownload saja tidak bisa ke buka
# After replacing numbers: Apk rusak jelek banget baru didownload saja tidak bisa ke buka
# After case transformation: apk rusak jelek banget baru didownload saja tidak bisa ke buka
# After tokenization: ['apk', 'rusak', 'jelek', 'banget', 'baru', 'didownload', 'saja', 'tidak', 'bisa', 'ke', 'buka']
# After stopword removal: apk rusak jelek banget didownload buka
# After stemming: apk rusak jelek banget didownload buka
# ------
# Original: Bagus, tapi lagi di meeting malah mic nya bermasalah terus. Bekin kesal pula. Lebih baik saya kasih bintang 2 dulu
# After replacing numbers: Bagus, tapi lagi di meeting malah mic nya bermasalah terus. Bekin kesal pula. Lebih baik saya kasih bintang dua dulu
# After case transformation: bagus, tapi lagi di meeting malah mic nya bermasalah terus. bekin kesal pula. lebih baik saya kasih bintang dua dulu
# After tokenization: ['bagus,', 'tapi', 'lagi', 'di', 'meeting', 'malah', 'mic', 'nya', 'bermasalah', 'terus.', 'bekin', 'kesal', 'pula.', 'lebih', 'baik', 'saya', 'kasih', 'bintang', 'dua', 'dulu']
# After stopword removal: bagus, meeting mic nya bermasalah terus. bekin kesal pula. kasih bintang
# After stemming: bagus meeting mic nya masalah terus bekin kesal pula kasih bintang
# ------
# Original: Kok tidak bisa masuk ya sandi nya salah terus padahal sudah sesuai. bagaimana dong aplikasi nya padahalsaya butuh banget
# After replacing numbers: Kok tidak bisa masuk ya sandi nya salah terus padahal sudah sesuai. bagaimana dong aplikasi nya padahalsaya butuh banget
# After case transformation: kok tidak bisa masuk ya sandi nya salah terus padahal sudah sesuai. bagaimana dong aplikasi nya padahalsaya butuh banget
# After tokenization: ['kok', 'tidak', 'bisa', 'masuk', 'ya', 'sandi', 'nya', 'salah', 'terus', 'padahal', 'sudah', 'sesuai.', 'bagaimana', 'dong', 'aplikasi', 'nya', 'padahalsaya', 'butuh', 'banget']
# After stopword removal: masuk ya sandi nya salah sesuai. aplikasi nya padahalsaya butuh banget
# After stemming: masuk ya sandi nya salah sesuai aplikasi nya padahalsaya butuh banget
# ------
# Original: Aplikasinya error masak tugasnya masuk terus
# After replacing numbers: Aplikasinya error masak tugasnya masuk terus
# After case transformation: aplikasinya error masak tugasnya masuk terus
# After tokenization: ['aplikasinya', 'error', 'masak', 'tugasnya', 'masuk', 'terus']
# After stopword removal: aplikasinya error masak tugasnya masuk
# After stemming: aplikasi error masak tugas masuk
# ------
# Original: Aplikasi sering error beberapa kali dibuka tetap tidak bisa ini aplikasi sebenarnya bisa dipergunakan tidak sih, sementara mau di pakai untuk rapat, harap diperbaiki kembali!!!.
# After replacing numbers: Aplikasi sering error beberapa kali dibuka tetap tidak bisa ini aplikasi sebenarnya bisa dipergunakan tidak sih, sementara mau di pakai untuk rapat, harap diperbaiki kembali!!!.
# After case transformation: aplikasi sering error beberapa kali dibuka tetap tidak bisa ini aplikasi sebenarnya bisa dipergunakan tidak sih, sementara mau di pakai untuk rapat, harap diperbaiki kembali!!!.
# After tokenization: ['aplikasi', 'sering', 'error', 'beberapa', 'kali', 'dibuka', 'tetap', 'tidak', 'bisa', 'ini', 'aplikasi', 'sebenarnya', 'bisa', 'dipergunakan', 'tidak', 'sih,', 'sementara', 'mau', 'di', 'pakai', 'untuk', 'rapat,', 'harap', 'diperbaiki', 'kembali!!!.']
# After stopword removal: aplikasi error kali dibuka aplikasi sih, pakai rapat, harap diperbaiki kembali!!!.
# After stemming: aplikasi error kali buka aplikasi sih pakai rapat harap baik kembali
# ------
# Original: Saya kasih bintang 1 saja ,karena setiap saya masuk ke microsoft team selalu saja eror,tolong lah di perbaiki lagi perangkat
# After replacing numbers: Saya kasih bintang satu saja ,karena setiap saya masuk ke microsoft team selalu saja eror,tolong lah di perbaiki lagi perangkat
# After case transformation: saya kasih bintang satu saja ,karena setiap saya masuk ke microsoft team selalu saja eror,tolong lah di perbaiki lagi perangkat
# After tokenization: ['saya', 'kasih', 'bintang', 'satu', 'saja', ',karena', 'setiap', 'saya', 'masuk', 'ke', 'microsoft', 'team', 'selalu', 'saja', 'eror,tolong', 'lah', 'di', 'perbaiki', 'lagi', 'perangkat']
# After stopword removal: kasih bintang ,karena masuk microsoft team eror,tolong perbaiki perangkat
# After stemming: kasih bintang karena masuk microsoft team eror tolong baik perangkat
# ------
# Original: ketika akan bergabung rapat melalui tautan link, selalu  gagal masuk berkali- kali dan selalu mengulang login akun microsoftnya, padahal saya sudah memasukan gmail  dan verifikasi pun sudah benar, tapi tetap saja tidak bisa masuk, dan terus berulang disuruh login akun lagi dan  gagal lagi.
# After replacing numbers: ketika akan bergabung rapat melalui tautan link, selalu  gagal masuk berkali- kali dan selalu mengulang login akun microsoftnya, padahal saya sudah memasukan gmail  dan verifikasi pun sudah benar, tapi tetap saja tidak bisa masuk, dan terus berulang disuruh login akun lagi dan  gagal lagi.
# After case transformation: ketika akan bergabung rapat melalui tautan link, selalu  gagal masuk berkali- kali dan selalu mengulang login akun microsoftnya, padahal saya sudah memasukan gmail  dan verifikasi pun sudah benar, tapi tetap saja tidak bisa masuk, dan terus berulang disuruh login akun lagi dan  gagal lagi.
# After tokenization: ['ketika', 'akan', 'bergabung', 'rapat', 'melalui', 'tautan', 'link,', 'selalu', 'gagal', 'masuk', 'berkali-', 'kali', 'dan', 'selalu', 'mengulang', 'login', 'akun', 'microsoftnya,', 'padahal', 'saya', 'sudah', 'memasukan', 'gmail', 'dan', 'verifikasi', 'pun', 'sudah', 'benar,', 'tapi', 'tetap', 'saja', 'tidak', 'bisa', 'masuk,', 'dan', 'terus', 'berulang', 'disuruh', 'login', 'akun', 'lagi', 'dan', 'gagal', 'lagi.']
# After stopword removal: bergabung rapat tautan link, gagal masuk berkali- kali mengulang login akun microsoftnya, memasukan gmail verifikasi benar, masuk, berulang disuruh login akun gagal lagi.
# After stemming: gabung rapat taut link gagal masuk berkali- kali ulang login akun microsoftnya pasu gmail verifikasi benar masuk ulang suruh login akun gagal lagi
# ------
# Original: tidak ada, pokoknya aplikasi ini jelek banget
# After replacing numbers: tidak ada, pokoknya aplikasi ini jelek banget
# After case transformation: tidak ada, pokoknya aplikasi ini jelek banget
# After tokenization: ['tidak', 'ada,', 'pokoknya', 'aplikasi', 'ini', 'jelek', 'banget']
# After stopword removal: ada, pokoknya aplikasi jelek banget
# After stemming: ada pokok aplikasi jelek banget
# ------
# Original: kalau di hp suruh join manual terus capek!!!!! kalau ada notif tidak tau!!!!
# After replacing numbers: kalau di hp suruh join manual terus capek!!!!! kalau ada notif tidak tau!!!!
# After case transformation: kalau di hp suruh join manual terus capek!!!!! kalau ada notif tidak tau!!!!
# After tokenization: ['kalau', 'di', 'hp', 'suruh', 'join', 'manual', 'terus', 'capek!!!!!', 'kalau', 'ada', 'notif', 'tidak', 'tau!!!!']
# After stopword removal: hp suruh join manual capek!!!!! notif tau!!!!
# After stemming: hp suruh join manual capek notif tau
# ------
# Original: Aplikasi tidak bisa login lewat hp, yakali harus buka laptop mulu
# After replacing numbers: Aplikasi tidak bisa login lewat hp, yakali harus buka laptop mulu
# After case transformation: aplikasi tidak bisa login lewat hp, yakali harus buka laptop mulu
# After tokenization: ['aplikasi', 'tidak', 'bisa', 'login', 'lewat', 'hp,', 'yakali', 'harus', 'buka', 'laptop', 'mulu']
# After stopword removal: aplikasi login hp, yakali buka laptop mulu
# After stemming: aplikasi login hp yakali buka laptop mulu
# ------
# Original: Aneh, suka ke logout sendiri. setiap mau masuk kenapa keterangan sandi salah, padahal tidak pernah diubah sandi.
# After replacing numbers: Aneh, suka ke logout sendiri. setiap mau masuk kenapa keterangan sandi salah, padahal tidak pernah diubah sandi.
# After case transformation: aneh, suka ke logout sendiri. setiap mau masuk kenapa keterangan sandi salah, padahal tidak pernah diubah sandi.
# After tokenization: ['aneh,', 'suka', 'ke', 'logout', 'sendiri.', 'setiap', 'mau', 'masuk', 'kenapa', 'keterangan', 'sandi', 'salah,', 'padahal', 'tidak', 'pernah', 'diubah', 'sandi.']
# After stopword removal: aneh, suka logout sendiri. masuk keterangan sandi salah, diubah sandi.
# After stemming: aneh suka logout sendiri masuk terang sandi salah ubah sandi
# ------
# Original: sering banget eror, sampe untuk akun 3 tetap saja ngga bisa masuk
# After replacing numbers: sering banget eror, sampe untuk akun tiga tetap saja ngga bisa masuk
# After case transformation: sering banget eror, sampe untuk akun tiga tetap saja ngga bisa masuk
# After tokenization: ['sering', 'banget', 'eror,', 'sampe', 'untuk', 'akun', 'tiga', 'tetap', 'saja', 'ngga', 'bisa', 'masuk']
# After stopword removal: banget eror, sampe akun ngga masuk
# After stemming: banget eror sampe akun ngga masuk
# ------
# Original: MIRCROFON TIDAK BISA. SERING KELUAR SENDIRI!!!!
# After replacing numbers: MIRCROFON TIDAK BISA. SERING KELUAR SENDIRI!!!!
# After case transformation: mircrofon tidak bisa. sering keluar sendiri!!!!
# After tokenization: ['mircrofon', 'tidak', 'bisa.', 'sering', 'keluar', 'sendiri!!!!']
# After stopword removal: mircrofon bisa. sendiri!!!!
# After stemming: mircrofon bisa sendiri
# ------
# Original: Tidak bisa masuk forum rapat terus
# After replacing numbers: Tidak bisa masuk forum rapat terus
# After case transformation: tidak bisa masuk forum rapat terus
# After tokenization: ['tidak', 'bisa', 'masuk', 'forum', 'rapat', 'terus']
# After stopword removal: masuk forum rapat
# After stemming: masuk forum rapat
# ------
# Original: sekarang buka kenapa harus perbaruan kata sandi tidak seperti dulu
# After replacing numbers: sekarang buka kenapa harus perbaruan kata sandi tidak seperti dulu
# After case transformation: sekarang buka kenapa harus perbaruan kata sandi tidak seperti dulu
# After tokenization: ['sekarang', 'buka', 'kenapa', 'harus', 'perbaruan', 'kata', 'sandi', 'tidak', 'seperti', 'dulu']
# After stopword removal: buka perbaruan sandi
# After stemming: buka baru sandi
# ------
# Original: kenapa kalau di upddet ulang fitur2nya hilang semua, untuk mengerjakan tugas tidak bisa.
# After replacing numbers: kenapa kalau di upddet ulang fiturduanya hilang semua, untuk mengerjakan tugas tidak bisa.
# After case transformation: kenapa kalau di upddet ulang fiturduanya hilang semua, untuk mengerjakan tugas tidak bisa.
# After tokenization: ['kenapa', 'kalau', 'di', 'upddet', 'ulang', 'fiturduanya', 'hilang', 'semua,', 'untuk', 'mengerjakan', 'tugas', 'tidak', 'bisa.']
# After stopword removal: upddet ulang fiturduanya hilang semua, tugas bisa.
# After stemming: upddet ulang fiturduanya hilang semua tugas bisa
# ------
# Original: Kok setelah di-update,mau buka tugas kok error terus ya & bagian assigmentnya hilang,woy tolonglah dibangetin itu. Mau untuk tugas tidak bisa-bisa,sudah ditagih tagih ini sama guru,plis tolonglah cepet dibangetin
# After replacing numbers: Kok setelah di-update,mau buka tugas kok error terus ya & bagian assigmentnya hilang,woy tolonglah dibangetin itu. Mau untuk tugas tidak bisa-bisa,sudah ditagih tagih ini sama guru,plis tolonglah cepet dibangetin
# After case transformation: kok setelah di-update,mau buka tugas kok error terus ya & bagian assigmentnya hilang,woy tolonglah dibangetin itu. mau untuk tugas tidak bisa-bisa,sudah ditagih tagih ini sama guru,plis tolonglah cepet dibangetin
# After tokenization: ['kok', 'setelah', 'di-update,mau', 'buka', 'tugas', 'kok', 'error', 'terus', 'ya', '&', 'bagian', 'assigmentnya', 'hilang,woy', 'tolonglah', 'dibangetin', 'itu.', 'mau', 'untuk', 'tugas', 'tidak', 'bisa-bisa,sudah', 'ditagih', 'tagih', 'ini', 'sama', 'guru,plis', 'tolonglah', 'cepet', 'dibangetin']
# After stopword removal: di-update,mau buka tugas error ya & assigmentnya hilang,woy tolonglah dibangetin itu. tugas bisa-bisa,sudah ditagih tagih guru,plis tolonglah cepet dibangetin
# After stemming: di-update mau buka tugas error ya assigmentnya hilang woy tolong dibangetin itu tugas bisa sudah tagih tagih guru plis tolong cepet dibangetin
# ------
#    score                        content    label
# 0      5                pintar aplikasi  POSITIF
# 1      5                           good  POSITIF
# 2      5                    mudah tugas  POSITIF
# 3      4                            oke  POSITIF
# 4      5  bantu banget aplikasi manfaat  POSITIF
